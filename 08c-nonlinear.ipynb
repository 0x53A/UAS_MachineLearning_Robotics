# %% [markdown]
# # Network Comparison Experiments
#
# This notebook compares training results across different seeds and network topologies.
#
# - Seed comparison: Train 5 networks with seeds 0-4
# - Topology comparison: Vary hidden layers (1-7) and neurons (1-8) with seed=0
# - Both experiments share cached checkpoints where topologies and seeds overlap

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt

from lib import (
    Net, NetConfig,
    SymbolicActivation, SymbolicLoss, WeightInit,
    CheckpointConfig, compute_data_hash
)

# %%
# Generate training data
np.random.seed(42)

q1 = np.random.uniform(-1, 1, 1000)
q2 = np.random.uniform(-1, 1, 1000)

def target_function(q1, q2):
    X1 = q1 + (q2**2) - 1
    X2 = q1 - q2 + 1
    return X1, X2

X1, X2 = target_function(q1, q2)

inputs = [[q1[i], q2[i]] for i in range(len(q1))]
targets = [[X1[i], X2[i]] for i in range(len(X1))]

inputs = np.array(inputs)
targets = np.array(targets)

input_list = [inputs[i] for i in range(len(inputs))]
target_list = [targets[i] for i in range(len(targets))]

print(f"Generated {len(inputs)} training samples")
print(f"Input shape: {inputs.shape}")
print(f"Target shape: {targets.shape}")
# Out:
# Generated 1000 training samples
# Input shape: (1000, 2)
# Target shape: (1000, 2)

# %%
# Compute hash for training data (enables checkpoint sharing)
data_hash = compute_data_hash(input_list, target_list)
print(f"Data hash: {data_hash}")

# Configure checkpointing
checkpoint_config = CheckpointConfig(
    enabled=True,
    cache_dir='.net_cache',
    checkpoint_interval=20,
    data_hash=data_hash,
    overwrite=False
)
print("Checkpointing enabled")
# Out:
# Data hash: a1ef014a45550963
# Checkpointing enabled

# %% [markdown]
# ## Seed Comparison
#
# Train 5 networks with seeds 0 to 4 to see effect of random initialization.

# %%
seed_results = {}
seeds = range(5)
epochs = 300
learning_rate = 0.01

for seed in seeds:
    print(f"Training with seed={seed}...")
    
    config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
        n_inputs=2,
        n_outputs=2,
        n_hidden_layers=2,
        n_neurons_per_hidden=4,
        loss_func=SymbolicLoss.mse(),
        weight_init=WeightInit.XAVIER,
        bias_init_std=0.01,
        seed=seed
    )
    
    net = Net.fully_connected(config)
    
    result = net.train(
        inputs=input_list,
        targets=target_list,
        learning_rate=learning_rate,
        epochs=epochs,
        batch_size=32,
        checkpoint_config=checkpoint_config
    )
    
    seed_results[seed] = result['loss_history']
    print(f"  Seed {seed}: final loss = {result['loss_history'][-1]:.6f}")

print("\nAll seed experiments complete!")
# Out:
# Training with seed=0...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Seed 0: final loss = 0.002078
# Training with seed=1...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Seed 1: final loss = 0.001486
# Training with seed=2...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Seed 2: final loss = 0.001266
# Training with seed=3...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Seed 3: final loss = 0.002120
# Training with seed=4...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Seed 4: final loss = 0.001455
#
# All seed experiments complete!

# %% [markdown]
# ### Seed Comparison Plot

# %%
plt.figure(figsize=(12, 6))

for seed, loss_history in seed_results.items():
    plt.plot(loss_history, label=f'Seed {seed}', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss Across Different Seeds')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# Statistics
final_losses = [seed_results[s][-1] for s in seeds]
print(f"Final losses: {[f'{l:.6f}' for l in final_losses]}")
print(f"Mean final loss: {np.mean(final_losses):.6f}")
print(f"Std final loss: {np.std(final_losses):.6f}")
print(f"Min final loss: {np.min(final_losses):.6f} (seed {seeds[np.argmin(final_losses)]})")
print(f"Max final loss: {np.max(final_losses):.6f} (seed {seeds[np.argmax(final_losses)]})")
# Out:
# Final losses: ['0.002078', '0.001486', '0.001266', '0.002120', '0.001455']
# Mean final loss: 0.001681
# Std final loss: 0.000350
# Min final loss: 0.001266 (seed 2)
# Max final loss: 0.002120 (seed 3)

# %% [markdown]
# ## Topology Comparison
#
# Compare training loss for different network topologies with seed=0.
#
# - Hidden layers: 1 to 7
# - Neurons per hidden layer: 1 to 8
#
# **Note:** The topology with 2 hidden layers and 4 neurons per layer will reuse the cached checkpoint from the seed comparison experiment (seed=0).

# %%
topology_results = {}
hidden_layers_range = range(1, 9)
neurons_range = range(1, 9)
epochs = 300
learning_rate = 0.01
seed = 0

for n_hidden in hidden_layers_range:
    for n_neurons in neurons_range:
        print(f"Training: {n_hidden} hidden layers, {n_neurons} neurons each...")
        
        config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
            n_inputs=2,
            n_outputs=2,
            n_hidden_layers=n_hidden,
            n_neurons_per_hidden=n_neurons,
            loss_func=SymbolicLoss.mse(),
            weight_init=WeightInit.XAVIER,
            bias_init_std=0.01,
            seed=seed
        )
        
        net = Net.fully_connected(config)
        
        result = net.train(
            inputs=input_list,
            targets=target_list,
            learning_rate=learning_rate,
            epochs=epochs,
            batch_size=32,
            checkpoint_config=checkpoint_config
        )
        
        topology_results[(n_hidden, n_neurons)] = result['loss_history']
        print(f"  Final loss: {result['loss_history'][-1]:.6f}")

print("\nAll topology experiments complete!")
# Out:
# Training: 1 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.110472
# Training: 1 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.006798
# Training: 1 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.003519
# Training: 1 hidden layers, 4 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001651
# Training: 1 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001500
# Training: 1 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001581
# Training: 1 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001689
# Training: 1 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.002065
# Training: 2 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.110813
# Training: 2 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.003591
# Training: 2 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001971
# Training: 2 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.002078
# Training: 2 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001815
# Training: 2 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001216
# Training: 2 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001423
# Training: 2 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001330
# Training: 3 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.111380
# Training: 3 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.005339
# Training: 3 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.002526
# Training: 3 hidden layers, 4 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001281
# Training: 3 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001426
# Training: 3 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001266
# Training: 3 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001285
# Training: 3 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001011
# Training: 4 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.114924
# Training: 4 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.007761
# Training: 4 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.004229
# Training: 4 hidden layers, 4 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001601
# Training: 4 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001555
# Training: 4 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001364
# Training: 4 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001546
# Training: 4 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.000881
# Training: 5 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.117835
# Training: 5 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.010356
# Training: 5 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.002334
# Training: 5 hidden layers, 4 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.003668
# Training: 5 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001666
# Training: 5 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001655
# Training: 5 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001560
# Training: 5 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.000991
# Training: 6 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.120855
# Training: 6 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.043976
# Training: 6 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.005822
# Training: 6 hidden layers, 4 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.004655
# Training: 6 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.002437
# Training: 6 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001971
# Training: 6 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001888
# Training: 6 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.000407
# Training: 7 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.126206
# Training: 7 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.105043
# Training: 7 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.007314
# Training: 7 hidden layers, 4 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.006674
# Training: 7 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.003746
# Training: 7 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001689
# Training: 7 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001069
# Training: 7 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.000774
# Training: 8 hidden layers, 1 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.132694
# Training: 8 hidden layers, 2 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.105658
# Training: 8 hidden layers, 3 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.010532
# Training: 8 hidden layers, 4 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.006957
# Training: 8 hidden layers, 5 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001802
# Training: 8 hidden layers, 6 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001649
# Training: 8 hidden layers, 7 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.002071
# Training: 8 hidden layers, 8 neurons each...
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
#   Final loss: 0.001494
#
# All topology experiments complete!

# %% [markdown]
# ### Final Loss Heatmap

# %%
# Create heatmap of final losses
final_loss_grid = np.zeros((len(hidden_layers_range), len(neurons_range)))

for i, n_hidden in enumerate(hidden_layers_range):
    for j, n_neurons in enumerate(neurons_range):
        final_loss_grid[i, j] = topology_results[(n_hidden, n_neurons)][-1]

plt.figure(figsize=(12, 8))
im = plt.imshow(final_loss_grid, cmap='viridis', aspect='auto', origin='lower')

plt.xticks(range(len(neurons_range)), neurons_range)
plt.yticks(range(len(hidden_layers_range)), hidden_layers_range)
plt.xlabel('Neurons per Hidden Layer')
plt.ylabel('Number of Hidden Layers')
plt.title('Final Training Loss by Network Topology (Seed=0)')
plt.colorbar(im, label='Final Loss')
plt.show()

# Find best topology
best_idx = np.unravel_index(np.argmin(final_loss_grid), final_loss_grid.shape)
best_n_hidden = hidden_layers_range[best_idx[0]]
best_n_neurons = neurons_range[best_idx[1]]
best_loss = final_loss_grid[best_idx]

print(f"Best topology: {best_n_hidden} hidden layers, {best_n_neurons} neurons each")
print(f"Best final loss: {best_loss:.6f}")
print(f"Total parameters: {best_n_hidden * best_n_neurons * (2 + best_n_hidden) + 2 * best_n_hidden + 2}")
# Out:
# Best topology: 6 hidden layers, 8 neurons each
# Best final loss: 0.000407
# Total parameters: 398

# %% [markdown]
# ### Training Curves by Topology

# %%
# Plot a few representative topologies
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
fig.suptitle('Training Loss by Topology (Seed=0)', fontsize=14)

for idx, n_hidden in enumerate(hidden_layers_range):
    row = idx // 4
    col = idx % 4
    ax = axes[row, col]
    
    for n_neurons in neurons_range:
        if (n_hidden, n_neurons) in topology_results:
            loss_hist = topology_results[(n_hidden, n_neurons)]
            ax.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)
    
    ax.set_title(f'{n_hidden} Hidden Layer(s)')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)
    ax.set_yscale('log')

plt.tight_layout()
plt.show()

# %%
# Plot all topologies with fixed neurons (4)
plt.figure(figsize=(12, 6))

for n_hidden in hidden_layers_range:
    n_neurons = 4
    loss_hist = topology_results[(n_hidden, n_neurons)]
    plt.plot(loss_hist, label=f'{n_hidden} layer(s)', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Hidden Layers (4 neurons each, Seed=0)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %%
# Plot all topologies with fixed layers (2)
plt.figure(figsize=(12, 6))

for n_neurons in neurons_range:
    n_hidden = 2
    loss_hist = topology_results[(n_hidden, n_neurons)]
    plt.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Neurons (2 hidden layers, Seed=0)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Summary
#
# ### Key Findings:

# %%
# Compute summary statistics
print("=" * 60)
print("SEED COMPARISON SUMMARY")
print("=" * 60)
seed_final = [seed_results[s][-1] for s in seeds]
print(f"Seeds tested: {list(seeds)}")
print(f"Final losses: {[f'{l:.6f}' for l in seed_final]}")
print(f"Mean: {np.mean(seed_final):.6f}")
print(f"Std: {np.std(seed_final):.6f}")
print(f"Range: [{np.min(seed_final):.6f}, {np.max(seed_final):.6f}]")

print("\n" + "=" * 60)
print("TOPOLOGY COMPARISON SUMMARY")
print("=" * 60)
print(f"Hidden layers tested: {list(hidden_layers_range)}")
print(f"Neurons tested: {list(neurons_range)}")
print(f"Total configurations: {len(hidden_layers_range) * len(neurons_range)}")

all_final_losses = [topology_results[(h, n)][-1] for h in hidden_layers_range for n in neurons_range]
print(f"\nBest final loss: {np.min(all_final_losses):.6f}")
print(f"Worst final loss: {np.max(all_final_losses):.6f}")
print(f"Mean final loss: {np.mean(all_final_losses):.6f}")
print(f"Median final loss: {np.median(all_final_losses):.6f}")
# Out:
# ============================================================
# SEED COMPARISON SUMMARY
# ============================================================
# Seeds tested: [0, 1, 2, 3, 4]
# Final losses: ['0.002078', '0.001486', '0.001266', '0.002120', '0.001455']
# Mean: 0.001681
# Std: 0.000350
# Range: [0.001266, 0.002120]
#
# ============================================================
# TOPOLOGY COMPARISON SUMMARY
# ============================================================
# Hidden layers tested: [1, 2, 3, 4, 5, 6, 7, 8]
# Neurons tested: [1, 2, 3, 4, 5, 6, 7, 8]
# Total configurations: 64
#
# Best final loss: 0.000407
# Worst final loss: 0.132694
# Mean final loss: 0.021099
# Median final loss: 0.002018

# %%
# topology_results = {}
# hidden_layers_range = range(1, 2)
# neurons_range = range(1, 100)
# epochs = 3000
# learning_rate = 0.01
# seed = 0

# for n_hidden in hidden_layers_range:
#     for n_neurons in neurons_range:
#         print(f"Training: {n_hidden} hidden layers, {n_neurons} neurons each...")
        
#         config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
#             n_inputs=2,
#             n_outputs=2,
#             n_hidden_layers=n_hidden,
#             n_neurons_per_hidden=n_neurons,
#             loss_func=SymbolicLoss.mse(),
#             weight_init=WeightInit.XAVIER,
#             bias_init_std=0.01,
#             seed=seed
#         )
        
#         net = Net.fully_connected(config)
        
#         result = net.train(
#             inputs=input_list,
#             targets=target_list,
#             learning_rate=learning_rate,
#             epochs=epochs,
#             batch_size=32,
#             checkpoint_config=checkpoint_config
#         )
        
#         topology_results[(n_hidden, n_neurons)] = result['loss_history']
#         print(f"  Final loss: {result['loss_history'][-1]:.6f}")

# print("\nAll topology experiments complete!")

# %%
# # Plot all topologies with fixed layers (1)
# plt.figure(figsize=(12, 6))

# for n_neurons in neurons_range:
#     n_hidden = 1
#     loss_hist = topology_results[(n_hidden, n_neurons)]
#     plt.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)

# plt.xlabel('Epoch')
# plt.ylabel('Loss (MSE)')
# plt.title('Training Loss: Varying Neurons (1 hidden layer, Seed=0)')
# #plt.legend()
# plt.grid(True, alpha=0.3)
# plt.yscale('log')
# plt.show()

# %%
config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
    n_inputs=2,
    n_outputs=2,
    n_hidden_layers=1,
    n_neurons_per_hidden=10,
    loss_func=SymbolicLoss.mse(),
    weight_init=WeightInit.XAVIER,
    bias_init_std=0.01,
    seed=seed
)

net = Net.fully_connected(config)

result = net.train(
    inputs=input_list,
    targets=target_list,
    learning_rate=0.01,
    epochs=100000,
    batch_size=32,
    checkpoint_config=checkpoint_config
)
# Out:
# Saved checkpoint at epoch 20
# Saved checkpoint at epoch 40
# Saved checkpoint at epoch 60
# Saved checkpoint at epoch 80
# Saved checkpoint at epoch 100
# Saved checkpoint at epoch 120
# Saved checkpoint at epoch 140
# Saved checkpoint at epoch 160
# Saved checkpoint at epoch 180
# Saved checkpoint at epoch 200
# Saved checkpoint at epoch 220
# Saved checkpoint at epoch 240
# Saved checkpoint at epoch 260
# Saved checkpoint at epoch 280
# Saved checkpoint at epoch 300
# Saved checkpoint at epoch 320
# Saved checkpoint at epoch 340
# Saved checkpoint at epoch 360
# Saved checkpoint at epoch 380
# Saved checkpoint at epoch 400
# Saved checkpoint at epoch 420
# Saved checkpoint at epoch 440
# Saved checkpoint at epoch 460
# Saved checkpoint at epoch 480
# Saved checkpoint at epoch 500
# Saved checkpoint at epoch 520
# Saved checkpoint at epoch 540
# Saved checkpoint at epoch 560
# Saved checkpoint at epoch 580
# Saved checkpoint at epoch 600
# Saved checkpoint at epoch 620
# Saved checkpoint at epoch 640
# Saved checkpoint at epoch 660
# Saved checkpoint at epoch 680
# Saved checkpoint at epoch 700
# Saved checkpoint at epoch 720
# Saved checkpoint at epoch 740
# Saved checkpoint at epoch 760
# Saved checkpoint at epoch 780
# Saved checkpoint at epoch 800
# Saved checkpoint at epoch 820
# Saved checkpoint at epoch 840
# Saved checkpoint at epoch 860
# Saved checkpoint at epoch 880
# Saved checkpoint at epoch 900
# Saved checkpoint at epoch 920
# Saved checkpoint at epoch 940
# Saved checkpoint at epoch 960
# Saved checkpoint at epoch 980
# Saved checkpoint at epoch 1000
# Saved checkpoint at epoch 1020
# Saved checkpoint at epoch 1040
# Saved checkpoint at epoch 1060
# Saved checkpoint at epoch 1080
# Saved checkpoint at epoch 1100
# Saved checkpoint at epoch 1120
# Saved checkpoint at epoch 1140
# Saved checkpoint at epoch 1160
# Saved checkpoint at epoch 1180
# Saved checkpoint at epoch 1200
# Saved checkpoint at epoch 1220
# Saved checkpoint at epoch 1240
# Saved checkpoint at epoch 1260
# Saved checkpoint at epoch 1280
# Saved checkpoint at epoch 1300
# Saved checkpoint at epoch 1320
# Saved checkpoint at epoch 1340
# Saved checkpoint at epoch 1360
# Saved checkpoint at epoch 1380
# Saved checkpoint at epoch 1400
# Saved checkpoint at epoch 1420
# Saved checkpoint at epoch 1440
# Saved checkpoint at epoch 1460
# Saved checkpoint at epoch 1480
# Saved checkpoint at epoch 1500
# Saved checkpoint at epoch 1520
# Saved checkpoint at epoch 1540
# Saved checkpoint at epoch 1560
# Saved checkpoint at epoch 1580
# Saved checkpoint at epoch 1600
# Saved checkpoint at epoch 1620
# Saved checkpoint at epoch 1640
# Saved checkpoint at epoch 1660
# Saved checkpoint at epoch 1680
# Saved checkpoint at epoch 1700
# Saved checkpoint at epoch 1720
# Saved checkpoint at epoch 1740
# Saved checkpoint at epoch 1760
# Saved checkpoint at epoch 1780
# Saved checkpoint at epoch 1800
# Saved checkpoint at epoch 1820
# Saved checkpoint at epoch 1840
# Saved checkpoint at epoch 1860
# Saved checkpoint at epoch 1880
# Saved checkpoint at epoch 1900
# Saved checkpoint at epoch 1920
# Saved checkpoint at epoch 1940
# Saved checkpoint at epoch 1960
# Saved checkpoint at epoch 1980
# Saved checkpoint at epoch 2000
# Saved checkpoint at epoch 2020
# Saved checkpoint at epoch 2040
# Saved checkpoint at epoch 2060
# Saved checkpoint at epoch 2080
# Saved checkpoint at epoch 2100
# Saved checkpoint at epoch 2120
# Saved checkpoint at epoch 2140
# Saved checkpoint at epoch 2160
# Saved checkpoint at epoch 2180
# Saved checkpoint at epoch 2200
# Saved checkpoint at epoch 2220
# Saved checkpoint at epoch 2240
# Saved checkpoint at epoch 2260
# Saved checkpoint at epoch 2280
# Saved checkpoint at epoch 2300
# Saved checkpoint at epoch 2320
# Saved checkpoint at epoch 2340
# Saved checkpoint at epoch 2360
# Saved checkpoint at epoch 2380
# Saved checkpoint at epoch 2400
# Saved checkpoint at epoch 2420
# Saved checkpoint at epoch 2440
# Saved checkpoint at epoch 2460
# Saved checkpoint at epoch 2480
# Saved checkpoint at epoch 2500
# Saved checkpoint at epoch 2520
# Saved checkpoint at epoch 2540
# Saved checkpoint at epoch 2560
# Saved checkpoint at epoch 2580
# Saved checkpoint at epoch 2600
# Saved checkpoint at epoch 2620
# Saved checkpoint at epoch 2640
# Saved checkpoint at epoch 2660
# Saved checkpoint at epoch 2680
# Saved checkpoint at epoch 2700
# Saved checkpoint at epoch 2720
# Saved checkpoint at epoch 2740
# Saved checkpoint at epoch 2760
# Saved checkpoint at epoch 2780
# Saved checkpoint at epoch 2800
# Saved checkpoint at epoch 2820
# Saved checkpoint at epoch 2840
# Saved checkpoint at epoch 2860
# Saved checkpoint at epoch 2880
# Saved checkpoint at epoch 2900
# Saved checkpoint at epoch 2920
# Saved checkpoint at epoch 2940
# Saved checkpoint at epoch 2960
# Saved checkpoint at epoch 2980
# Saved checkpoint at epoch 3000
# Saved checkpoint at epoch 3020
# Saved checkpoint at epoch 3040
# Saved checkpoint at epoch 3060
# Saved checkpoint at epoch 3080
# Saved checkpoint at epoch 3100
# Saved checkpoint at epoch 3120
# Saved checkpoint at epoch 3140
# Saved checkpoint at epoch 3160
# Saved checkpoint at epoch 3180
# Saved checkpoint at epoch 3200
# Saved checkpoint at epoch 3220
# Saved checkpoint at epoch 3240
# Saved checkpoint at epoch 3260
# Saved checkpoint at epoch 3280
# Saved checkpoint at epoch 3300
# Saved checkpoint at epoch 3320
# Saved checkpoint at epoch 3340
# Saved checkpoint at epoch 3360
# Saved checkpoint at epoch 3380
# Saved checkpoint at epoch 3400
# Saved checkpoint at epoch 3420
# Saved checkpoint at epoch 3440
# Saved checkpoint at epoch 3460
# Saved checkpoint at epoch 3480
# Saved checkpoint at epoch 3500
# Saved checkpoint at epoch 3520
# Saved checkpoint at epoch 3540
# Saved checkpoint at epoch 3560
# Saved checkpoint at epoch 3580
# Saved checkpoint at epoch 3600
# Saved checkpoint at epoch 3620
# Saved checkpoint at epoch 3640
# Saved checkpoint at epoch 3660
# Saved checkpoint at epoch 3680
# Saved checkpoint at epoch 3700
# Saved checkpoint at epoch 3720
# Saved checkpoint at epoch 3740
# Saved checkpoint at epoch 3760
# Saved checkpoint at epoch 3780
# Saved checkpoint at epoch 3800
# Saved checkpoint at epoch 3820
# Saved checkpoint at epoch 3840
# Saved checkpoint at epoch 3860
# Saved checkpoint at epoch 3880
# Saved checkpoint at epoch 3900
# Saved checkpoint at epoch 3920
# Saved checkpoint at epoch 3940
# Saved checkpoint at epoch 3960
# Saved checkpoint at epoch 3980
# Saved checkpoint at epoch 4000
# Saved checkpoint at epoch 4020
# Saved checkpoint at epoch 4040
# Saved checkpoint at epoch 4060
# Saved checkpoint at epoch 4080
# Saved checkpoint at epoch 4100
# Saved checkpoint at epoch 4120
# Saved checkpoint at epoch 4140
# Saved checkpoint at epoch 4160
# Saved checkpoint at epoch 4180
# Saved checkpoint at epoch 4200
# Saved checkpoint at epoch 4220
# Saved checkpoint at epoch 4240
# Saved checkpoint at epoch 4260
# Saved checkpoint at epoch 4280
# Saved checkpoint at epoch 4300
# Saved checkpoint at epoch 4320
# Saved checkpoint at epoch 4340
# Saved checkpoint at epoch 4360
# Saved checkpoint at epoch 4380
# Saved checkpoint at epoch 4400
# Saved checkpoint at epoch 4420
# Saved checkpoint at epoch 4440
# Saved checkpoint at epoch 4460
# Saved checkpoint at epoch 4480
# Saved checkpoint at epoch 4500
# Saved checkpoint at epoch 4520
# Saved checkpoint at epoch 4540
# Saved checkpoint at epoch 4560
# Saved checkpoint at epoch 4580
# Saved checkpoint at epoch 4600
# Saved checkpoint at epoch 4620
# Saved checkpoint at epoch 4640
# Saved checkpoint at epoch 4660
# Saved checkpoint at epoch 4680
# Saved checkpoint at epoch 4700
# Saved checkpoint at epoch 4720
# Saved checkpoint at epoch 4740
# Saved checkpoint at epoch 4760
# Saved checkpoint at epoch 4780
# Saved checkpoint at epoch 4800
# Saved checkpoint at epoch 4820
# Saved checkpoint at epoch 4840
# Saved checkpoint at epoch 4860
# Saved checkpoint at epoch 4880
# Saved checkpoint at epoch 4900
# Saved checkpoint at epoch 4920
# Saved checkpoint at epoch 4940
# Saved checkpoint at epoch 4960
# Saved checkpoint at epoch 4980
# Saved checkpoint at epoch 5000
# Saved checkpoint at epoch 5020
# Saved checkpoint at epoch 5040
# Saved checkpoint at epoch 5060
# Saved checkpoint at epoch 5080
# Saved checkpoint at epoch 5100
# Saved checkpoint at epoch 5120
# Saved checkpoint at epoch 5140
# Saved checkpoint at epoch 5160
# Saved checkpoint at epoch 5180
# Saved checkpoint at epoch 5200
# Saved checkpoint at epoch 5220
# Saved checkpoint at epoch 5240
# Saved checkpoint at epoch 5260
# Saved checkpoint at epoch 5280
# Saved checkpoint at epoch 5300
# Saved checkpoint at epoch 5320
# Saved checkpoint at epoch 5340
# Saved checkpoint at epoch 5360
# Saved checkpoint at epoch 5380
# Saved checkpoint at epoch 5400
# Saved checkpoint at epoch 5420
# Saved checkpoint at epoch 5440
# Saved checkpoint at epoch 5460
# Saved checkpoint at epoch 5480
# Saved checkpoint at epoch 5500
# Saved checkpoint at epoch 5520
# Saved checkpoint at epoch 5540
# Saved checkpoint at epoch 5560
# Saved checkpoint at epoch 5580
# Saved checkpoint at epoch 5600
# Saved checkpoint at epoch 5620
# Saved checkpoint at epoch 5640
# Saved checkpoint at epoch 5660
# Saved checkpoint at epoch 5680
# Saved checkpoint at epoch 5700
# Saved checkpoint at epoch 5720
# Saved checkpoint at epoch 5740
# Saved checkpoint at epoch 5760
# Saved checkpoint at epoch 5780
# Saved checkpoint at epoch 5800
# Saved checkpoint at epoch 5820
# Saved checkpoint at epoch 5840
# Saved checkpoint at epoch 5860
# Saved checkpoint at epoch 5880
# Saved checkpoint at epoch 5900
# Saved checkpoint at epoch 5920
# Saved checkpoint at epoch 5940
# Saved checkpoint at epoch 5960
# Saved checkpoint at epoch 5980
# Saved checkpoint at epoch 6000
# Saved checkpoint at epoch 6020
# Saved checkpoint at epoch 6040
# Saved checkpoint at epoch 6060
# Saved checkpoint at epoch 6080
# Saved checkpoint at epoch 6100
# Saved checkpoint at epoch 6120
# Saved checkpoint at epoch 6140
# Saved checkpoint at epoch 6160
# Saved checkpoint at epoch 6180
# Saved checkpoint at epoch 6200
# Saved checkpoint at epoch 6220
# Saved checkpoint at epoch 6240
# Saved checkpoint at epoch 6260
# Saved checkpoint at epoch 6280
# Saved checkpoint at epoch 6300
# Saved checkpoint at epoch 6320
# Saved checkpoint at epoch 6340
# Saved checkpoint at epoch 6360
# Saved checkpoint at epoch 6380
# Saved checkpoint at epoch 6400
# Saved checkpoint at epoch 6420
# Saved checkpoint at epoch 6440
# Saved checkpoint at epoch 6460
# Saved checkpoint at epoch 6480
# Saved checkpoint at epoch 6500
# Saved checkpoint at epoch 6520
# Saved checkpoint at epoch 6540
# Saved checkpoint at epoch 6560
# Saved checkpoint at epoch 6580
# Saved checkpoint at epoch 6600
# Saved checkpoint at epoch 6620
# Saved checkpoint at epoch 6640
# Saved checkpoint at epoch 6660
# Saved checkpoint at epoch 6680
# Saved checkpoint at epoch 6700
# Saved checkpoint at epoch 6720
# Saved checkpoint at epoch 6740
# Saved checkpoint at epoch 6760
# Saved checkpoint at epoch 6780
# Saved checkpoint at epoch 6800
# Saved checkpoint at epoch 6820
# Saved checkpoint at epoch 6840
# Saved checkpoint at epoch 6860
# Saved checkpoint at epoch 6880
# Saved checkpoint at epoch 6900
# Saved checkpoint at epoch 6920
# Saved checkpoint at epoch 6940
# Saved checkpoint at epoch 6960
# Saved checkpoint at epoch 6980
# Saved checkpoint at epoch 7000
# Saved checkpoint at epoch 7020
# Saved checkpoint at epoch 7040
# Saved checkpoint at epoch 7060
# Saved checkpoint at epoch 7080
# Saved checkpoint at epoch 7100
# Saved checkpoint at epoch 7120
# Saved checkpoint at epoch 7140
# Saved checkpoint at epoch 7160
# Saved checkpoint at epoch 7180
# Saved checkpoint at epoch 7200
# Saved checkpoint at epoch 7220
# Saved checkpoint at epoch 7240
# Saved checkpoint at epoch 7260
# Saved checkpoint at epoch 7280
# Saved checkpoint at epoch 7300
# Saved checkpoint at epoch 7320
# Saved checkpoint at epoch 7340
# Saved checkpoint at epoch 7360
# Saved checkpoint at epoch 7380
# Saved checkpoint at epoch 7400
# Saved checkpoint at epoch 7420
# Saved checkpoint at epoch 7440
# Saved checkpoint at epoch 7460
# Saved checkpoint at epoch 7480
# Saved checkpoint at epoch 7500
# Saved checkpoint at epoch 7520
# Saved checkpoint at epoch 7540
# Saved checkpoint at epoch 7560
# Saved checkpoint at epoch 7580
# Saved checkpoint at epoch 7600
# Saved checkpoint at epoch 7620
# Saved checkpoint at epoch 7640
# Saved checkpoint at epoch 7660
# Saved checkpoint at epoch 7680
# Saved checkpoint at epoch 7700
# Saved checkpoint at epoch 7720
# Saved checkpoint at epoch 7740
# Saved checkpoint at epoch 7760
# Saved checkpoint at epoch 7780
# Saved checkpoint at epoch 7800
# Saved checkpoint at epoch 7820
# Saved checkpoint at epoch 7840
# Saved checkpoint at epoch 7860
# Saved checkpoint at epoch 7880
# Saved checkpoint at epoch 7900
# Saved checkpoint at epoch 7920
# Saved checkpoint at epoch 7940
# Saved checkpoint at epoch 7960
# Saved checkpoint at epoch 7980
# Saved checkpoint at epoch 8000
# Saved checkpoint at epoch 8020
# Saved checkpoint at epoch 8040
# Saved checkpoint at epoch 8060
# Saved checkpoint at epoch 8080
# Saved checkpoint at epoch 8100
# Saved checkpoint at epoch 8120
# Saved checkpoint at epoch 8140
# Saved checkpoint at epoch 8160
# Saved checkpoint at epoch 8180
# Saved checkpoint at epoch 8200
# Saved checkpoint at epoch 8220
# Saved checkpoint at epoch 8240
# Saved checkpoint at epoch 8260
# Saved checkpoint at epoch 8280
# Saved checkpoint at epoch 8300
# Saved checkpoint at epoch 8320
# Saved checkpoint at epoch 8340
# Saved checkpoint at epoch 8360
# Saved checkpoint at epoch 8380
# Saved checkpoint at epoch 8400
# Saved checkpoint at epoch 8420
# Saved checkpoint at epoch 8440
# Saved checkpoint at epoch 8460
# Saved checkpoint at epoch 8480
# Saved checkpoint at epoch 8500
# Saved checkpoint at epoch 8520
# Saved checkpoint at epoch 8540
# Saved checkpoint at epoch 8560
# Saved checkpoint at epoch 8580
# Saved checkpoint at epoch 8600
# Saved checkpoint at epoch 8620
# Saved checkpoint at epoch 8640
# Saved checkpoint at epoch 8660
# Saved checkpoint at epoch 8680
# Saved checkpoint at epoch 8700
# Saved checkpoint at epoch 8720
# Saved checkpoint at epoch 8740
# Saved checkpoint at epoch 8760
# Saved checkpoint at epoch 8780
# Saved checkpoint at epoch 8800
# Saved checkpoint at epoch 8820
# Saved checkpoint at epoch 8840
# Saved checkpoint at epoch 8860
# Saved checkpoint at epoch 8880
# Saved checkpoint at epoch 8900
# Saved checkpoint at epoch 8920
# Saved checkpoint at epoch 8940
# Saved checkpoint at epoch 8960
# Saved checkpoint at epoch 8980
# Saved checkpoint at epoch 9000
# Saved checkpoint at epoch 9020
# Saved checkpoint at epoch 9040
# Saved checkpoint at epoch 9060
# Saved checkpoint at epoch 9080
# Saved checkpoint at epoch 9100
# Saved checkpoint at epoch 9120
# Saved checkpoint at epoch 9140
# Saved checkpoint at epoch 9160
# Saved checkpoint at epoch 9180
# Saved checkpoint at epoch 9200
# Saved checkpoint at epoch 9220
# Saved checkpoint at epoch 9240
# Saved checkpoint at epoch 9260
# Saved checkpoint at epoch 9280
# Saved checkpoint at epoch 9300
# Saved checkpoint at epoch 9320
# Saved checkpoint at epoch 9340
# Saved checkpoint at epoch 9360
# Saved checkpoint at epoch 9380
# Saved checkpoint at epoch 9400
# Saved checkpoint at epoch 9420
# Saved checkpoint at epoch 9440
# Saved checkpoint at epoch 9460
# Saved checkpoint at epoch 9480
# Saved checkpoint at epoch 9500
# Saved checkpoint at epoch 9520
# Saved checkpoint at epoch 9540
# Saved checkpoint at epoch 9560
# Saved checkpoint at epoch 9580
# Saved checkpoint at epoch 9600
# Saved checkpoint at epoch 9620
# Saved checkpoint at epoch 9640
# Saved checkpoint at epoch 9660
# Saved checkpoint at epoch 9680
# Saved checkpoint at epoch 9700
# Saved checkpoint at epoch 9720
# Saved checkpoint at epoch 9740
# Saved checkpoint at epoch 9760
# Saved checkpoint at epoch 9780
# Saved checkpoint at epoch 9800
# Saved checkpoint at epoch 9820
# Saved checkpoint at epoch 9840
# Saved checkpoint at epoch 9860
# Saved checkpoint at epoch 9880
# Saved checkpoint at epoch 9900
# Saved checkpoint at epoch 9920
# Saved checkpoint at epoch 9940
# Saved checkpoint at epoch 9960
# Saved checkpoint at epoch 9980
# Saved checkpoint at epoch 10000
# Saved checkpoint at epoch 10020
# Saved checkpoint at epoch 10040
# Saved checkpoint at epoch 10060
# Saved checkpoint at epoch 10080
# Saved checkpoint at epoch 10100
# Saved checkpoint at epoch 10120
# Saved checkpoint at epoch 10140
# Saved checkpoint at epoch 10160
# Saved checkpoint at epoch 10180
# Saved checkpoint at epoch 10200
# Saved checkpoint at epoch 10220
# Saved checkpoint at epoch 10240
# Saved checkpoint at epoch 10260
# Saved checkpoint at epoch 10280
# Saved checkpoint at epoch 10300
# Saved checkpoint at epoch 10320
# Saved checkpoint at epoch 10340
# Saved checkpoint at epoch 10360
# Saved checkpoint at epoch 10380
# Saved checkpoint at epoch 10400
# Saved checkpoint at epoch 10420
# Saved checkpoint at epoch 10440
# Saved checkpoint at epoch 10460
# Saved checkpoint at epoch 10480
# Saved checkpoint at epoch 10500
# Saved checkpoint at epoch 10520
# Saved checkpoint at epoch 10540
# Saved checkpoint at epoch 10560
# Saved checkpoint at epoch 10580
# Saved checkpoint at epoch 10600
# Saved checkpoint at epoch 10620
# Saved checkpoint at epoch 10640
# Saved checkpoint at epoch 10660
# Saved checkpoint at epoch 10680
# Saved checkpoint at epoch 10700
# Saved checkpoint at epoch 10720
# Saved checkpoint at epoch 10740
# Saved checkpoint at epoch 10760
# Saved checkpoint at epoch 10780
# Saved checkpoint at epoch 10800
# Saved checkpoint at epoch 10820
# Saved checkpoint at epoch 10840
# Saved checkpoint at epoch 10860
# Saved checkpoint at epoch 10880
# Saved checkpoint at epoch 10900
# Saved checkpoint at epoch 10920
# Saved checkpoint at epoch 10940
# Saved checkpoint at epoch 10960
# Saved checkpoint at epoch 10980
# Saved checkpoint at epoch 11000
# Saved checkpoint at epoch 11020
# Saved checkpoint at epoch 11040
# Saved checkpoint at epoch 11060
# Saved checkpoint at epoch 11080
# Saved checkpoint at epoch 11100
# Saved checkpoint at epoch 11120
# Saved checkpoint at epoch 11140
# Saved checkpoint at epoch 11160
# Saved checkpoint at epoch 11180
# Saved checkpoint at epoch 11200
# Saved checkpoint at epoch 11220
# Saved checkpoint at epoch 11240
# Saved checkpoint at epoch 11260
# Saved checkpoint at epoch 11280
# Saved checkpoint at epoch 11300
# Saved checkpoint at epoch 11320
# Saved checkpoint at epoch 11340
# Saved checkpoint at epoch 11360
# Saved checkpoint at epoch 11380
# Saved checkpoint at epoch 11400
# Saved checkpoint at epoch 11420
# Saved checkpoint at epoch 11440
# Saved checkpoint at epoch 11460
# Saved checkpoint at epoch 11480
# Saved checkpoint at epoch 11500
# Saved checkpoint at epoch 11520
# Saved checkpoint at epoch 11540
# Saved checkpoint at epoch 11560
# Saved checkpoint at epoch 11580
# Saved checkpoint at epoch 11600
# Saved checkpoint at epoch 11620
# Saved checkpoint at epoch 11640
# Saved checkpoint at epoch 11660
# Saved checkpoint at epoch 11680
# Saved checkpoint at epoch 11700
# Saved checkpoint at epoch 11720
# Saved checkpoint at epoch 11740
# Saved checkpoint at epoch 11760
# Saved checkpoint at epoch 11780
# Saved checkpoint at epoch 11800
# Saved checkpoint at epoch 11820
# Saved checkpoint at epoch 11840
# Saved checkpoint at epoch 11860
# Saved checkpoint at epoch 11880
# Saved checkpoint at epoch 11900
# Saved checkpoint at epoch 11920
# Saved checkpoint at epoch 11940
# Saved checkpoint at epoch 11960
# Saved checkpoint at epoch 11980
# Saved checkpoint at epoch 12000
# Saved checkpoint at epoch 12020
# Saved checkpoint at epoch 12040
# Saved checkpoint at epoch 12060
# Saved checkpoint at epoch 12080
# Saved checkpoint at epoch 12100
# Saved checkpoint at epoch 12120
# Saved checkpoint at epoch 12140
# Saved checkpoint at epoch 12160
# Saved checkpoint at epoch 12180
# Saved checkpoint at epoch 12200
# Saved checkpoint at epoch 12220
# Saved checkpoint at epoch 12240
# Saved checkpoint at epoch 12260
# Saved checkpoint at epoch 12280
# Saved checkpoint at epoch 12300
# Saved checkpoint at epoch 12320
# Saved checkpoint at epoch 12340
# Saved checkpoint at epoch 12360
# Saved checkpoint at epoch 12380
# Saved checkpoint at epoch 12400
# Saved checkpoint at epoch 12420
# Saved checkpoint at epoch 12440
# Saved checkpoint at epoch 12460
# Saved checkpoint at epoch 12480
# Saved checkpoint at epoch 12500
# Saved checkpoint at epoch 12520
# Saved checkpoint at epoch 12540
# Saved checkpoint at epoch 12560
# Saved checkpoint at epoch 12580
# Saved checkpoint at epoch 12600
# Saved checkpoint at epoch 12620
# Saved checkpoint at epoch 12640
# Saved checkpoint at epoch 12660
# Saved checkpoint at epoch 12680
# Saved checkpoint at epoch 12700
# Saved checkpoint at epoch 12720
# Saved checkpoint at epoch 12740
# Saved checkpoint at epoch 12760
# Saved checkpoint at epoch 12780
# Saved checkpoint at epoch 12800
# Saved checkpoint at epoch 12820
# Saved checkpoint at epoch 12840
# Saved checkpoint at epoch 12860
# Saved checkpoint at epoch 12880
# Saved checkpoint at epoch 12900
# Saved checkpoint at epoch 12920
# Saved checkpoint at epoch 12940
# Saved checkpoint at epoch 12960
# Saved checkpoint at epoch 12980
# Saved checkpoint at epoch 13000
# Saved checkpoint at epoch 13020
# Saved checkpoint at epoch 13040
# Saved checkpoint at epoch 13060
# Saved checkpoint at epoch 13080
# Saved checkpoint at epoch 13100
# Saved checkpoint at epoch 13120
# Saved checkpoint at epoch 13140
# Saved checkpoint at epoch 13160
# Saved checkpoint at epoch 13180
# Saved checkpoint at epoch 13200
# Saved checkpoint at epoch 13220
# Saved checkpoint at epoch 13240
# Saved checkpoint at epoch 13260
# Saved checkpoint at epoch 13280
# Saved checkpoint at epoch 13300
# Saved checkpoint at epoch 13320
# Saved checkpoint at epoch 13340
# Saved checkpoint at epoch 13360
# Saved checkpoint at epoch 13380
# Saved checkpoint at epoch 13400
# Saved checkpoint at epoch 13420
# Saved checkpoint at epoch 13440
# Saved checkpoint at epoch 13460
# Saved checkpoint at epoch 13480
# Saved checkpoint at epoch 13500
# Saved checkpoint at epoch 13520
# Saved checkpoint at epoch 13540
# Saved checkpoint at epoch 13560
# Saved checkpoint at epoch 13580
# Saved checkpoint at epoch 13600
# Saved checkpoint at epoch 13620
# Saved checkpoint at epoch 13640
# Saved checkpoint at epoch 13660
# Saved checkpoint at epoch 13680
# Saved checkpoint at epoch 13700
# Saved checkpoint at epoch 13720
# Saved checkpoint at epoch 13740
# Saved checkpoint at epoch 13760
# Saved checkpoint at epoch 13780
# Saved checkpoint at epoch 13800
# Saved checkpoint at epoch 13820
# Saved checkpoint at epoch 13840
# Saved checkpoint at epoch 13860
# Saved checkpoint at epoch 13880
# Saved checkpoint at epoch 13900
# Saved checkpoint at epoch 13920
# Saved checkpoint at epoch 13940
# Saved checkpoint at epoch 13960
# Saved checkpoint at epoch 13980
# Saved checkpoint at epoch 14000
# Saved checkpoint at epoch 14020
# Saved checkpoint at epoch 14040
# Saved checkpoint at epoch 14060
# Saved checkpoint at epoch 14080
# Saved checkpoint at epoch 14100
# Saved checkpoint at epoch 14120
# Saved checkpoint at epoch 14140
# Saved checkpoint at epoch 14160
# Saved checkpoint at epoch 14180
# Saved checkpoint at epoch 14200
# Saved checkpoint at epoch 14220
# Saved checkpoint at epoch 14240
# Saved checkpoint at epoch 14260
# Saved checkpoint at epoch 14280
# Saved checkpoint at epoch 14300
# Saved checkpoint at epoch 14320
# Saved checkpoint at epoch 14340
# Saved checkpoint at epoch 14360
# Saved checkpoint at epoch 14380
# Saved checkpoint at epoch 14400
# Saved checkpoint at epoch 14420
# Saved checkpoint at epoch 14440
# Saved checkpoint at epoch 14460
# Saved checkpoint at epoch 14480
# Saved checkpoint at epoch 14500
# Saved checkpoint at epoch 14520
# Saved checkpoint at epoch 14540
# Saved checkpoint at epoch 14560
# Saved checkpoint at epoch 14580
# Saved checkpoint at epoch 14600
# Saved checkpoint at epoch 14620
# Saved checkpoint at epoch 14640
# Saved checkpoint at epoch 14660
# Saved checkpoint at epoch 14680
# Saved checkpoint at epoch 14700
# Saved checkpoint at epoch 14720
# Saved checkpoint at epoch 14740
# Saved checkpoint at epoch 14760
# Saved checkpoint at epoch 14780
# Saved checkpoint at epoch 14800
# Saved checkpoint at epoch 14820
# Saved checkpoint at epoch 14840
# Saved checkpoint at epoch 14860
# Saved checkpoint at epoch 14880
# Saved checkpoint at epoch 14900
# Saved checkpoint at epoch 14920
# Saved checkpoint at epoch 14940
# Saved checkpoint at epoch 14960
# Saved checkpoint at epoch 14980
# Saved checkpoint at epoch 15000
# Saved checkpoint at epoch 15020
# Saved checkpoint at epoch 15040
# Saved checkpoint at epoch 15060
# Saved checkpoint at epoch 15080
# Saved checkpoint at epoch 15100
# Saved checkpoint at epoch 15120
# Saved checkpoint at epoch 15140
# Saved checkpoint at epoch 15160
# Saved checkpoint at epoch 15180
# Saved checkpoint at epoch 15200
# Saved checkpoint at epoch 15220
# Saved checkpoint at epoch 15240
# Saved checkpoint at epoch 15260
# Saved checkpoint at epoch 15280
# Saved checkpoint at epoch 15300
# Saved checkpoint at epoch 15320
# Saved checkpoint at epoch 15340
# Saved checkpoint at epoch 15360
# Saved checkpoint at epoch 15380
# Saved checkpoint at epoch 15400
# Saved checkpoint at epoch 15420
# Saved checkpoint at epoch 15440
# Saved checkpoint at epoch 15460
# Saved checkpoint at epoch 15480
# Saved checkpoint at epoch 15500
# Saved checkpoint at epoch 15520
# Saved checkpoint at epoch 15540
# Saved checkpoint at epoch 15560
# Saved checkpoint at epoch 15580
# Saved checkpoint at epoch 15600
# Saved checkpoint at epoch 15620
# Saved checkpoint at epoch 15640
# Saved checkpoint at epoch 15660
# Saved checkpoint at epoch 15680
# Saved checkpoint at epoch 15700
# Saved checkpoint at epoch 15720
# Saved checkpoint at epoch 15740
# Saved checkpoint at epoch 15760
# Saved checkpoint at epoch 15780
# Saved checkpoint at epoch 15800
# Saved checkpoint at epoch 15820
# Saved checkpoint at epoch 15840
# Saved checkpoint at epoch 15860
# Saved checkpoint at epoch 15880
# Saved checkpoint at epoch 15900
# Saved checkpoint at epoch 15920
# Saved checkpoint at epoch 15940
# Saved checkpoint at epoch 15960
# Saved checkpoint at epoch 15980
# Saved checkpoint at epoch 16000
# Saved checkpoint at epoch 16020
# Saved checkpoint at epoch 16040
# Saved checkpoint at epoch 16060
# Saved checkpoint at epoch 16080
# Saved checkpoint at epoch 16100
# Saved checkpoint at epoch 16120
# Saved checkpoint at epoch 16140
# Saved checkpoint at epoch 16160
# Saved checkpoint at epoch 16180
# Saved checkpoint at epoch 16200
# Saved checkpoint at epoch 16220
# Saved checkpoint at epoch 16240
# Saved checkpoint at epoch 16260
# Saved checkpoint at epoch 16280
# Saved checkpoint at epoch 16300
# Saved checkpoint at epoch 16320
# Saved checkpoint at epoch 16340
# Saved checkpoint at epoch 16360
# Saved checkpoint at epoch 16380
# Saved checkpoint at epoch 16400
# Saved checkpoint at epoch 16420
# Saved checkpoint at epoch 16440
# Saved checkpoint at epoch 16460
# Saved checkpoint at epoch 16480
# Saved checkpoint at epoch 16500
# Saved checkpoint at epoch 16520
# Saved checkpoint at epoch 16540
# Saved checkpoint at epoch 16560
# Saved checkpoint at epoch 16580
# Saved checkpoint at epoch 16600
# Saved checkpoint at epoch 16620
# Saved checkpoint at epoch 16640
# Saved checkpoint at epoch 16660
# Saved checkpoint at epoch 16680
# Saved checkpoint at epoch 16700
# Saved checkpoint at epoch 16720
# Saved checkpoint at epoch 16740
# Saved checkpoint at epoch 16760
# Saved checkpoint at epoch 16780
# Saved checkpoint at epoch 16800
# Saved checkpoint at epoch 16820
# Saved checkpoint at epoch 16840
# Saved checkpoint at epoch 16860
# Saved checkpoint at epoch 16880
# Saved checkpoint at epoch 16900
# Saved checkpoint at epoch 16920
# Saved checkpoint at epoch 16940
# Saved checkpoint at epoch 16960
# Saved checkpoint at epoch 16980
# Saved checkpoint at epoch 17000
# Saved checkpoint at epoch 17020
# Saved checkpoint at epoch 17040
# Saved checkpoint at epoch 17060
# Saved checkpoint at epoch 17080
# Saved checkpoint at epoch 17100
# Saved checkpoint at epoch 17120
# Saved checkpoint at epoch 17140
# Saved checkpoint at epoch 17160
# Saved checkpoint at epoch 17180
# Saved checkpoint at epoch 17200
# Saved checkpoint at epoch 17220
# Saved checkpoint at epoch 17240
# Saved checkpoint at epoch 17260
# Saved checkpoint at epoch 17280
# Saved checkpoint at epoch 17300
# Saved checkpoint at epoch 17320
# Saved checkpoint at epoch 17340
# Saved checkpoint at epoch 17360
# Saved checkpoint at epoch 17380
# Saved checkpoint at epoch 17400
# Saved checkpoint at epoch 17420
# Saved checkpoint at epoch 17440
# Saved checkpoint at epoch 17460
# Saved checkpoint at epoch 17480
# Saved checkpoint at epoch 17500
# Saved checkpoint at epoch 17520
# Saved checkpoint at epoch 17540
# Saved checkpoint at epoch 17560
# Saved checkpoint at epoch 17580
# Saved checkpoint at epoch 17600
# Saved checkpoint at epoch 17620
# Saved checkpoint at epoch 17640
# Saved checkpoint at epoch 17660
# Saved checkpoint at epoch 17680
# Saved checkpoint at epoch 17700
# Saved checkpoint at epoch 17720
# Saved checkpoint at epoch 17740
# Saved checkpoint at epoch 17760
# Saved checkpoint at epoch 17780
# Saved checkpoint at epoch 17800
# Saved checkpoint at epoch 17820
# Saved checkpoint at epoch 17840
# Saved checkpoint at epoch 17860
# Saved checkpoint at epoch 17880
# Saved checkpoint at epoch 17900
# Saved checkpoint at epoch 17920
# Saved checkpoint at epoch 17940
# Saved checkpoint at epoch 17960
# Saved checkpoint at epoch 17980
# Saved checkpoint at epoch 18000
# Saved checkpoint at epoch 18020
# Saved checkpoint at epoch 18040
# Saved checkpoint at epoch 18060
# Saved checkpoint at epoch 18080
# Saved checkpoint at epoch 18100
# Saved checkpoint at epoch 18120
# Saved checkpoint at epoch 18140
# Saved checkpoint at epoch 18160
# Saved checkpoint at epoch 18180
# Saved checkpoint at epoch 18200
# Saved checkpoint at epoch 18220
# Saved checkpoint at epoch 18240
# Saved checkpoint at epoch 18260
# Saved checkpoint at epoch 18280
# Saved checkpoint at epoch 18300
# Saved checkpoint at epoch 18320
# Saved checkpoint at epoch 18340
# Saved checkpoint at epoch 18360
# Saved checkpoint at epoch 18380
# Saved checkpoint at epoch 18400
# Saved checkpoint at epoch 18420
# Saved checkpoint at epoch 18440
# Saved checkpoint at epoch 18460
# Saved checkpoint at epoch 18480
# Saved checkpoint at epoch 18500
# Saved checkpoint at epoch 18520
# Saved checkpoint at epoch 18540
# Saved checkpoint at epoch 18560
# Saved checkpoint at epoch 18580
# Saved checkpoint at epoch 18600
# Saved checkpoint at epoch 18620
# Saved checkpoint at epoch 18640
# Saved checkpoint at epoch 18660
# Saved checkpoint at epoch 18680
# Saved checkpoint at epoch 18700
# Saved checkpoint at epoch 18720
# Saved checkpoint at epoch 18740
# Saved checkpoint at epoch 18760
# Saved checkpoint at epoch 18780
# Saved checkpoint at epoch 18800
# Saved checkpoint at epoch 18820
# Saved checkpoint at epoch 18840
# Saved checkpoint at epoch 18860
# Saved checkpoint at epoch 18880
# Saved checkpoint at epoch 18900
# Saved checkpoint at epoch 18920
# Saved checkpoint at epoch 18940
# Saved checkpoint at epoch 18960
# Saved checkpoint at epoch 18980
# Saved checkpoint at epoch 19000
# Saved checkpoint at epoch 19020
# Saved checkpoint at epoch 19040
# Saved checkpoint at epoch 19060
# Saved checkpoint at epoch 19080
# Saved checkpoint at epoch 19100
# Saved checkpoint at epoch 19120
# Saved checkpoint at epoch 19140
# Saved checkpoint at epoch 19160
# Saved checkpoint at epoch 19180
# Saved checkpoint at epoch 19200
# Saved checkpoint at epoch 19220
# Saved checkpoint at epoch 19240
# Saved checkpoint at epoch 19260
# Saved checkpoint at epoch 19280
# Saved checkpoint at epoch 19300
# Saved checkpoint at epoch 19320
# Saved checkpoint at epoch 19340
# Saved checkpoint at epoch 19360
# Saved checkpoint at epoch 19380
# Saved checkpoint at epoch 19400
# Saved checkpoint at epoch 19420
# Saved checkpoint at epoch 19440
# Saved checkpoint at epoch 19460
# Saved checkpoint at epoch 19480
# Saved checkpoint at epoch 19500
# Saved checkpoint at epoch 19520
# Saved checkpoint at epoch 19540
# Saved checkpoint at epoch 19560
# Saved checkpoint at epoch 19580
# Saved checkpoint at epoch 19600
# Saved checkpoint at epoch 19620
# Saved checkpoint at epoch 19640
# Saved checkpoint at epoch 19660
# Saved checkpoint at epoch 19680
# Saved checkpoint at epoch 19700
# Saved checkpoint at epoch 19720
# Saved checkpoint at epoch 19740
# Saved checkpoint at epoch 19760
# Saved checkpoint at epoch 19780
# Saved checkpoint at epoch 19800
# Saved checkpoint at epoch 19820
# Saved checkpoint at epoch 19840
# Saved checkpoint at epoch 19860
# Saved checkpoint at epoch 19880
# Saved checkpoint at epoch 19900
# Saved checkpoint at epoch 19920
# Saved checkpoint at epoch 19940
# Saved checkpoint at epoch 19960
# Saved checkpoint at epoch 19980
# Saved checkpoint at epoch 20000
# Saved checkpoint at epoch 20020
# Saved checkpoint at epoch 20040
# Saved checkpoint at epoch 20060
# Saved checkpoint at epoch 20080
# Saved checkpoint at epoch 20100
# Saved checkpoint at epoch 20120
# Saved checkpoint at epoch 20140
# Saved checkpoint at epoch 20160
# Saved checkpoint at epoch 20180
# Saved checkpoint at epoch 20200
# Saved checkpoint at epoch 20220
# Saved checkpoint at epoch 20240
# Saved checkpoint at epoch 20260
# Saved checkpoint at epoch 20280
# Saved checkpoint at epoch 20300
# Saved checkpoint at epoch 20320
# Saved checkpoint at epoch 20340
# Saved checkpoint at epoch 20360
# Saved checkpoint at epoch 20380
# Saved checkpoint at epoch 20400
# Saved checkpoint at epoch 20420
# Saved checkpoint at epoch 20440
# Saved checkpoint at epoch 20460
# Saved checkpoint at epoch 20480
# Saved checkpoint at epoch 20500
# Saved checkpoint at epoch 20520
# Saved checkpoint at epoch 20540
# Saved checkpoint at epoch 20560
# Saved checkpoint at epoch 20580
# Saved checkpoint at epoch 20600
# Saved checkpoint at epoch 20620
# Saved checkpoint at epoch 20640
# Saved checkpoint at epoch 20660
# Saved checkpoint at epoch 20680
# Saved checkpoint at epoch 20700
# Saved checkpoint at epoch 20720
# Saved checkpoint at epoch 20740
# Saved checkpoint at epoch 20760
# Saved checkpoint at epoch 20780
# Saved checkpoint at epoch 20800
# Saved checkpoint at epoch 20820
# Saved checkpoint at epoch 20840
# Saved checkpoint at epoch 20860
# Saved checkpoint at epoch 20880
# Saved checkpoint at epoch 20900
# Saved checkpoint at epoch 20920
# Saved checkpoint at epoch 20940
# Saved checkpoint at epoch 20960
# Saved checkpoint at epoch 20980
# Saved checkpoint at epoch 21000
# Saved checkpoint at epoch 21020
# Saved checkpoint at epoch 21040
# Saved checkpoint at epoch 21060
# Saved checkpoint at epoch 21080
# Saved checkpoint at epoch 21100
# Saved checkpoint at epoch 21120
# Saved checkpoint at epoch 21140
# Saved checkpoint at epoch 21160
# Saved checkpoint at epoch 21180
# Saved checkpoint at epoch 21200
# Saved checkpoint at epoch 21220
# Saved checkpoint at epoch 21240
# Saved checkpoint at epoch 21260
# Saved checkpoint at epoch 21280
# Saved checkpoint at epoch 21300
# Saved checkpoint at epoch 21320
# Saved checkpoint at epoch 21340
# Saved checkpoint at epoch 21360
# Saved checkpoint at epoch 21380
# Saved checkpoint at epoch 21400
# Saved checkpoint at epoch 21420
# Saved checkpoint at epoch 21440
# Saved checkpoint at epoch 21460
# Saved checkpoint at epoch 21480
# Saved checkpoint at epoch 21500
# Saved checkpoint at epoch 21520
# Saved checkpoint at epoch 21540
# Saved checkpoint at epoch 21560
# Saved checkpoint at epoch 21580
# Saved checkpoint at epoch 21600
# Saved checkpoint at epoch 21620
# Saved checkpoint at epoch 21640
# Saved checkpoint at epoch 21660
# Saved checkpoint at epoch 21680
# Saved checkpoint at epoch 21700
# Saved checkpoint at epoch 21720
# Saved checkpoint at epoch 21740
# Saved checkpoint at epoch 21760
# Saved checkpoint at epoch 21780
# Saved checkpoint at epoch 21800
# Saved checkpoint at epoch 21820
# Saved checkpoint at epoch 21840
# Saved checkpoint at epoch 21860
# Saved checkpoint at epoch 21880
# Saved checkpoint at epoch 21900
# Saved checkpoint at epoch 21920
# Saved checkpoint at epoch 21940
# Saved checkpoint at epoch 21960
# Saved checkpoint at epoch 21980
# Saved checkpoint at epoch 22000
# Saved checkpoint at epoch 22020
# Saved checkpoint at epoch 22040
# Saved checkpoint at epoch 22060
# Saved checkpoint at epoch 22080
# Saved checkpoint at epoch 22100
# Saved checkpoint at epoch 22120
# Saved checkpoint at epoch 22140
# Saved checkpoint at epoch 22160
# Saved checkpoint at epoch 22180
# Saved checkpoint at epoch 22200
# Saved checkpoint at epoch 22220
# Saved checkpoint at epoch 22240
# Saved checkpoint at epoch 22260
# Saved checkpoint at epoch 22280
# Saved checkpoint at epoch 22300
# Saved checkpoint at epoch 22320
# Saved checkpoint at epoch 22340
# Saved checkpoint at epoch 22360
# Saved checkpoint at epoch 22380
# Saved checkpoint at epoch 22400
# Saved checkpoint at epoch 22420
# Saved checkpoint at epoch 22440
# Saved checkpoint at epoch 22460
# Saved checkpoint at epoch 22480
# Saved checkpoint at epoch 22500
# Saved checkpoint at epoch 22520
# Saved checkpoint at epoch 22540
# Saved checkpoint at epoch 22560
# Saved checkpoint at epoch 22580
# Saved checkpoint at epoch 22600
# Saved checkpoint at epoch 22620
# Saved checkpoint at epoch 22640
# Saved checkpoint at epoch 22660
# Saved checkpoint at epoch 22680
# Saved checkpoint at epoch 22700
# Saved checkpoint at epoch 22720
# Saved checkpoint at epoch 22740
# Saved checkpoint at epoch 22760
# Saved checkpoint at epoch 22780
# Saved checkpoint at epoch 22800
# Saved checkpoint at epoch 22820
# Saved checkpoint at epoch 22840
# Saved checkpoint at epoch 22860
# Saved checkpoint at epoch 22880
# Saved checkpoint at epoch 22900
# Saved checkpoint at epoch 22920
# Saved checkpoint at epoch 22940
# Saved checkpoint at epoch 22960
# Saved checkpoint at epoch 22980
# Saved checkpoint at epoch 23000
# Saved checkpoint at epoch 23020
# Saved checkpoint at epoch 23040
# Saved checkpoint at epoch 23060
# Saved checkpoint at epoch 23080
# Saved checkpoint at epoch 23100
# Saved checkpoint at epoch 23120
# Saved checkpoint at epoch 23140
# Saved checkpoint at epoch 23160
# Saved checkpoint at epoch 23180
# Saved checkpoint at epoch 23200
# Saved checkpoint at epoch 23220
# Saved checkpoint at epoch 23240
# Saved checkpoint at epoch 23260
# Saved checkpoint at epoch 23280
# Saved checkpoint at epoch 23300
# Saved checkpoint at epoch 23320
# Saved checkpoint at epoch 23340
# Saved checkpoint at epoch 23360
# Saved checkpoint at epoch 23380
# Saved checkpoint at epoch 23400
# Saved checkpoint at epoch 23420
# Saved checkpoint at epoch 23440
# Saved checkpoint at epoch 23460
# Saved checkpoint at epoch 23480
# Saved checkpoint at epoch 23500
# Saved checkpoint at epoch 23520
# Saved checkpoint at epoch 23540
# Saved checkpoint at epoch 23560
# Saved checkpoint at epoch 23580
# Saved checkpoint at epoch 23600
# Saved checkpoint at epoch 23620
# Saved checkpoint at epoch 23640
# Saved checkpoint at epoch 23660
# Saved checkpoint at epoch 23680
# Saved checkpoint at epoch 23700
# Saved checkpoint at epoch 23720
# Saved checkpoint at epoch 23740
# Saved checkpoint at epoch 23760
# Saved checkpoint at epoch 23780
# Saved checkpoint at epoch 23800
# Saved checkpoint at epoch 23820
# Saved checkpoint at epoch 23840
# Saved checkpoint at epoch 23860
# Saved checkpoint at epoch 23880
# Saved checkpoint at epoch 23900
# Saved checkpoint at epoch 23920
# Saved checkpoint at epoch 23940
# Saved checkpoint at epoch 23960
# Saved checkpoint at epoch 23980
# Saved checkpoint at epoch 24000
# Saved checkpoint at epoch 24020
# Saved checkpoint at epoch 24040
# Saved checkpoint at epoch 24060
# Saved checkpoint at epoch 24080
# Saved checkpoint at epoch 24100
# Saved checkpoint at epoch 24120
# Saved checkpoint at epoch 24140
# Saved checkpoint at epoch 24160
# Saved checkpoint at epoch 24180
# Saved checkpoint at epoch 24200
# Saved checkpoint at epoch 24220
# Saved checkpoint at epoch 24240
# Saved checkpoint at epoch 24260
# Saved checkpoint at epoch 24280
# Saved checkpoint at epoch 24300
# Saved checkpoint at epoch 24320
# Saved checkpoint at epoch 24340
# Saved checkpoint at epoch 24360
# Saved checkpoint at epoch 24380
# Saved checkpoint at epoch 24400
# Saved checkpoint at epoch 24420
# Saved checkpoint at epoch 24440
# Saved checkpoint at epoch 24460
# Saved checkpoint at epoch 24480
# Saved checkpoint at epoch 24500
# Saved checkpoint at epoch 24520
# Saved checkpoint at epoch 24540
# Saved checkpoint at epoch 24560
# Saved checkpoint at epoch 24580
# Saved checkpoint at epoch 24600
# Saved checkpoint at epoch 24620
# Saved checkpoint at epoch 24640
# Saved checkpoint at epoch 24660
# Saved checkpoint at epoch 24680
# Saved checkpoint at epoch 24700
# Saved checkpoint at epoch 24720
# Saved checkpoint at epoch 24740
# Saved checkpoint at epoch 24760
# Saved checkpoint at epoch 24780
# Saved checkpoint at epoch 24800
# Saved checkpoint at epoch 24820
# Saved checkpoint at epoch 24840
# Saved checkpoint at epoch 24860
# Saved checkpoint at epoch 24880
# Saved checkpoint at epoch 24900
# Saved checkpoint at epoch 24920
# Saved checkpoint at epoch 24940
# Saved checkpoint at epoch 24960
# Saved checkpoint at epoch 24980
# Saved checkpoint at epoch 25000
# Saved checkpoint at epoch 25020
# Saved checkpoint at epoch 25040
# Saved checkpoint at epoch 25060
# Saved checkpoint at epoch 25080
# Saved checkpoint at epoch 25100
# Saved checkpoint at epoch 25120
# Saved checkpoint at epoch 25140
# Saved checkpoint at epoch 25160
# Saved checkpoint at epoch 25180
# Saved checkpoint at epoch 25200
# Saved checkpoint at epoch 25220
# Saved checkpoint at epoch 25240
# Saved checkpoint at epoch 25260
# Saved checkpoint at epoch 25280
# Saved checkpoint at epoch 25300
# Saved checkpoint at epoch 25320
# Saved checkpoint at epoch 25340
# Saved checkpoint at epoch 25360
# Saved checkpoint at epoch 25380
# Saved checkpoint at epoch 25400
# Saved checkpoint at epoch 25420
# Saved checkpoint at epoch 25440
# Saved checkpoint at epoch 25460
# Saved checkpoint at epoch 25480
# Saved checkpoint at epoch 25500
# Saved checkpoint at epoch 25520
# Saved checkpoint at epoch 25540
# Saved checkpoint at epoch 25560
# Saved checkpoint at epoch 25580
# Saved checkpoint at epoch 25600
# Saved checkpoint at epoch 25620
# Saved checkpoint at epoch 25640
# Saved checkpoint at epoch 25660
# Saved checkpoint at epoch 25680
# Saved checkpoint at epoch 25700
# Saved checkpoint at epoch 25720
# Saved checkpoint at epoch 25740
# Saved checkpoint at epoch 25760
# Saved checkpoint at epoch 25780
# Saved checkpoint at epoch 25800
# Saved checkpoint at epoch 25820
# Saved checkpoint at epoch 25840
# Saved checkpoint at epoch 25860
# Saved checkpoint at epoch 25880
# Saved checkpoint at epoch 25900
# Saved checkpoint at epoch 25920
# Saved checkpoint at epoch 25940
# Saved checkpoint at epoch 25960
# Saved checkpoint at epoch 25980
# Saved checkpoint at epoch 26000
# Saved checkpoint at epoch 26020
# Saved checkpoint at epoch 26040
# Saved checkpoint at epoch 26060
# Saved checkpoint at epoch 26080
# Saved checkpoint at epoch 26100
# Saved checkpoint at epoch 26120
# Saved checkpoint at epoch 26140
# Saved checkpoint at epoch 26160
# Saved checkpoint at epoch 26180
# Saved checkpoint at epoch 26200
# Saved checkpoint at epoch 26220
# Saved checkpoint at epoch 26240
# Saved checkpoint at epoch 26260
# Saved checkpoint at epoch 26280
# Saved checkpoint at epoch 26300
# Saved checkpoint at epoch 26320
# Saved checkpoint at epoch 26340
# Saved checkpoint at epoch 26360
# Saved checkpoint at epoch 26380
# Saved checkpoint at epoch 26400
# Saved checkpoint at epoch 26420
# Saved checkpoint at epoch 26440
# Saved checkpoint at epoch 26460
# Saved checkpoint at epoch 26480
# Saved checkpoint at epoch 26500
# Saved checkpoint at epoch 26520
# Saved checkpoint at epoch 26540
# Saved checkpoint at epoch 26560
# Saved checkpoint at epoch 26580
# Saved checkpoint at epoch 26600
# Saved checkpoint at epoch 26620
# Saved checkpoint at epoch 26640
# Saved checkpoint at epoch 26660
# Saved checkpoint at epoch 26680
# Saved checkpoint at epoch 26700
# Saved checkpoint at epoch 26720
# Saved checkpoint at epoch 26740
# Saved checkpoint at epoch 26760
# Saved checkpoint at epoch 26780
# Saved checkpoint at epoch 26800
# Saved checkpoint at epoch 26820
# Saved checkpoint at epoch 26840
# Saved checkpoint at epoch 26860
# Saved checkpoint at epoch 26880
# Saved checkpoint at epoch 26900
# Saved checkpoint at epoch 26920
# Saved checkpoint at epoch 26940
# Saved checkpoint at epoch 26960
# Saved checkpoint at epoch 26980
# Saved checkpoint at epoch 27000
# Saved checkpoint at epoch 27020
# Saved checkpoint at epoch 27040
# Saved checkpoint at epoch 27060
# Saved checkpoint at epoch 27080
# Saved checkpoint at epoch 27100
# Saved checkpoint at epoch 27120
# Saved checkpoint at epoch 27140
# Saved checkpoint at epoch 27160
# Saved checkpoint at epoch 27180
# Saved checkpoint at epoch 27200
# Saved checkpoint at epoch 27220
# Saved checkpoint at epoch 27240
# Saved checkpoint at epoch 27260
# Saved checkpoint at epoch 27280
# Saved checkpoint at epoch 27300
# Saved checkpoint at epoch 27320
# Saved checkpoint at epoch 27340
# Saved checkpoint at epoch 27360
# Saved checkpoint at epoch 27380
# Saved checkpoint at epoch 27400
# Saved checkpoint at epoch 27420
# Saved checkpoint at epoch 27440
# Saved checkpoint at epoch 27460
# Saved checkpoint at epoch 27480
# Saved checkpoint at epoch 27500
# Saved checkpoint at epoch 27520
# Saved checkpoint at epoch 27540
# Saved checkpoint at epoch 27560
# Saved checkpoint at epoch 27580
# Saved checkpoint at epoch 27600
# Saved checkpoint at epoch 27620
# Saved checkpoint at epoch 27640
# Saved checkpoint at epoch 27660
# Saved checkpoint at epoch 27680
# Saved checkpoint at epoch 27700
# Saved checkpoint at epoch 27720
# Saved checkpoint at epoch 27740
# Saved checkpoint at epoch 27760
# Saved checkpoint at epoch 27780
# Saved checkpoint at epoch 27800
# Saved checkpoint at epoch 27820
# Saved checkpoint at epoch 27840
# Saved checkpoint at epoch 27860
# Saved checkpoint at epoch 27880
# Saved checkpoint at epoch 27900
# Saved checkpoint at epoch 27920
# Saved checkpoint at epoch 27940
# Saved checkpoint at epoch 27960
# Saved checkpoint at epoch 27980
# Saved checkpoint at epoch 28000
# Saved checkpoint at epoch 28020
# Saved checkpoint at epoch 28040
# Saved checkpoint at epoch 28060
# Saved checkpoint at epoch 28080
# Saved checkpoint at epoch 28100
# Saved checkpoint at epoch 28120
# Saved checkpoint at epoch 28140
# Saved checkpoint at epoch 28160
# Saved checkpoint at epoch 28180
# Saved checkpoint at epoch 28200
# Saved checkpoint at epoch 28220
# Saved checkpoint at epoch 28240
# Saved checkpoint at epoch 28260
# Saved checkpoint at epoch 28280
# Saved checkpoint at epoch 28300
# Saved checkpoint at epoch 28320
# Saved checkpoint at epoch 28340
# Saved checkpoint at epoch 28360
# Saved checkpoint at epoch 28380
# Saved checkpoint at epoch 28400
# Saved checkpoint at epoch 28420
# Saved checkpoint at epoch 28440
# Saved checkpoint at epoch 28460
# Saved checkpoint at epoch 28480
# Saved checkpoint at epoch 28500
# Saved checkpoint at epoch 28520
# Saved checkpoint at epoch 28540
# Saved checkpoint at epoch 28560
# Saved checkpoint at epoch 28580
# Saved checkpoint at epoch 28600
# Saved checkpoint at epoch 28620
# Saved checkpoint at epoch 28640
# Saved checkpoint at epoch 28660
# Saved checkpoint at epoch 28680
# Saved checkpoint at epoch 28700
# Saved checkpoint at epoch 28720
# Saved checkpoint at epoch 28740
# Saved checkpoint at epoch 28760
# Saved checkpoint at epoch 28780
# Saved checkpoint at epoch 28800
# Saved checkpoint at epoch 28820
# Saved checkpoint at epoch 28840
# Saved checkpoint at epoch 28860
# Saved checkpoint at epoch 28880
# Saved checkpoint at epoch 28900
# Saved checkpoint at epoch 28920
# Saved checkpoint at epoch 28940
# Saved checkpoint at epoch 28960
# Saved checkpoint at epoch 28980
# Saved checkpoint at epoch 29000
# Saved checkpoint at epoch 29020
# Saved checkpoint at epoch 29040
# Saved checkpoint at epoch 29060
# Saved checkpoint at epoch 29080
# Saved checkpoint at epoch 29100
# Saved checkpoint at epoch 29120
# Saved checkpoint at epoch 29140
# Saved checkpoint at epoch 29160
# Saved checkpoint at epoch 29180
# Saved checkpoint at epoch 29200
# Saved checkpoint at epoch 29220
# Saved checkpoint at epoch 29240
# Saved checkpoint at epoch 29260
# Saved checkpoint at epoch 29280
# Saved checkpoint at epoch 29300
# Saved checkpoint at epoch 29320
# Saved checkpoint at epoch 29340
# Saved checkpoint at epoch 29360
# Saved checkpoint at epoch 29380
# Saved checkpoint at epoch 29400
# Saved checkpoint at epoch 29420
# Saved checkpoint at epoch 29440
# Saved checkpoint at epoch 29460
# Saved checkpoint at epoch 29480
# Saved checkpoint at epoch 29500
# Saved checkpoint at epoch 29520
# Saved checkpoint at epoch 29540
# Saved checkpoint at epoch 29560
# Saved checkpoint at epoch 29580
# Saved checkpoint at epoch 29600
# Saved checkpoint at epoch 29620
# Saved checkpoint at epoch 29640
# Saved checkpoint at epoch 29660
# Saved checkpoint at epoch 29680
# Saved checkpoint at epoch 29700
# Saved checkpoint at epoch 29720
# Saved checkpoint at epoch 29740
# Saved checkpoint at epoch 29760
# Saved checkpoint at epoch 29780
# Saved checkpoint at epoch 29800
# Saved checkpoint at epoch 29820
# Saved checkpoint at epoch 29840
# Saved checkpoint at epoch 29860
# Saved checkpoint at epoch 29880
# Saved checkpoint at epoch 29900
# Saved checkpoint at epoch 29920
# Saved checkpoint at epoch 29940
# Saved checkpoint at epoch 29960
# Saved checkpoint at epoch 29980
# Saved checkpoint at epoch 30000
# Saved checkpoint at epoch 30020
# Saved checkpoint at epoch 30040
# Saved checkpoint at epoch 30060
# Saved checkpoint at epoch 30080
# Saved checkpoint at epoch 30100
# Saved checkpoint at epoch 30120
# Saved checkpoint at epoch 30140
# Saved checkpoint at epoch 30160
# Saved checkpoint at epoch 30180
# Saved checkpoint at epoch 30200
# Saved checkpoint at epoch 30220
# Saved checkpoint at epoch 30240
# Saved checkpoint at epoch 30260
# Saved checkpoint at epoch 30280
# Saved checkpoint at epoch 30300
# Saved checkpoint at epoch 30320
# Saved checkpoint at epoch 30340
# ...
# Saved checkpoint at epoch 90040
# Saved checkpoint at epoch 90060
# Saved checkpoint at epoch 90080
# Saved checkpoint at epoch 90100
# Saved checkpoint at epoch 90120
# Saved checkpoint at epoch 90140
# Saved checkpoint at epoch 90160
# Saved checkpoint at epoch 90180
# Saved checkpoint at epoch 90200
# Saved checkpoint at epoch 90220
# Saved checkpoint at epoch 90240
# Saved checkpoint at epoch 90260
# Saved checkpoint at epoch 90280
# Saved checkpoint at epoch 90300
# Saved checkpoint at epoch 90320
# Saved checkpoint at epoch 90340
# Saved checkpoint at epoch 90360
# Saved checkpoint at epoch 90380
# Saved checkpoint at epoch 90400
# Saved checkpoint at epoch 90420
# Saved checkpoint at epoch 90440
# Saved checkpoint at epoch 90460
# Saved checkpoint at epoch 90480
# Saved checkpoint at epoch 90500
# Saved checkpoint at epoch 90520
# Saved checkpoint at epoch 90540
# Saved checkpoint at epoch 90560
# Saved checkpoint at epoch 90580
# Saved checkpoint at epoch 90600
# Saved checkpoint at epoch 90620
# Saved checkpoint at epoch 90640
# Saved checkpoint at epoch 90660
# Saved checkpoint at epoch 90680
# Saved checkpoint at epoch 90700
# Saved checkpoint at epoch 90720
# Saved checkpoint at epoch 90740
# Saved checkpoint at epoch 90760
# Saved checkpoint at epoch 90780
# Saved checkpoint at epoch 90800
# Saved checkpoint at epoch 90820
# Saved checkpoint at epoch 90840
# Saved checkpoint at epoch 90860
# Saved checkpoint at epoch 90880
# Saved checkpoint at epoch 90900
# Saved checkpoint at epoch 90920
# Saved checkpoint at epoch 90940
# Saved checkpoint at epoch 90960
# Saved checkpoint at epoch 90980
# Saved checkpoint at epoch 91000
# Saved checkpoint at epoch 91020
# Saved checkpoint at epoch 91040
# Saved checkpoint at epoch 91060
# Saved checkpoint at epoch 91080
# Saved checkpoint at epoch 91100
# Saved checkpoint at epoch 91120
# Saved checkpoint at epoch 91140
# Saved checkpoint at epoch 91160
# Saved checkpoint at epoch 91180
# Saved checkpoint at epoch 91200
# Saved checkpoint at epoch 91220
# Saved checkpoint at epoch 91240
# Saved checkpoint at epoch 91260
# Saved checkpoint at epoch 91280
# Saved checkpoint at epoch 91300
# Saved checkpoint at epoch 91320
# Saved checkpoint at epoch 91340
# Saved checkpoint at epoch 91360
# Saved checkpoint at epoch 91380
# Saved checkpoint at epoch 91400
# Saved checkpoint at epoch 91420
# Saved checkpoint at epoch 91440
# Saved checkpoint at epoch 91460
# Saved checkpoint at epoch 91480
# Saved checkpoint at epoch 91500
# Saved checkpoint at epoch 91520
# Saved checkpoint at epoch 91540
# Saved checkpoint at epoch 91560
# Saved checkpoint at epoch 91580
# Saved checkpoint at epoch 91600
# Saved checkpoint at epoch 91620
# Saved checkpoint at epoch 91640
# Saved checkpoint at epoch 91660
# Saved checkpoint at epoch 91680
# Saved checkpoint at epoch 91700
# Saved checkpoint at epoch 91720
# Saved checkpoint at epoch 91740
# Saved checkpoint at epoch 91760
# Saved checkpoint at epoch 91780
# Saved checkpoint at epoch 91800
# Saved checkpoint at epoch 91820
# Saved checkpoint at epoch 91840
# Saved checkpoint at epoch 91860
# Saved checkpoint at epoch 91880
# Saved checkpoint at epoch 91900
# Saved checkpoint at epoch 91920
# Saved checkpoint at epoch 91940
# Saved checkpoint at epoch 91960
# Saved checkpoint at epoch 91980
# Saved checkpoint at epoch 92000
# Saved checkpoint at epoch 92020
# Saved checkpoint at epoch 92040
# Saved checkpoint at epoch 92060
# Saved checkpoint at epoch 92080
# Saved checkpoint at epoch 92100
# Saved checkpoint at epoch 92120
# Saved checkpoint at epoch 92140
# Saved checkpoint at epoch 92160
# Saved checkpoint at epoch 92180
# Saved checkpoint at epoch 92200
# Saved checkpoint at epoch 92220
# Saved checkpoint at epoch 92240
# Saved checkpoint at epoch 92260
# Saved checkpoint at epoch 92280
# Saved checkpoint at epoch 92300
# Saved checkpoint at epoch 92320
# Saved checkpoint at epoch 92340
# Saved checkpoint at epoch 92360
# Saved checkpoint at epoch 92380
# Saved checkpoint at epoch 92400
# Saved checkpoint at epoch 92420
# Saved checkpoint at epoch 92440
# Saved checkpoint at epoch 92460
# Saved checkpoint at epoch 92480
# Saved checkpoint at epoch 92500
# Saved checkpoint at epoch 92520
# Saved checkpoint at epoch 92540
# Saved checkpoint at epoch 92560
# Saved checkpoint at epoch 92580
# Saved checkpoint at epoch 92600
# Saved checkpoint at epoch 92620
# Saved checkpoint at epoch 92640
# Saved checkpoint at epoch 92660
# Saved checkpoint at epoch 92680
# Saved checkpoint at epoch 92700
# Saved checkpoint at epoch 92720
# Saved checkpoint at epoch 92740
# Saved checkpoint at epoch 92760
# Saved checkpoint at epoch 92780
# Saved checkpoint at epoch 92800
# Saved checkpoint at epoch 92820
# Saved checkpoint at epoch 92840
# Saved checkpoint at epoch 92860
# Saved checkpoint at epoch 92880
# Saved checkpoint at epoch 92900
# Saved checkpoint at epoch 92920
# Saved checkpoint at epoch 92940
# Saved checkpoint at epoch 92960
# Saved checkpoint at epoch 92980
# Saved checkpoint at epoch 93000
# Saved checkpoint at epoch 93020
# Saved checkpoint at epoch 93040
# Saved checkpoint at epoch 93060
# Saved checkpoint at epoch 93080
# Saved checkpoint at epoch 93100
# Saved checkpoint at epoch 93120
# Saved checkpoint at epoch 93140
# Saved checkpoint at epoch 93160
# Saved checkpoint at epoch 93180
# Saved checkpoint at epoch 93200
# Saved checkpoint at epoch 93220
# Saved checkpoint at epoch 93240
# Saved checkpoint at epoch 93260
# Saved checkpoint at epoch 93280
# Saved checkpoint at epoch 93300
# Saved checkpoint at epoch 93320
# Saved checkpoint at epoch 93340
# Saved checkpoint at epoch 93360
# Saved checkpoint at epoch 93380
# Saved checkpoint at epoch 93400
# Saved checkpoint at epoch 93420
# Saved checkpoint at epoch 93440
# Saved checkpoint at epoch 93460
# Saved checkpoint at epoch 93480
# Saved checkpoint at epoch 93500
# Saved checkpoint at epoch 93520
# Saved checkpoint at epoch 93540
# Saved checkpoint at epoch 93560
# Saved checkpoint at epoch 93580
# Saved checkpoint at epoch 93600
# Saved checkpoint at epoch 93620
# Saved checkpoint at epoch 93640
# Saved checkpoint at epoch 93660
# Saved checkpoint at epoch 93680
# Saved checkpoint at epoch 93700
# Saved checkpoint at epoch 93720
# Saved checkpoint at epoch 93740
# Saved checkpoint at epoch 93760
# Saved checkpoint at epoch 93780
# Saved checkpoint at epoch 93800
# Saved checkpoint at epoch 93820
# Saved checkpoint at epoch 93840
# Saved checkpoint at epoch 93860
# Saved checkpoint at epoch 93880
# Saved checkpoint at epoch 93900
# Saved checkpoint at epoch 93920
# Saved checkpoint at epoch 93940
# Saved checkpoint at epoch 93960
# Saved checkpoint at epoch 93980
# Saved checkpoint at epoch 94000
# Saved checkpoint at epoch 94020
# Saved checkpoint at epoch 94040
# Saved checkpoint at epoch 94060
# Saved checkpoint at epoch 94080
# Saved checkpoint at epoch 94100
# Saved checkpoint at epoch 94120
# Saved checkpoint at epoch 94140
# Saved checkpoint at epoch 94160
# Saved checkpoint at epoch 94180
# Saved checkpoint at epoch 94200
# Saved checkpoint at epoch 94220
# Saved checkpoint at epoch 94240
# Saved checkpoint at epoch 94260
# Saved checkpoint at epoch 94280
# Saved checkpoint at epoch 94300
# Saved checkpoint at epoch 94320
# Saved checkpoint at epoch 94340
# Saved checkpoint at epoch 94360
# Saved checkpoint at epoch 94380
# Saved checkpoint at epoch 94400
# Saved checkpoint at epoch 94420
# Saved checkpoint at epoch 94440
# Saved checkpoint at epoch 94460
# Saved checkpoint at epoch 94480
# Saved checkpoint at epoch 94500
# Saved checkpoint at epoch 94520
# Saved checkpoint at epoch 94540
# Saved checkpoint at epoch 94560
# Saved checkpoint at epoch 94580
# Saved checkpoint at epoch 94600
# Saved checkpoint at epoch 94620
# Saved checkpoint at epoch 94640
# Saved checkpoint at epoch 94660
# Saved checkpoint at epoch 94680
# Saved checkpoint at epoch 94700
# Saved checkpoint at epoch 94720
# Saved checkpoint at epoch 94740
# Saved checkpoint at epoch 94760
# Saved checkpoint at epoch 94780
# Saved checkpoint at epoch 94800
# Saved checkpoint at epoch 94820
# Saved checkpoint at epoch 94840
# Saved checkpoint at epoch 94860
# Saved checkpoint at epoch 94880
# Saved checkpoint at epoch 94900
# Saved checkpoint at epoch 94920
# Saved checkpoint at epoch 94940
# Saved checkpoint at epoch 94960
# Saved checkpoint at epoch 94980
# Saved checkpoint at epoch 95000
# Saved checkpoint at epoch 95020
# Saved checkpoint at epoch 95040
# Saved checkpoint at epoch 95060
# Saved checkpoint at epoch 95080
# Saved checkpoint at epoch 95100
# Saved checkpoint at epoch 95120
# Saved checkpoint at epoch 95140
# Saved checkpoint at epoch 95160
# Saved checkpoint at epoch 95180
# Saved checkpoint at epoch 95200
# Saved checkpoint at epoch 95220
# Saved checkpoint at epoch 95240
# Saved checkpoint at epoch 95260
# Saved checkpoint at epoch 95280
# Saved checkpoint at epoch 95300
# Saved checkpoint at epoch 95320
# Saved checkpoint at epoch 95340
# Saved checkpoint at epoch 95360
# Saved checkpoint at epoch 95380
# Saved checkpoint at epoch 95400
# Saved checkpoint at epoch 95420
# Saved checkpoint at epoch 95440
# Saved checkpoint at epoch 95460
# Saved checkpoint at epoch 95480
# Saved checkpoint at epoch 95500
# Saved checkpoint at epoch 95520
# Saved checkpoint at epoch 95540
# Saved checkpoint at epoch 95560
# Saved checkpoint at epoch 95580
# Saved checkpoint at epoch 95600
# Saved checkpoint at epoch 95620
# Saved checkpoint at epoch 95640
# Saved checkpoint at epoch 95660
# Saved checkpoint at epoch 95680
# Saved checkpoint at epoch 95700
# Saved checkpoint at epoch 95720
# Saved checkpoint at epoch 95740
# Saved checkpoint at epoch 95760
# Saved checkpoint at epoch 95780
# Saved checkpoint at epoch 95800
# Saved checkpoint at epoch 95820
# Saved checkpoint at epoch 95840
# Saved checkpoint at epoch 95860
# Saved checkpoint at epoch 95880
# Saved checkpoint at epoch 95900
# Saved checkpoint at epoch 95920
# Saved checkpoint at epoch 95940
# Saved checkpoint at epoch 95960
# Saved checkpoint at epoch 95980
# Saved checkpoint at epoch 96000
# Saved checkpoint at epoch 96020
# Saved checkpoint at epoch 96040
# Saved checkpoint at epoch 96060
# Saved checkpoint at epoch 96080
# Saved checkpoint at epoch 96100
# Saved checkpoint at epoch 96120
# Saved checkpoint at epoch 96140
# Saved checkpoint at epoch 96160
# Saved checkpoint at epoch 96180
# Saved checkpoint at epoch 96200
# Saved checkpoint at epoch 96220
# Saved checkpoint at epoch 96240
# Saved checkpoint at epoch 96260
# Saved checkpoint at epoch 96280
# Saved checkpoint at epoch 96300
# Saved checkpoint at epoch 96320
# Saved checkpoint at epoch 96340
# Saved checkpoint at epoch 96360
# Saved checkpoint at epoch 96380
# Saved checkpoint at epoch 96400
# Saved checkpoint at epoch 96420
# Saved checkpoint at epoch 96440
# Saved checkpoint at epoch 96460
# Saved checkpoint at epoch 96480
# Saved checkpoint at epoch 96500
# Saved checkpoint at epoch 96520
# Saved checkpoint at epoch 96540
# Saved checkpoint at epoch 96560
# Saved checkpoint at epoch 96580
# Saved checkpoint at epoch 96600
# Saved checkpoint at epoch 96620
# Saved checkpoint at epoch 96640
# Saved checkpoint at epoch 96660
# Saved checkpoint at epoch 96680
# Saved checkpoint at epoch 96700
# Saved checkpoint at epoch 96720
# Saved checkpoint at epoch 96740
# Saved checkpoint at epoch 96760
# Saved checkpoint at epoch 96780
# Saved checkpoint at epoch 96800
# Saved checkpoint at epoch 96820
# Saved checkpoint at epoch 96840
# Saved checkpoint at epoch 96860
# Saved checkpoint at epoch 96880
# Saved checkpoint at epoch 96900
# Saved checkpoint at epoch 96920
# Saved checkpoint at epoch 96940
# Saved checkpoint at epoch 96960
# Saved checkpoint at epoch 96980
# Saved checkpoint at epoch 97000
# Saved checkpoint at epoch 97020
# Saved checkpoint at epoch 97040
# Saved checkpoint at epoch 97060
# Saved checkpoint at epoch 97080
# Saved checkpoint at epoch 97100
# Saved checkpoint at epoch 97120
# Saved checkpoint at epoch 97140
# Saved checkpoint at epoch 97160
# Saved checkpoint at epoch 97180
# Saved checkpoint at epoch 97200
# Saved checkpoint at epoch 97220
# Saved checkpoint at epoch 97240
# Saved checkpoint at epoch 97260
# Saved checkpoint at epoch 97280
# Saved checkpoint at epoch 97300
# Saved checkpoint at epoch 97320
# Saved checkpoint at epoch 97340
# Saved checkpoint at epoch 97360
# Saved checkpoint at epoch 97380
# Saved checkpoint at epoch 97400
# Saved checkpoint at epoch 97420
# Saved checkpoint at epoch 97440
# Saved checkpoint at epoch 97460
# Saved checkpoint at epoch 97480
# Saved checkpoint at epoch 97500
# Saved checkpoint at epoch 97520
# Saved checkpoint at epoch 97540
# Saved checkpoint at epoch 97560
# Saved checkpoint at epoch 97580
# Saved checkpoint at epoch 97600
# Saved checkpoint at epoch 97620
# Saved checkpoint at epoch 97640
# Saved checkpoint at epoch 97660
# Saved checkpoint at epoch 97680
# Saved checkpoint at epoch 97700
# Saved checkpoint at epoch 97720
# Saved checkpoint at epoch 97740
# Saved checkpoint at epoch 97760
# Saved checkpoint at epoch 97780
# Saved checkpoint at epoch 97800
# Saved checkpoint at epoch 97820
# Saved checkpoint at epoch 97840
# Saved checkpoint at epoch 97860
# Saved checkpoint at epoch 97880
# Saved checkpoint at epoch 97900
# Saved checkpoint at epoch 97920
# Saved checkpoint at epoch 97940
# Saved checkpoint at epoch 97960
# Saved checkpoint at epoch 97980
# Saved checkpoint at epoch 98000
# Saved checkpoint at epoch 98020
# Saved checkpoint at epoch 98040
# Saved checkpoint at epoch 98060
# Saved checkpoint at epoch 98080
# Saved checkpoint at epoch 98100
# Saved checkpoint at epoch 98120
# Saved checkpoint at epoch 98140
# Saved checkpoint at epoch 98160
# Saved checkpoint at epoch 98180
# Saved checkpoint at epoch 98200
# Saved checkpoint at epoch 98220
# Saved checkpoint at epoch 98240
# Saved checkpoint at epoch 98260
# Saved checkpoint at epoch 98280
# Saved checkpoint at epoch 98300
# Saved checkpoint at epoch 98320
# Saved checkpoint at epoch 98340
# Saved checkpoint at epoch 98360
# Saved checkpoint at epoch 98380
# Saved checkpoint at epoch 98400
# Saved checkpoint at epoch 98420
# Saved checkpoint at epoch 98440
# Saved checkpoint at epoch 98460
# Saved checkpoint at epoch 98480
# Saved checkpoint at epoch 98500
# Saved checkpoint at epoch 98520
# Saved checkpoint at epoch 98540
# Saved checkpoint at epoch 98560
# Saved checkpoint at epoch 98580
# Saved checkpoint at epoch 98600
# Saved checkpoint at epoch 98620
# Saved checkpoint at epoch 98640
# Saved checkpoint at epoch 98660
# Saved checkpoint at epoch 98680
# Saved checkpoint at epoch 98700
# Saved checkpoint at epoch 98720
# Saved checkpoint at epoch 98740
# Saved checkpoint at epoch 98760
# Saved checkpoint at epoch 98780
# Saved checkpoint at epoch 98800
# Saved checkpoint at epoch 98820
# Saved checkpoint at epoch 98840
# Saved checkpoint at epoch 98860
# Saved checkpoint at epoch 98880
# Saved checkpoint at epoch 98900
# Saved checkpoint at epoch 98920
# Saved checkpoint at epoch 98940
# Saved checkpoint at epoch 98960
# Saved checkpoint at epoch 98980
# Saved checkpoint at epoch 99000
# Saved checkpoint at epoch 99020
# Saved checkpoint at epoch 99040
# Saved checkpoint at epoch 99060
# Saved checkpoint at epoch 99080
# Saved checkpoint at epoch 99100
# Saved checkpoint at epoch 99120
# Saved checkpoint at epoch 99140
# Saved checkpoint at epoch 99160
# Saved checkpoint at epoch 99180
# Saved checkpoint at epoch 99200
# Saved checkpoint at epoch 99220
# Saved checkpoint at epoch 99240
# Saved checkpoint at epoch 99260
# Saved checkpoint at epoch 99280
# Saved checkpoint at epoch 99300
# Saved checkpoint at epoch 99320
# Saved checkpoint at epoch 99340
# Saved checkpoint at epoch 99360
# Saved checkpoint at epoch 99380
# Saved checkpoint at epoch 99400
# Saved checkpoint at epoch 99420
# Saved checkpoint at epoch 99440
# Saved checkpoint at epoch 99460
# Saved checkpoint at epoch 99480
# Saved checkpoint at epoch 99500
# Saved checkpoint at epoch 99520
# Saved checkpoint at epoch 99540
# Saved checkpoint at epoch 99560
# Saved checkpoint at epoch 99580
# Saved checkpoint at epoch 99600
# Saved checkpoint at epoch 99620
# Saved checkpoint at epoch 99640
# Saved checkpoint at epoch 99660
# Saved checkpoint at epoch 99680
# Saved checkpoint at epoch 99700
# Saved checkpoint at epoch 99720
# Saved checkpoint at epoch 99740
# Saved checkpoint at epoch 99760
# Saved checkpoint at epoch 99780
# Saved checkpoint at epoch 99800
# Saved checkpoint at epoch 99820
# Saved checkpoint at epoch 99840
# Saved checkpoint at epoch 99860
# Saved checkpoint at epoch 99880
# Saved checkpoint at epoch 99900
# Saved checkpoint at epoch 99920
# Saved checkpoint at epoch 99940
# Saved checkpoint at epoch 99960
# Saved checkpoint at epoch 99980
# Saved checkpoint at epoch 100000

# %%
# Plot all topologies with fixed layers (2)
plt.figure(figsize=(12, 6))

plt.plot(result['loss_history'], label=f'10 neurons', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Neurons (1 hidden layer, Seed=0)')
#plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %%
topology_results = {}
neurons_range = [2, 4, 8, 16, 32, 64, 100]
epochs = 50000
learning_rate = 0.01
seed = 0

n_hidden = 1
for n_neurons in neurons_range:
    print(f"Training: {n_hidden} hidden layers, {n_neurons} neurons each...")
    
    config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
        n_inputs=2,
        n_outputs=2,
        n_hidden_layers=n_hidden,
        n_neurons_per_hidden=n_neurons,
        loss_func=SymbolicLoss.mse(),
        weight_init=WeightInit.XAVIER,
        bias_init_std=0.01,
        seed=seed
    )
    
    net = Net.fully_connected(config)
    
    result = net.train(
        inputs=input_list,
        targets=target_list,
        learning_rate=learning_rate,
        epochs=epochs,
        batch_size=32,
        checkpoint_config=checkpoint_config
    )
    
    topology_results[(n_hidden, n_neurons)] = result['loss_history']
    print(f"  Final loss: {result['loss_history'][-1]:.6f}")

print("\nAll topology experiments complete!")
# Out:
# Training: 1 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, continuing to epoch 50000...
# Saved checkpoint at epoch 320
# Saved checkpoint at epoch 340
# Saved checkpoint at epoch 360
# Saved checkpoint at epoch 380
# Saved checkpoint at epoch 400
# Saved checkpoint at epoch 420
# Saved checkpoint at epoch 440
# Saved checkpoint at epoch 460
# Saved checkpoint at epoch 480
# Saved checkpoint at epoch 500
# Saved checkpoint at epoch 520
# Saved checkpoint at epoch 540
# Saved checkpoint at epoch 560
# Saved checkpoint at epoch 580
# Saved checkpoint at epoch 600
# Saved checkpoint at epoch 620
# Saved checkpoint at epoch 640
# Saved checkpoint at epoch 660
# Saved checkpoint at epoch 680
# Saved checkpoint at epoch 700
# Saved checkpoint at epoch 720
# Saved checkpoint at epoch 740
# Saved checkpoint at epoch 760
# Saved checkpoint at epoch 780
# Saved checkpoint at epoch 800
# Saved checkpoint at epoch 820
# Saved checkpoint at epoch 840
# Saved checkpoint at epoch 860
# Saved checkpoint at epoch 880
# Saved checkpoint at epoch 900
# Saved checkpoint at epoch 920
# Saved checkpoint at epoch 940
# Saved checkpoint at epoch 960
# Saved checkpoint at epoch 980
# Saved checkpoint at epoch 1000
# Saved checkpoint at epoch 1020
# Saved checkpoint at epoch 1040
# Saved checkpoint at epoch 1060
# Saved checkpoint at epoch 1080
# Saved checkpoint at epoch 1100
# Saved checkpoint at epoch 1120
# Saved checkpoint at epoch 1140
# Saved checkpoint at epoch 1160
# Saved checkpoint at epoch 1180
# Saved checkpoint at epoch 1200
# Saved checkpoint at epoch 1220
# Saved checkpoint at epoch 1240
# Saved checkpoint at epoch 1260
# Saved checkpoint at epoch 1280
# Saved checkpoint at epoch 1300
# Saved checkpoint at epoch 1320
# Saved checkpoint at epoch 1340
# Saved checkpoint at epoch 1360
# Saved checkpoint at epoch 1380
# Saved checkpoint at epoch 1400
# Saved checkpoint at epoch 1420
# Saved checkpoint at epoch 1440
# Saved checkpoint at epoch 1460
# Saved checkpoint at epoch 1480
# Saved checkpoint at epoch 1500
# Saved checkpoint at epoch 1520
# Saved checkpoint at epoch 1540
# Saved checkpoint at epoch 1560
# Saved checkpoint at epoch 1580
# Saved checkpoint at epoch 1600
# Saved checkpoint at epoch 1620
# Saved checkpoint at epoch 1640
# Saved checkpoint at epoch 1660
# Saved checkpoint at epoch 1680
# Saved checkpoint at epoch 1700
# Saved checkpoint at epoch 1720
# Saved checkpoint at epoch 1740
# Saved checkpoint at epoch 1760
# Saved checkpoint at epoch 1780
# Saved checkpoint at epoch 1800
# Saved checkpoint at epoch 1820
# Saved checkpoint at epoch 1840
# Saved checkpoint at epoch 1860
# Saved checkpoint at epoch 1880
# Saved checkpoint at epoch 1900
# Saved checkpoint at epoch 1920
# Saved checkpoint at epoch 1940
# Saved checkpoint at epoch 1960
# Saved checkpoint at epoch 1980
# Saved checkpoint at epoch 2000
# Saved checkpoint at epoch 2020
# Saved checkpoint at epoch 2040
# Saved checkpoint at epoch 2060
# Saved checkpoint at epoch 2080
# Saved checkpoint at epoch 2100
# Saved checkpoint at epoch 2120
# Saved checkpoint at epoch 2140
# Saved checkpoint at epoch 2160
# Saved checkpoint at epoch 2180
# Saved checkpoint at epoch 2200
# Saved checkpoint at epoch 2220
# Saved checkpoint at epoch 2240
# Saved checkpoint at epoch 2260
# Saved checkpoint at epoch 2280
# Saved checkpoint at epoch 2300
# Saved checkpoint at epoch 2320
# Saved checkpoint at epoch 2340
# Saved checkpoint at epoch 2360
# Saved checkpoint at epoch 2380
# Saved checkpoint at epoch 2400
# Saved checkpoint at epoch 2420
# Saved checkpoint at epoch 2440
# Saved checkpoint at epoch 2460
# Saved checkpoint at epoch 2480
# Saved checkpoint at epoch 2500
# Saved checkpoint at epoch 2520
# Saved checkpoint at epoch 2540
# Saved checkpoint at epoch 2560
# Saved checkpoint at epoch 2580
# Saved checkpoint at epoch 2600
# Saved checkpoint at epoch 2620
# Saved checkpoint at epoch 2640
# Saved checkpoint at epoch 2660
# Saved checkpoint at epoch 2680
# Saved checkpoint at epoch 2700
# Saved checkpoint at epoch 2720
# Saved checkpoint at epoch 2740
# Saved checkpoint at epoch 2760
# Saved checkpoint at epoch 2780
# Saved checkpoint at epoch 2800
# Saved checkpoint at epoch 2820
# Saved checkpoint at epoch 2840
# Saved checkpoint at epoch 2860
# Saved checkpoint at epoch 2880
# Saved checkpoint at epoch 2900
# Saved checkpoint at epoch 2920
# Saved checkpoint at epoch 2940
# Saved checkpoint at epoch 2960
# Saved checkpoint at epoch 2980
# Saved checkpoint at epoch 3000
# Saved checkpoint at epoch 3020
# Saved checkpoint at epoch 3040
# Saved checkpoint at epoch 3060
# Saved checkpoint at epoch 3080
# Saved checkpoint at epoch 3100
# Saved checkpoint at epoch 3120
# Saved checkpoint at epoch 3140
# Saved checkpoint at epoch 3160
# Saved checkpoint at epoch 3180
# Saved checkpoint at epoch 3200
# Saved checkpoint at epoch 3220
# Saved checkpoint at epoch 3240
# Saved checkpoint at epoch 3260
# Saved checkpoint at epoch 3280
# Saved checkpoint at epoch 3300
# Saved checkpoint at epoch 3320
# Saved checkpoint at epoch 3340
# Saved checkpoint at epoch 3360
# Saved checkpoint at epoch 3380
# Saved checkpoint at epoch 3400
# Saved checkpoint at epoch 3420
# Saved checkpoint at epoch 3440
# Saved checkpoint at epoch 3460
# Saved checkpoint at epoch 3480
# Saved checkpoint at epoch 3500
# Saved checkpoint at epoch 3520
# Saved checkpoint at epoch 3540
# Saved checkpoint at epoch 3560
# Saved checkpoint at epoch 3580
# Saved checkpoint at epoch 3600
# Saved checkpoint at epoch 3620
# Saved checkpoint at epoch 3640
# Saved checkpoint at epoch 3660
# Saved checkpoint at epoch 3680
# Saved checkpoint at epoch 3700
# Saved checkpoint at epoch 3720
# Saved checkpoint at epoch 3740
# Saved checkpoint at epoch 3760
# Saved checkpoint at epoch 3780
# Saved checkpoint at epoch 3800
# Saved checkpoint at epoch 3820
# Saved checkpoint at epoch 3840
# Saved checkpoint at epoch 3860
# Saved checkpoint at epoch 3880
# Saved checkpoint at epoch 3900
# Saved checkpoint at epoch 3920
# Saved checkpoint at epoch 3940
# Saved checkpoint at epoch 3960
# Saved checkpoint at epoch 3980
# Saved checkpoint at epoch 4000
# Saved checkpoint at epoch 4020
# Saved checkpoint at epoch 4040
# Saved checkpoint at epoch 4060
# Saved checkpoint at epoch 4080
# Saved checkpoint at epoch 4100
# Saved checkpoint at epoch 4120
# Saved checkpoint at epoch 4140
# Saved checkpoint at epoch 4160
# Saved checkpoint at epoch 4180
# Saved checkpoint at epoch 4200
# Saved checkpoint at epoch 4220
# Saved checkpoint at epoch 4240
# Saved checkpoint at epoch 4260
# Saved checkpoint at epoch 4280
# Saved checkpoint at epoch 4300
# Saved checkpoint at epoch 4320
# Saved checkpoint at epoch 4340
# Saved checkpoint at epoch 4360
# Saved checkpoint at epoch 4380
# Saved checkpoint at epoch 4400
# Saved checkpoint at epoch 4420
# Saved checkpoint at epoch 4440
# Saved checkpoint at epoch 4460
# Saved checkpoint at epoch 4480
# Saved checkpoint at epoch 4500
# Saved checkpoint at epoch 4520
# Saved checkpoint at epoch 4540
# Saved checkpoint at epoch 4560
# Saved checkpoint at epoch 4580
# Saved checkpoint at epoch 4600
# Saved checkpoint at epoch 4620
# Saved checkpoint at epoch 4640
# Saved checkpoint at epoch 4660
# Saved checkpoint at epoch 4680
# Saved checkpoint at epoch 4700
# Saved checkpoint at epoch 4720
# Saved checkpoint at epoch 4740
# Saved checkpoint at epoch 4760
# Saved checkpoint at epoch 4780
# Saved checkpoint at epoch 4800
# Saved checkpoint at epoch 4820
# Saved checkpoint at epoch 4840
# Saved checkpoint at epoch 4860
# Saved checkpoint at epoch 4880
# Saved checkpoint at epoch 4900
# Saved checkpoint at epoch 4920
# Saved checkpoint at epoch 4940
# Saved checkpoint at epoch 4960
# Saved checkpoint at epoch 4980
# Saved checkpoint at epoch 5000
# Saved checkpoint at epoch 5020
# Saved checkpoint at epoch 5040
# Saved checkpoint at epoch 5060
# Saved checkpoint at epoch 5080
# Saved checkpoint at epoch 5100
# Saved checkpoint at epoch 5120
# Saved checkpoint at epoch 5140
# Saved checkpoint at epoch 5160
# Saved checkpoint at epoch 5180
# Saved checkpoint at epoch 5200
# Saved checkpoint at epoch 5220
# Saved checkpoint at epoch 5240
# Saved checkpoint at epoch 5260
# Saved checkpoint at epoch 5280
# Saved checkpoint at epoch 5300
# Saved checkpoint at epoch 5320
# Saved checkpoint at epoch 5340
# Saved checkpoint at epoch 5360
# Saved checkpoint at epoch 5380
# Saved checkpoint at epoch 5400
# Saved checkpoint at epoch 5420
# Saved checkpoint at epoch 5440
# Saved checkpoint at epoch 5460
# Saved checkpoint at epoch 5480
# Saved checkpoint at epoch 5500
# Saved checkpoint at epoch 5520
# Saved checkpoint at epoch 5540
# Saved checkpoint at epoch 5560
# Saved checkpoint at epoch 5580
# Saved checkpoint at epoch 5600
# Saved checkpoint at epoch 5620
# Saved checkpoint at epoch 5640
# Saved checkpoint at epoch 5660
# Saved checkpoint at epoch 5680
# Saved checkpoint at epoch 5700
# Saved checkpoint at epoch 5720
# Saved checkpoint at epoch 5740
# Saved checkpoint at epoch 5760
# Saved checkpoint at epoch 5780
# Saved checkpoint at epoch 5800
# Saved checkpoint at epoch 5820
# Saved checkpoint at epoch 5840
# Saved checkpoint at epoch 5860
# Saved checkpoint at epoch 5880
# Saved checkpoint at epoch 5900
# Saved checkpoint at epoch 5920
# Saved checkpoint at epoch 5940
# Saved checkpoint at epoch 5960
# Saved checkpoint at epoch 5980
# Saved checkpoint at epoch 6000
# Saved checkpoint at epoch 6020
# Saved checkpoint at epoch 6040
# Saved checkpoint at epoch 6060
# Saved checkpoint at epoch 6080
# Saved checkpoint at epoch 6100
# Saved checkpoint at epoch 6120
# Saved checkpoint at epoch 6140
# Saved checkpoint at epoch 6160
# Saved checkpoint at epoch 6180
# Saved checkpoint at epoch 6200
# Saved checkpoint at epoch 6220
# Saved checkpoint at epoch 6240
# Saved checkpoint at epoch 6260
# Saved checkpoint at epoch 6280
# Saved checkpoint at epoch 6300
# Saved checkpoint at epoch 6320
# Saved checkpoint at epoch 6340
# Saved checkpoint at epoch 6360
# Saved checkpoint at epoch 6380
# Saved checkpoint at epoch 6400
# Saved checkpoint at epoch 6420
# Saved checkpoint at epoch 6440
# Saved checkpoint at epoch 6460
# Saved checkpoint at epoch 6480
# Saved checkpoint at epoch 6500
# Saved checkpoint at epoch 6520
# Saved checkpoint at epoch 6540
# Saved checkpoint at epoch 6560
# Saved checkpoint at epoch 6580
# Saved checkpoint at epoch 6600
# Saved checkpoint at epoch 6620
# Saved checkpoint at epoch 6640
# Saved checkpoint at epoch 6660
# Saved checkpoint at epoch 6680
# Saved checkpoint at epoch 6700
# Saved checkpoint at epoch 6720
# Saved checkpoint at epoch 6740
# Saved checkpoint at epoch 6760
# Saved checkpoint at epoch 6780
# Saved checkpoint at epoch 6800
# Saved checkpoint at epoch 6820
# Saved checkpoint at epoch 6840
# Saved checkpoint at epoch 6860
# Saved checkpoint at epoch 6880
# Saved checkpoint at epoch 6900
# Saved checkpoint at epoch 6920
# Saved checkpoint at epoch 6940
# Saved checkpoint at epoch 6960
# Saved checkpoint at epoch 6980
# Saved checkpoint at epoch 7000
# Saved checkpoint at epoch 7020
# Saved checkpoint at epoch 7040
# Saved checkpoint at epoch 7060
# Saved checkpoint at epoch 7080
# Saved checkpoint at epoch 7100
# Saved checkpoint at epoch 7120
# Saved checkpoint at epoch 7140
# Saved checkpoint at epoch 7160
# Saved checkpoint at epoch 7180
# Saved checkpoint at epoch 7200
# Saved checkpoint at epoch 7220
# Saved checkpoint at epoch 7240
# Saved checkpoint at epoch 7260
# Saved checkpoint at epoch 7280
# Saved checkpoint at epoch 7300
# Saved checkpoint at epoch 7320
# Saved checkpoint at epoch 7340
# Saved checkpoint at epoch 7360
# Saved checkpoint at epoch 7380
# Saved checkpoint at epoch 7400
# Saved checkpoint at epoch 7420
# Saved checkpoint at epoch 7440
# Saved checkpoint at epoch 7460
# Saved checkpoint at epoch 7480
# Saved checkpoint at epoch 7500
# Saved checkpoint at epoch 7520
# Saved checkpoint at epoch 7540
# Saved checkpoint at epoch 7560
# Saved checkpoint at epoch 7580
# Saved checkpoint at epoch 7600
# Saved checkpoint at epoch 7620
# Saved checkpoint at epoch 7640
# Saved checkpoint at epoch 7660
# Saved checkpoint at epoch 7680
# Saved checkpoint at epoch 7700
# Saved checkpoint at epoch 7720
# Saved checkpoint at epoch 7740
# Saved checkpoint at epoch 7760
# Saved checkpoint at epoch 7780
# Saved checkpoint at epoch 7800
# Saved checkpoint at epoch 7820
# Saved checkpoint at epoch 7840
# Saved checkpoint at epoch 7860
# Saved checkpoint at epoch 7880
# Saved checkpoint at epoch 7900
# Saved checkpoint at epoch 7920
# Saved checkpoint at epoch 7940
# Saved checkpoint at epoch 7960
# Saved checkpoint at epoch 7980
# Saved checkpoint at epoch 8000
# Saved checkpoint at epoch 8020
# Saved checkpoint at epoch 8040
# Saved checkpoint at epoch 8060
# Saved checkpoint at epoch 8080
# Saved checkpoint at epoch 8100
# Saved checkpoint at epoch 8120
# Saved checkpoint at epoch 8140
# Saved checkpoint at epoch 8160
# Saved checkpoint at epoch 8180
# Saved checkpoint at epoch 8200
# Saved checkpoint at epoch 8220
# Saved checkpoint at epoch 8240
# Saved checkpoint at epoch 8260
# Saved checkpoint at epoch 8280
# Saved checkpoint at epoch 8300
# Saved checkpoint at epoch 8320
# Saved checkpoint at epoch 8340
# Saved checkpoint at epoch 8360
# Saved checkpoint at epoch 8380
# Saved checkpoint at epoch 8400
# Saved checkpoint at epoch 8420
# Saved checkpoint at epoch 8440
# Saved checkpoint at epoch 8460
# Saved checkpoint at epoch 8480
# Saved checkpoint at epoch 8500
# Saved checkpoint at epoch 8520
# Saved checkpoint at epoch 8540
# Saved checkpoint at epoch 8560
# Saved checkpoint at epoch 8580
# Saved checkpoint at epoch 8600
# Saved checkpoint at epoch 8620
# Saved checkpoint at epoch 8640
# Saved checkpoint at epoch 8660
# Saved checkpoint at epoch 8680
# Saved checkpoint at epoch 8700
# Saved checkpoint at epoch 8720
# Saved checkpoint at epoch 8740
# Saved checkpoint at epoch 8760
# Saved checkpoint at epoch 8780
# Saved checkpoint at epoch 8800
# Saved checkpoint at epoch 8820
# Saved checkpoint at epoch 8840
# Saved checkpoint at epoch 8860
# Saved checkpoint at epoch 8880
# Saved checkpoint at epoch 8900
# Saved checkpoint at epoch 8920
# Saved checkpoint at epoch 8940
# Saved checkpoint at epoch 8960
# Saved checkpoint at epoch 8980
# Saved checkpoint at epoch 9000
# Saved checkpoint at epoch 9020
# Saved checkpoint at epoch 9040
# Saved checkpoint at epoch 9060
# Saved checkpoint at epoch 9080
# Saved checkpoint at epoch 9100
# Saved checkpoint at epoch 9120
# Saved checkpoint at epoch 9140
# Saved checkpoint at epoch 9160
# Saved checkpoint at epoch 9180
# Saved checkpoint at epoch 9200
# Saved checkpoint at epoch 9220
# Saved checkpoint at epoch 9240
# Saved checkpoint at epoch 9260
# Saved checkpoint at epoch 9280
# Saved checkpoint at epoch 9300
# Saved checkpoint at epoch 9320
# Saved checkpoint at epoch 9340
# Saved checkpoint at epoch 9360
# Saved checkpoint at epoch 9380
# Saved checkpoint at epoch 9400
# Saved checkpoint at epoch 9420
# Saved checkpoint at epoch 9440
# Saved checkpoint at epoch 9460
# Saved checkpoint at epoch 9480
# Saved checkpoint at epoch 9500
# Saved checkpoint at epoch 9520
# Saved checkpoint at epoch 9540
# Saved checkpoint at epoch 9560
# Saved checkpoint at epoch 9580
# Saved checkpoint at epoch 9600
# Saved checkpoint at epoch 9620
# Saved checkpoint at epoch 9640
# Saved checkpoint at epoch 9660
# Saved checkpoint at epoch 9680
# Saved checkpoint at epoch 9700
# Saved checkpoint at epoch 9720
# Saved checkpoint at epoch 9740
# Saved checkpoint at epoch 9760
# Saved checkpoint at epoch 9780
# Saved checkpoint at epoch 9800
# Saved checkpoint at epoch 9820
# Saved checkpoint at epoch 9840
# Saved checkpoint at epoch 9860
# Saved checkpoint at epoch 9880
# Saved checkpoint at epoch 9900
# Saved checkpoint at epoch 9920
# Saved checkpoint at epoch 9940
# Saved checkpoint at epoch 9960
# Saved checkpoint at epoch 9980
# Saved checkpoint at epoch 10000
# Saved checkpoint at epoch 10020
# Saved checkpoint at epoch 10040
# Saved checkpoint at epoch 10060
# Saved checkpoint at epoch 10080
# Saved checkpoint at epoch 10100
# Saved checkpoint at epoch 10120
# Saved checkpoint at epoch 10140
# Saved checkpoint at epoch 10160
# Saved checkpoint at epoch 10180
# Saved checkpoint at epoch 10200
# Saved checkpoint at epoch 10220
# Saved checkpoint at epoch 10240
# Saved checkpoint at epoch 10260
# Saved checkpoint at epoch 10280
# Saved checkpoint at epoch 10300
# Saved checkpoint at epoch 10320
# Saved checkpoint at epoch 10340
# Saved checkpoint at epoch 10360
# Saved checkpoint at epoch 10380
# Saved checkpoint at epoch 10400
# Saved checkpoint at epoch 10420
# Saved checkpoint at epoch 10440
# Saved checkpoint at epoch 10460
# Saved checkpoint at epoch 10480
# Saved checkpoint at epoch 10500
# Saved checkpoint at epoch 10520
# Saved checkpoint at epoch 10540
# Saved checkpoint at epoch 10560
# Saved checkpoint at epoch 10580
# Saved checkpoint at epoch 10600
# Saved checkpoint at epoch 10620
# Saved checkpoint at epoch 10640
# Saved checkpoint at epoch 10660
# Saved checkpoint at epoch 10680
# Saved checkpoint at epoch 10700
# Saved checkpoint at epoch 10720
# Saved checkpoint at epoch 10740
# Saved checkpoint at epoch 10760
# Saved checkpoint at epoch 10780
# Saved checkpoint at epoch 10800
# Saved checkpoint at epoch 10820
# Saved checkpoint at epoch 10840
# Saved checkpoint at epoch 10860
# Saved checkpoint at epoch 10880
# Saved checkpoint at epoch 10900
# Saved checkpoint at epoch 10920
# Saved checkpoint at epoch 10940
# Saved checkpoint at epoch 10960
# Saved checkpoint at epoch 10980
# Saved checkpoint at epoch 11000
# Saved checkpoint at epoch 11020
# Saved checkpoint at epoch 11040
# Saved checkpoint at epoch 11060
# Saved checkpoint at epoch 11080
# Saved checkpoint at epoch 11100
# Saved checkpoint at epoch 11120
# Saved checkpoint at epoch 11140
# Saved checkpoint at epoch 11160
# Saved checkpoint at epoch 11180
# Saved checkpoint at epoch 11200
# Saved checkpoint at epoch 11220
# Saved checkpoint at epoch 11240
# Saved checkpoint at epoch 11260
# Saved checkpoint at epoch 11280
# Saved checkpoint at epoch 11300
# Saved checkpoint at epoch 11320
# Saved checkpoint at epoch 11340
# Saved checkpoint at epoch 11360
# Saved checkpoint at epoch 11380
# Saved checkpoint at epoch 11400
# Saved checkpoint at epoch 11420
# Saved checkpoint at epoch 11440
# Saved checkpoint at epoch 11460
# Saved checkpoint at epoch 11480
# Saved checkpoint at epoch 11500
# Saved checkpoint at epoch 11520
# Saved checkpoint at epoch 11540
# Saved checkpoint at epoch 11560
# Saved checkpoint at epoch 11580
# Saved checkpoint at epoch 11600
# Saved checkpoint at epoch 11620
# Saved checkpoint at epoch 11640
# Saved checkpoint at epoch 11660
# Saved checkpoint at epoch 11680
# Saved checkpoint at epoch 11700
# Saved checkpoint at epoch 11720
# Saved checkpoint at epoch 11740
# Saved checkpoint at epoch 11760
# Saved checkpoint at epoch 11780
# Saved checkpoint at epoch 11800
# Saved checkpoint at epoch 11820
# Saved checkpoint at epoch 11840
# Saved checkpoint at epoch 11860
# Saved checkpoint at epoch 11880
# Saved checkpoint at epoch 11900
# Saved checkpoint at epoch 11920
# Saved checkpoint at epoch 11940
# Saved checkpoint at epoch 11960
# Saved checkpoint at epoch 11980
# Saved checkpoint at epoch 12000
# Saved checkpoint at epoch 12020
# Saved checkpoint at epoch 12040
# Saved checkpoint at epoch 12060
# Saved checkpoint at epoch 12080
# Saved checkpoint at epoch 12100
# Saved checkpoint at epoch 12120
# Saved checkpoint at epoch 12140
# Saved checkpoint at epoch 12160
# Saved checkpoint at epoch 12180
# Saved checkpoint at epoch 12200
# Saved checkpoint at epoch 12220
# Saved checkpoint at epoch 12240
# Saved checkpoint at epoch 12260
# Saved checkpoint at epoch 12280
# Saved checkpoint at epoch 12300
# Saved checkpoint at epoch 12320
# Saved checkpoint at epoch 12340
# Saved checkpoint at epoch 12360
# Saved checkpoint at epoch 12380
# Saved checkpoint at epoch 12400
# Saved checkpoint at epoch 12420
# Saved checkpoint at epoch 12440
# Saved checkpoint at epoch 12460
# Saved checkpoint at epoch 12480
# Saved checkpoint at epoch 12500
# Saved checkpoint at epoch 12520
# Saved checkpoint at epoch 12540
# Saved checkpoint at epoch 12560
# Saved checkpoint at epoch 12580
# Saved checkpoint at epoch 12600
# Saved checkpoint at epoch 12620
# Saved checkpoint at epoch 12640
# Saved checkpoint at epoch 12660
# Saved checkpoint at epoch 12680
# Saved checkpoint at epoch 12700
# Saved checkpoint at epoch 12720
# Saved checkpoint at epoch 12740
# Saved checkpoint at epoch 12760
# Saved checkpoint at epoch 12780
# Saved checkpoint at epoch 12800
# Saved checkpoint at epoch 12820
# Saved checkpoint at epoch 12840
# Saved checkpoint at epoch 12860
# Saved checkpoint at epoch 12880
# Saved checkpoint at epoch 12900
# Saved checkpoint at epoch 12920
# Saved checkpoint at epoch 12940
# Saved checkpoint at epoch 12960
# Saved checkpoint at epoch 12980
# Saved checkpoint at epoch 13000
# Saved checkpoint at epoch 13020
# Saved checkpoint at epoch 13040
# Saved checkpoint at epoch 13060
# Saved checkpoint at epoch 13080
# Saved checkpoint at epoch 13100
# Saved checkpoint at epoch 13120
# Saved checkpoint at epoch 13140
# Saved checkpoint at epoch 13160
# Saved checkpoint at epoch 13180
# Saved checkpoint at epoch 13200
# Saved checkpoint at epoch 13220
# Saved checkpoint at epoch 13240
# Saved checkpoint at epoch 13260
# Saved checkpoint at epoch 13280
# Saved checkpoint at epoch 13300
# Saved checkpoint at epoch 13320
# Saved checkpoint at epoch 13340
# Saved checkpoint at epoch 13360
# Saved checkpoint at epoch 13380
# Saved checkpoint at epoch 13400
# Saved checkpoint at epoch 13420
# Saved checkpoint at epoch 13440
# Saved checkpoint at epoch 13460
# Saved checkpoint at epoch 13480
# Saved checkpoint at epoch 13500
# Saved checkpoint at epoch 13520
# Saved checkpoint at epoch 13540
# Saved checkpoint at epoch 13560
# Saved checkpoint at epoch 13580
# Saved checkpoint at epoch 13600
# Saved checkpoint at epoch 13620
# Saved checkpoint at epoch 13640
# Saved checkpoint at epoch 13660
# Saved checkpoint at epoch 13680
# Saved checkpoint at epoch 13700
# Saved checkpoint at epoch 13720
# Saved checkpoint at epoch 13740
# Saved checkpoint at epoch 13760
# Saved checkpoint at epoch 13780
# Saved checkpoint at epoch 13800
# Saved checkpoint at epoch 13820
# Saved checkpoint at epoch 13840
# Saved checkpoint at epoch 13860
# Saved checkpoint at epoch 13880
# Saved checkpoint at epoch 13900
# Saved checkpoint at epoch 13920
# Saved checkpoint at epoch 13940
# Saved checkpoint at epoch 13960
# Saved checkpoint at epoch 13980
# Saved checkpoint at epoch 14000
# Saved checkpoint at epoch 14020
# Saved checkpoint at epoch 14040
# Saved checkpoint at epoch 14060
# Saved checkpoint at epoch 14080
# Saved checkpoint at epoch 14100
# Saved checkpoint at epoch 14120
# Saved checkpoint at epoch 14140
# Saved checkpoint at epoch 14160
# Saved checkpoint at epoch 14180
# Saved checkpoint at epoch 14200
# Saved checkpoint at epoch 14220
# Saved checkpoint at epoch 14240
# Saved checkpoint at epoch 14260
# Saved checkpoint at epoch 14280
# Saved checkpoint at epoch 14300
# Saved checkpoint at epoch 14320
# Saved checkpoint at epoch 14340
# Saved checkpoint at epoch 14360
# Saved checkpoint at epoch 14380
# Saved checkpoint at epoch 14400
# Saved checkpoint at epoch 14420
# Saved checkpoint at epoch 14440
# Saved checkpoint at epoch 14460
# Saved checkpoint at epoch 14480
# Saved checkpoint at epoch 14500
# Saved checkpoint at epoch 14520
# Saved checkpoint at epoch 14540
# Saved checkpoint at epoch 14560
# Saved checkpoint at epoch 14580
# Saved checkpoint at epoch 14600
# Saved checkpoint at epoch 14620
# Saved checkpoint at epoch 14640
# Saved checkpoint at epoch 14660
# Saved checkpoint at epoch 14680
# Saved checkpoint at epoch 14700
# Saved checkpoint at epoch 14720
# Saved checkpoint at epoch 14740
# Saved checkpoint at epoch 14760
# Saved checkpoint at epoch 14780
# Saved checkpoint at epoch 14800
# Saved checkpoint at epoch 14820
# Saved checkpoint at epoch 14840
# Saved checkpoint at epoch 14860
# Saved checkpoint at epoch 14880
# Saved checkpoint at epoch 14900
# Saved checkpoint at epoch 14920
# Saved checkpoint at epoch 14940
# Saved checkpoint at epoch 14960
# Saved checkpoint at epoch 14980
# Saved checkpoint at epoch 15000
# Saved checkpoint at epoch 15020
# Saved checkpoint at epoch 15040
# Saved checkpoint at epoch 15060
# Saved checkpoint at epoch 15080
# Saved checkpoint at epoch 15100
# Saved checkpoint at epoch 15120
# Saved checkpoint at epoch 15140
# Saved checkpoint at epoch 15160
# Saved checkpoint at epoch 15180
# Saved checkpoint at epoch 15200
# Saved checkpoint at epoch 15220
# Saved checkpoint at epoch 15240
# Saved checkpoint at epoch 15260
# Saved checkpoint at epoch 15280
# Saved checkpoint at epoch 15300
# Saved checkpoint at epoch 15320
# Saved checkpoint at epoch 15340
# Saved checkpoint at epoch 15360
# Saved checkpoint at epoch 15380
# Saved checkpoint at epoch 15400
# Saved checkpoint at epoch 15420
# Saved checkpoint at epoch 15440
# Saved checkpoint at epoch 15460
# Saved checkpoint at epoch 15480
# Saved checkpoint at epoch 15500
# Saved checkpoint at epoch 15520
# Saved checkpoint at epoch 15540
# Saved checkpoint at epoch 15560
# Saved checkpoint at epoch 15580
# Saved checkpoint at epoch 15600
# Saved checkpoint at epoch 15620
# Saved checkpoint at epoch 15640
# Saved checkpoint at epoch 15660
# Saved checkpoint at epoch 15680
# Saved checkpoint at epoch 15700
# Saved checkpoint at epoch 15720
# Saved checkpoint at epoch 15740
# Saved checkpoint at epoch 15760
# Saved checkpoint at epoch 15780
# Saved checkpoint at epoch 15800
# Saved checkpoint at epoch 15820
# Saved checkpoint at epoch 15840
# Saved checkpoint at epoch 15860
# Saved checkpoint at epoch 15880
# Saved checkpoint at epoch 15900
# Saved checkpoint at epoch 15920
# Saved checkpoint at epoch 15940
# Saved checkpoint at epoch 15960
# Saved checkpoint at epoch 15980
# Saved checkpoint at epoch 16000
# Saved checkpoint at epoch 16020
# Saved checkpoint at epoch 16040
# Saved checkpoint at epoch 16060
# Saved checkpoint at epoch 16080
# Saved checkpoint at epoch 16100
# Saved checkpoint at epoch 16120
# Saved checkpoint at epoch 16140
# Saved checkpoint at epoch 16160
# Saved checkpoint at epoch 16180
# Saved checkpoint at epoch 16200
# Saved checkpoint at epoch 16220
# Saved checkpoint at epoch 16240
# Saved checkpoint at epoch 16260
# Saved checkpoint at epoch 16280
# Saved checkpoint at epoch 16300
# Saved checkpoint at epoch 16320
# Saved checkpoint at epoch 16340
# Saved checkpoint at epoch 16360
# Saved checkpoint at epoch 16380
# Saved checkpoint at epoch 16400
# Saved checkpoint at epoch 16420
# Saved checkpoint at epoch 16440
# Saved checkpoint at epoch 16460
# Saved checkpoint at epoch 16480
# Saved checkpoint at epoch 16500
# Saved checkpoint at epoch 16520
# Saved checkpoint at epoch 16540
# Saved checkpoint at epoch 16560
# Saved checkpoint at epoch 16580
# Saved checkpoint at epoch 16600
# Saved checkpoint at epoch 16620
# Saved checkpoint at epoch 16640
# Saved checkpoint at epoch 16660
# Saved checkpoint at epoch 16680
# Saved checkpoint at epoch 16700
# Saved checkpoint at epoch 16720
# Saved checkpoint at epoch 16740
# Saved checkpoint at epoch 16760
# Saved checkpoint at epoch 16780
# Saved checkpoint at epoch 16800
# Saved checkpoint at epoch 16820
# Saved checkpoint at epoch 16840
# Saved checkpoint at epoch 16860
# Saved checkpoint at epoch 16880
# Saved checkpoint at epoch 16900
# Saved checkpoint at epoch 16920
# Saved checkpoint at epoch 16940
# Saved checkpoint at epoch 16960
# Saved checkpoint at epoch 16980
# Saved checkpoint at epoch 17000
# Saved checkpoint at epoch 17020
# Saved checkpoint at epoch 17040
# Saved checkpoint at epoch 17060
# Saved checkpoint at epoch 17080
# Saved checkpoint at epoch 17100
# Saved checkpoint at epoch 17120
# Saved checkpoint at epoch 17140
# Saved checkpoint at epoch 17160
# Saved checkpoint at epoch 17180
# Saved checkpoint at epoch 17200
# Saved checkpoint at epoch 17220
# Saved checkpoint at epoch 17240
# Saved checkpoint at epoch 17260
# Saved checkpoint at epoch 17280
# Saved checkpoint at epoch 17300
# Saved checkpoint at epoch 17320
# Saved checkpoint at epoch 17340
# Saved checkpoint at epoch 17360
# Saved checkpoint at epoch 17380
# Saved checkpoint at epoch 17400
# Saved checkpoint at epoch 17420
# Saved checkpoint at epoch 17440
# Saved checkpoint at epoch 17460
# Saved checkpoint at epoch 17480
# Saved checkpoint at epoch 17500
# Saved checkpoint at epoch 17520
# Saved checkpoint at epoch 17540
# Saved checkpoint at epoch 17560
# Saved checkpoint at epoch 17580
# Saved checkpoint at epoch 17600
# Saved checkpoint at epoch 17620
# Saved checkpoint at epoch 17640
# Saved checkpoint at epoch 17660
# Saved checkpoint at epoch 17680
# Saved checkpoint at epoch 17700
# Saved checkpoint at epoch 17720
# Saved checkpoint at epoch 17740
# Saved checkpoint at epoch 17760
# Saved checkpoint at epoch 17780
# Saved checkpoint at epoch 17800
# Saved checkpoint at epoch 17820
# Saved checkpoint at epoch 17840
# Saved checkpoint at epoch 17860
# Saved checkpoint at epoch 17880
# Saved checkpoint at epoch 17900
# Saved checkpoint at epoch 17920
# Saved checkpoint at epoch 17940
# Saved checkpoint at epoch 17960
# Saved checkpoint at epoch 17980
# Saved checkpoint at epoch 18000
# Saved checkpoint at epoch 18020
# Saved checkpoint at epoch 18040
# Saved checkpoint at epoch 18060
# Saved checkpoint at epoch 18080
# Saved checkpoint at epoch 18100
# Saved checkpoint at epoch 18120
# Saved checkpoint at epoch 18140
# Saved checkpoint at epoch 18160
# Saved checkpoint at epoch 18180
# Saved checkpoint at epoch 18200
# Saved checkpoint at epoch 18220
# Saved checkpoint at epoch 18240
# Saved checkpoint at epoch 18260
# Saved checkpoint at epoch 18280
# Saved checkpoint at epoch 18300
# Saved checkpoint at epoch 18320
# Saved checkpoint at epoch 18340
# Saved checkpoint at epoch 18360
# Saved checkpoint at epoch 18380
# Saved checkpoint at epoch 18400
# Saved checkpoint at epoch 18420
# Saved checkpoint at epoch 18440
# Saved checkpoint at epoch 18460
# Saved checkpoint at epoch 18480
# Saved checkpoint at epoch 18500
# Saved checkpoint at epoch 18520
# Saved checkpoint at epoch 18540
# Saved checkpoint at epoch 18560
# Saved checkpoint at epoch 18580
# Saved checkpoint at epoch 18600
# Saved checkpoint at epoch 18620
# Saved checkpoint at epoch 18640
# Saved checkpoint at epoch 18660
# Saved checkpoint at epoch 18680
# Saved checkpoint at epoch 18700
# Saved checkpoint at epoch 18720
# Saved checkpoint at epoch 18740
# Saved checkpoint at epoch 18760
# Saved checkpoint at epoch 18780
# Saved checkpoint at epoch 18800
# Saved checkpoint at epoch 18820
# Saved checkpoint at epoch 18840
# Saved checkpoint at epoch 18860
# Saved checkpoint at epoch 18880
# Saved checkpoint at epoch 18900
# Saved checkpoint at epoch 18920
# Saved checkpoint at epoch 18940
# Saved checkpoint at epoch 18960
# Saved checkpoint at epoch 18980
# Saved checkpoint at epoch 19000
# Saved checkpoint at epoch 19020
# Saved checkpoint at epoch 19040
# Saved checkpoint at epoch 19060
# Saved checkpoint at epoch 19080
# Saved checkpoint at epoch 19100
# Saved checkpoint at epoch 19120
# Saved checkpoint at epoch 19140
# Saved checkpoint at epoch 19160
# Saved checkpoint at epoch 19180
# Saved checkpoint at epoch 19200
# Saved checkpoint at epoch 19220
# Saved checkpoint at epoch 19240
# Saved checkpoint at epoch 19260
# Saved checkpoint at epoch 19280
# Saved checkpoint at epoch 19300
# Saved checkpoint at epoch 19320
# Saved checkpoint at epoch 19340
# Saved checkpoint at epoch 19360
# Saved checkpoint at epoch 19380
# Saved checkpoint at epoch 19400
# Saved checkpoint at epoch 19420
# Saved checkpoint at epoch 19440
# Saved checkpoint at epoch 19460
# Saved checkpoint at epoch 19480
# Saved checkpoint at epoch 19500
# Saved checkpoint at epoch 19520
# Saved checkpoint at epoch 19540
# Saved checkpoint at epoch 19560
# Saved checkpoint at epoch 19580
# Saved checkpoint at epoch 19600
# Saved checkpoint at epoch 19620
# Saved checkpoint at epoch 19640
# Saved checkpoint at epoch 19660
# Saved checkpoint at epoch 19680
# Saved checkpoint at epoch 19700
# Saved checkpoint at epoch 19720
# Saved checkpoint at epoch 19740
# Saved checkpoint at epoch 19760
# Saved checkpoint at epoch 19780
# Saved checkpoint at epoch 19800
# Saved checkpoint at epoch 19820
# Saved checkpoint at epoch 19840
# Saved checkpoint at epoch 19860
# Saved checkpoint at epoch 19880
# Saved checkpoint at epoch 19900
# Saved checkpoint at epoch 19920
# Saved checkpoint at epoch 19940
# Saved checkpoint at epoch 19960
# Saved checkpoint at epoch 19980
# Saved checkpoint at epoch 20000
# Saved checkpoint at epoch 20020
# Saved checkpoint at epoch 20040
# Saved checkpoint at epoch 20060
# Saved checkpoint at epoch 20080
# Saved checkpoint at epoch 20100
# Saved checkpoint at epoch 20120
# Saved checkpoint at epoch 20140
# Saved checkpoint at epoch 20160
# Saved checkpoint at epoch 20180
# Saved checkpoint at epoch 20200
# Saved checkpoint at epoch 20220
# Saved checkpoint at epoch 20240
# Saved checkpoint at epoch 20260
# Saved checkpoint at epoch 20280
# Saved checkpoint at epoch 20300
# Saved checkpoint at epoch 20320
# Saved checkpoint at epoch 20340
# Saved checkpoint at epoch 20360
# Saved checkpoint at epoch 20380
# Saved checkpoint at epoch 20400
# Saved checkpoint at epoch 20420
# Saved checkpoint at epoch 20440
# Saved checkpoint at epoch 20460
# Saved checkpoint at epoch 20480
# Saved checkpoint at epoch 20500
# Saved checkpoint at epoch 20520
# Saved checkpoint at epoch 20540
# Saved checkpoint at epoch 20560
# Saved checkpoint at epoch 20580
# Saved checkpoint at epoch 20600
# Saved checkpoint at epoch 20620
# Saved checkpoint at epoch 20640
# Saved checkpoint at epoch 20660
# Saved checkpoint at epoch 20680
# Saved checkpoint at epoch 20700
# Saved checkpoint at epoch 20720
# Saved checkpoint at epoch 20740
# Saved checkpoint at epoch 20760
# Saved checkpoint at epoch 20780
# Saved checkpoint at epoch 20800
# Saved checkpoint at epoch 20820
# Saved checkpoint at epoch 20840
# Saved checkpoint at epoch 20860
# Saved checkpoint at epoch 20880
# Saved checkpoint at epoch 20900
# Saved checkpoint at epoch 20920
# Saved checkpoint at epoch 20940
# Saved checkpoint at epoch 20960
# Saved checkpoint at epoch 20980
# Saved checkpoint at epoch 21000
# Saved checkpoint at epoch 21020
# Saved checkpoint at epoch 21040
# Saved checkpoint at epoch 21060
# Saved checkpoint at epoch 21080
# Saved checkpoint at epoch 21100
# Saved checkpoint at epoch 21120
# Saved checkpoint at epoch 21140
# Saved checkpoint at epoch 21160
# Saved checkpoint at epoch 21180
# Saved checkpoint at epoch 21200
# Saved checkpoint at epoch 21220
# Saved checkpoint at epoch 21240
# Saved checkpoint at epoch 21260
# Saved checkpoint at epoch 21280
# Saved checkpoint at epoch 21300
# Saved checkpoint at epoch 21320
# Saved checkpoint at epoch 21340
# Saved checkpoint at epoch 21360
# Saved checkpoint at epoch 21380
# Saved checkpoint at epoch 21400
# Saved checkpoint at epoch 21420
# Saved checkpoint at epoch 21440
# Saved checkpoint at epoch 21460
# Saved checkpoint at epoch 21480
# Saved checkpoint at epoch 21500
# Saved checkpoint at epoch 21520
# Saved checkpoint at epoch 21540
# Saved checkpoint at epoch 21560
# Saved checkpoint at epoch 21580
# Saved checkpoint at epoch 21600
# Saved checkpoint at epoch 21620
# Saved checkpoint at epoch 21640
# Saved checkpoint at epoch 21660
# Saved checkpoint at epoch 21680
# Saved checkpoint at epoch 21700
# Saved checkpoint at epoch 21720
# Saved checkpoint at epoch 21740
# Saved checkpoint at epoch 21760
# Saved checkpoint at epoch 21780
# Saved checkpoint at epoch 21800
# Saved checkpoint at epoch 21820
# Saved checkpoint at epoch 21840
# Saved checkpoint at epoch 21860
# Saved checkpoint at epoch 21880
# Saved checkpoint at epoch 21900
# Saved checkpoint at epoch 21920
# Saved checkpoint at epoch 21940
# Saved checkpoint at epoch 21960
# Saved checkpoint at epoch 21980
# Saved checkpoint at epoch 22000
# Saved checkpoint at epoch 22020
# Saved checkpoint at epoch 22040
# Saved checkpoint at epoch 22060
# Saved checkpoint at epoch 22080
# Saved checkpoint at epoch 22100
# Saved checkpoint at epoch 22120
# Saved checkpoint at epoch 22140
# Saved checkpoint at epoch 22160
# Saved checkpoint at epoch 22180
# Saved checkpoint at epoch 22200
# Saved checkpoint at epoch 22220
# Saved checkpoint at epoch 22240
# Saved checkpoint at epoch 22260
# Saved checkpoint at epoch 22280
# Saved checkpoint at epoch 22300
# Saved checkpoint at epoch 22320
# Saved checkpoint at epoch 22340
# Saved checkpoint at epoch 22360
# Saved checkpoint at epoch 22380
# Saved checkpoint at epoch 22400
# Saved checkpoint at epoch 22420
# Saved checkpoint at epoch 22440
# Saved checkpoint at epoch 22460
# Saved checkpoint at epoch 22480
# Saved checkpoint at epoch 22500
# Saved checkpoint at epoch 22520
# Saved checkpoint at epoch 22540
# Saved checkpoint at epoch 22560
# Saved checkpoint at epoch 22580
# Saved checkpoint at epoch 22600
# Saved checkpoint at epoch 22620
# Saved checkpoint at epoch 22640
# Saved checkpoint at epoch 22660
# Saved checkpoint at epoch 22680
# Saved checkpoint at epoch 22700
# Saved checkpoint at epoch 22720
# Saved checkpoint at epoch 22740
# Saved checkpoint at epoch 22760
# Saved checkpoint at epoch 22780
# Saved checkpoint at epoch 22800
# Saved checkpoint at epoch 22820
# Saved checkpoint at epoch 22840
# Saved checkpoint at epoch 22860
# Saved checkpoint at epoch 22880
# Saved checkpoint at epoch 22900
# Saved checkpoint at epoch 22920
# Saved checkpoint at epoch 22940
# Saved checkpoint at epoch 22960
# Saved checkpoint at epoch 22980
# Saved checkpoint at epoch 23000
# Saved checkpoint at epoch 23020
# Saved checkpoint at epoch 23040
# Saved checkpoint at epoch 23060
# Saved checkpoint at epoch 23080
# Saved checkpoint at epoch 23100
# Saved checkpoint at epoch 23120
# Saved checkpoint at epoch 23140
# Saved checkpoint at epoch 23160
# Saved checkpoint at epoch 23180
# Saved checkpoint at epoch 23200
# Saved checkpoint at epoch 23220
# Saved checkpoint at epoch 23240
# Saved checkpoint at epoch 23260
# Saved checkpoint at epoch 23280
# Saved checkpoint at epoch 23300
# Saved checkpoint at epoch 23320
# Saved checkpoint at epoch 23340
# Saved checkpoint at epoch 23360
# Saved checkpoint at epoch 23380
# Saved checkpoint at epoch 23400
# Saved checkpoint at epoch 23420
# Saved checkpoint at epoch 23440
# Saved checkpoint at epoch 23460
# Saved checkpoint at epoch 23480
# Saved checkpoint at epoch 23500
# Saved checkpoint at epoch 23520
# Saved checkpoint at epoch 23540
# Saved checkpoint at epoch 23560
# Saved checkpoint at epoch 23580
# Saved checkpoint at epoch 23600
# Saved checkpoint at epoch 23620
# Saved checkpoint at epoch 23640
# Saved checkpoint at epoch 23660
# Saved checkpoint at epoch 23680
# Saved checkpoint at epoch 23700
# Saved checkpoint at epoch 23720
# Saved checkpoint at epoch 23740
# Saved checkpoint at epoch 23760
# Saved checkpoint at epoch 23780
# Saved checkpoint at epoch 23800
# Saved checkpoint at epoch 23820
# Saved checkpoint at epoch 23840
# Saved checkpoint at epoch 23860
# Saved checkpoint at epoch 23880
# Saved checkpoint at epoch 23900
# Saved checkpoint at epoch 23920
# Saved checkpoint at epoch 23940
# Saved checkpoint at epoch 23960
# Saved checkpoint at epoch 23980
# Saved checkpoint at epoch 24000
# Saved checkpoint at epoch 24020
# Saved checkpoint at epoch 24040
# Saved checkpoint at epoch 24060
# Saved checkpoint at epoch 24080
# Saved checkpoint at epoch 24100
# Saved checkpoint at epoch 24120
# Saved checkpoint at epoch 24140
# Saved checkpoint at epoch 24160
# Saved checkpoint at epoch 24180
# Saved checkpoint at epoch 24200
# Saved checkpoint at epoch 24220
# Saved checkpoint at epoch 24240
# Saved checkpoint at epoch 24260
# Saved checkpoint at epoch 24280
# Saved checkpoint at epoch 24300
# Saved checkpoint at epoch 24320
# Saved checkpoint at epoch 24340
# Saved checkpoint at epoch 24360
# Saved checkpoint at epoch 24380
# Saved checkpoint at epoch 24400
# Saved checkpoint at epoch 24420
# Saved checkpoint at epoch 24440
# Saved checkpoint at epoch 24460
# Saved checkpoint at epoch 24480
# Saved checkpoint at epoch 24500
# Saved checkpoint at epoch 24520
# Saved checkpoint at epoch 24540
# Saved checkpoint at epoch 24560
# Saved checkpoint at epoch 24580
# Saved checkpoint at epoch 24600
# Saved checkpoint at epoch 24620
# Saved checkpoint at epoch 24640
# Saved checkpoint at epoch 24660
# Saved checkpoint at epoch 24680
# Saved checkpoint at epoch 24700
# Saved checkpoint at epoch 24720
# Saved checkpoint at epoch 24740
# Saved checkpoint at epoch 24760
# Saved checkpoint at epoch 24780
# Saved checkpoint at epoch 24800
# Saved checkpoint at epoch 24820
# Saved checkpoint at epoch 24840
# Saved checkpoint at epoch 24860
# Saved checkpoint at epoch 24880
# Saved checkpoint at epoch 24900
# Saved checkpoint at epoch 24920
# Saved checkpoint at epoch 24940
# Saved checkpoint at epoch 24960
# Saved checkpoint at epoch 24980
# Saved checkpoint at epoch 25000
# Saved checkpoint at epoch 25020
# Saved checkpoint at epoch 25040
# Saved checkpoint at epoch 25060
# Saved checkpoint at epoch 25080
# Saved checkpoint at epoch 25100
# Saved checkpoint at epoch 25120
# Saved checkpoint at epoch 25140
# Saved checkpoint at epoch 25160
# Saved checkpoint at epoch 25180
# Saved checkpoint at epoch 25200
# Saved checkpoint at epoch 25220
# Saved checkpoint at epoch 25240
# Saved checkpoint at epoch 25260
# Saved checkpoint at epoch 25280
# Saved checkpoint at epoch 25300
# Saved checkpoint at epoch 25320
# Saved checkpoint at epoch 25340
# Saved checkpoint at epoch 25360
# Saved checkpoint at epoch 25380
# Saved checkpoint at epoch 25400
# Saved checkpoint at epoch 25420
# Saved checkpoint at epoch 25440
# Saved checkpoint at epoch 25460
# Saved checkpoint at epoch 25480
# Saved checkpoint at epoch 25500
# Saved checkpoint at epoch 25520
# Saved checkpoint at epoch 25540
# Saved checkpoint at epoch 25560
# Saved checkpoint at epoch 25580
# Saved checkpoint at epoch 25600
# Saved checkpoint at epoch 25620
# Saved checkpoint at epoch 25640
# Saved checkpoint at epoch 25660
# Saved checkpoint at epoch 25680
# Saved checkpoint at epoch 25700
# Saved checkpoint at epoch 25720
# Saved checkpoint at epoch 25740
# Saved checkpoint at epoch 25760
# Saved checkpoint at epoch 25780
# Saved checkpoint at epoch 25800
# Saved checkpoint at epoch 25820
# Saved checkpoint at epoch 25840
# Saved checkpoint at epoch 25860
# Saved checkpoint at epoch 25880
# Saved checkpoint at epoch 25900
# Saved checkpoint at epoch 25920
# Saved checkpoint at epoch 25940
# Saved checkpoint at epoch 25960
# Saved checkpoint at epoch 25980
# Saved checkpoint at epoch 26000
# Saved checkpoint at epoch 26020
# Saved checkpoint at epoch 26040
# Saved checkpoint at epoch 26060
# Saved checkpoint at epoch 26080
# Saved checkpoint at epoch 26100
# Saved checkpoint at epoch 26120
# Saved checkpoint at epoch 26140
# Saved checkpoint at epoch 26160
# Saved checkpoint at epoch 26180
# Saved checkpoint at epoch 26200
# Saved checkpoint at epoch 26220
# Saved checkpoint at epoch 26240
# Saved checkpoint at epoch 26260
# Saved checkpoint at epoch 26280
# Saved checkpoint at epoch 26300
# Saved checkpoint at epoch 26320
# Saved checkpoint at epoch 26340
# Saved checkpoint at epoch 26360
# Saved checkpoint at epoch 26380
# Saved checkpoint at epoch 26400
# Saved checkpoint at epoch 26420
# Saved checkpoint at epoch 26440
# Saved checkpoint at epoch 26460
# Saved checkpoint at epoch 26480
# Saved checkpoint at epoch 26500
# Saved checkpoint at epoch 26520
# Saved checkpoint at epoch 26540
# Saved checkpoint at epoch 26560
# Saved checkpoint at epoch 26580
# Saved checkpoint at epoch 26600
# Saved checkpoint at epoch 26620
# Saved checkpoint at epoch 26640
# Saved checkpoint at epoch 26660
# Saved checkpoint at epoch 26680
# Saved checkpoint at epoch 26700
# Saved checkpoint at epoch 26720
# Saved checkpoint at epoch 26740
# Saved checkpoint at epoch 26760
# Saved checkpoint at epoch 26780
# Saved checkpoint at epoch 26800
# Saved checkpoint at epoch 26820
# Saved checkpoint at epoch 26840
# Saved checkpoint at epoch 26860
# Saved checkpoint at epoch 26880
# Saved checkpoint at epoch 26900
# Saved checkpoint at epoch 26920
# Saved checkpoint at epoch 26940
# Saved checkpoint at epoch 26960
# Saved checkpoint at epoch 26980
# Saved checkpoint at epoch 27000
# Saved checkpoint at epoch 27020
# Saved checkpoint at epoch 27040
# Saved checkpoint at epoch 27060
# Saved checkpoint at epoch 27080
# Saved checkpoint at epoch 27100
# Saved checkpoint at epoch 27120
# Saved checkpoint at epoch 27140
# Saved checkpoint at epoch 27160
# Saved checkpoint at epoch 27180
# Saved checkpoint at epoch 27200
# Saved checkpoint at epoch 27220
# Saved checkpoint at epoch 27240
# Saved checkpoint at epoch 27260
# Saved checkpoint at epoch 27280
# Saved checkpoint at epoch 27300
# Saved checkpoint at epoch 27320
# Saved checkpoint at epoch 27340
# Saved checkpoint at epoch 27360
# Saved checkpoint at epoch 27380
# Saved checkpoint at epoch 27400
# Saved checkpoint at epoch 27420
# Saved checkpoint at epoch 27440
# Saved checkpoint at epoch 27460
# Saved checkpoint at epoch 27480
# Saved checkpoint at epoch 27500
# Saved checkpoint at epoch 27520
# Saved checkpoint at epoch 27540
# Saved checkpoint at epoch 27560
# Saved checkpoint at epoch 27580
# Saved checkpoint at epoch 27600
# Saved checkpoint at epoch 27620
# Saved checkpoint at epoch 27640
# Saved checkpoint at epoch 27660
# Saved checkpoint at epoch 27680
# Saved checkpoint at epoch 27700
# Saved checkpoint at epoch 27720
# Saved checkpoint at epoch 27740
# Saved checkpoint at epoch 27760
# Saved checkpoint at epoch 27780
# Saved checkpoint at epoch 27800
# Saved checkpoint at epoch 27820
# Saved checkpoint at epoch 27840
# Saved checkpoint at epoch 27860
# Saved checkpoint at epoch 27880
# Saved checkpoint at epoch 27900
# Saved checkpoint at epoch 27920
# Saved checkpoint at epoch 27940
# Saved checkpoint at epoch 27960
# Saved checkpoint at epoch 27980
# Saved checkpoint at epoch 28000
# Saved checkpoint at epoch 28020
# Saved checkpoint at epoch 28040
# Saved checkpoint at epoch 28060
# Saved checkpoint at epoch 28080
# Saved checkpoint at epoch 28100
# Saved checkpoint at epoch 28120
# Saved checkpoint at epoch 28140
# Saved checkpoint at epoch 28160
# Saved checkpoint at epoch 28180
# Saved checkpoint at epoch 28200
# Saved checkpoint at epoch 28220
# Saved checkpoint at epoch 28240
# Saved checkpoint at epoch 28260
# Saved checkpoint at epoch 28280
# Saved checkpoint at epoch 28300
# Saved checkpoint at epoch 28320
# Saved checkpoint at epoch 28340
# Saved checkpoint at epoch 28360
# Saved checkpoint at epoch 28380
# Saved checkpoint at epoch 28400
# Saved checkpoint at epoch 28420
# Saved checkpoint at epoch 28440
# Saved checkpoint at epoch 28460
# Saved checkpoint at epoch 28480
# Saved checkpoint at epoch 28500
# Saved checkpoint at epoch 28520
# Saved checkpoint at epoch 28540
# Saved checkpoint at epoch 28560
# Saved checkpoint at epoch 28580
# Saved checkpoint at epoch 28600
# Saved checkpoint at epoch 28620
# Saved checkpoint at epoch 28640
# Saved checkpoint at epoch 28660
# Saved checkpoint at epoch 28680
# Saved checkpoint at epoch 28700
# Saved checkpoint at epoch 28720
# Saved checkpoint at epoch 28740
# Saved checkpoint at epoch 28760
# Saved checkpoint at epoch 28780
# Saved checkpoint at epoch 28800
# Saved checkpoint at epoch 28820
# Saved checkpoint at epoch 28840
# Saved checkpoint at epoch 28860
# Saved checkpoint at epoch 28880
# Saved checkpoint at epoch 28900
# Saved checkpoint at epoch 28920
# Saved checkpoint at epoch 28940
# Saved checkpoint at epoch 28960
# Saved checkpoint at epoch 28980
# Saved checkpoint at epoch 29000
# Saved checkpoint at epoch 29020
# Saved checkpoint at epoch 29040
# Saved checkpoint at epoch 29060
# Saved checkpoint at epoch 29080
# Saved checkpoint at epoch 29100
# Saved checkpoint at epoch 29120
# Saved checkpoint at epoch 29140
# Saved checkpoint at epoch 29160
# Saved checkpoint at epoch 29180
# Saved checkpoint at epoch 29200
# Saved checkpoint at epoch 29220
# Saved checkpoint at epoch 29240
# Saved checkpoint at epoch 29260
# Saved checkpoint at epoch 29280
# Saved checkpoint at epoch 29300
# Saved checkpoint at epoch 29320
# Saved checkpoint at epoch 29340
# Saved checkpoint at epoch 29360
# Saved checkpoint at epoch 29380
# Saved checkpoint at epoch 29400
# Saved checkpoint at epoch 29420
# Saved checkpoint at epoch 29440
# Saved checkpoint at epoch 29460
# Saved checkpoint at epoch 29480
# Saved checkpoint at epoch 29500
# Saved checkpoint at epoch 29520
# Saved checkpoint at epoch 29540
# Saved checkpoint at epoch 29560
# Saved checkpoint at epoch 29580
# Saved checkpoint at epoch 29600
# Saved checkpoint at epoch 29620
# Saved checkpoint at epoch 29640
# Saved checkpoint at epoch 29660
# Saved checkpoint at epoch 29680
# Saved checkpoint at epoch 29700
# Saved checkpoint at epoch 29720
# Saved checkpoint at epoch 29740
# Saved checkpoint at epoch 29760
# Saved checkpoint at epoch 29780
# Saved checkpoint at epoch 29800
# Saved checkpoint at epoch 29820
# Saved checkpoint at epoch 29840
# Saved checkpoint at epoch 29860
# Saved checkpoint at epoch 29880
# Saved checkpoint at epoch 29900
# Saved checkpoint at epoch 29920
# Saved checkpoint at epoch 29940
# Saved checkpoint at epoch 29960
# Saved checkpoint at epoch 29980
# Saved checkpoint at epoch 30000
# Saved checkpoint at epoch 30020
# Saved checkpoint at epoch 30040
# Saved checkpoint at epoch 30060
# Saved checkpoint at epoch 30080
# Saved checkpoint at epoch 30100
# Saved checkpoint at epoch 30120
# Saved checkpoint at epoch 30140
# Saved checkpoint at epoch 30160
# Saved checkpoint at epoch 30180
# Saved checkpoint at epoch 30200
# Saved checkpoint at epoch 30220
# Saved checkpoint at epoch 30240
# Saved checkpoint at epoch 30260
# Saved checkpoint at epoch 30280
# Saved checkpoint at epoch 30300
# Saved checkpoint at epoch 30320
# Saved checkpoint at epoch 30340
# Saved checkpoint at epoch 30360
# Saved checkpoint at epoch 30380
# Saved checkpoint at epoch 30400
# Saved checkpoint at epoch 30420
# Saved checkpoint at epoch 30440
# Saved checkpoint at epoch 30460
# Saved checkpoint at epoch 30480
# Saved checkpoint at epoch 30500
# Saved checkpoint at epoch 30520
# Saved checkpoint at epoch 30540
# ...
# Saved checkpoint at epoch 40060
# Saved checkpoint at epoch 40080
# Saved checkpoint at epoch 40100
# Saved checkpoint at epoch 40120
# Saved checkpoint at epoch 40140
# Saved checkpoint at epoch 40160
# Saved checkpoint at epoch 40180
# Saved checkpoint at epoch 40200
# Saved checkpoint at epoch 40220
# Saved checkpoint at epoch 40240
# Saved checkpoint at epoch 40260
# Saved checkpoint at epoch 40280
# Saved checkpoint at epoch 40300
# Saved checkpoint at epoch 40320
# Saved checkpoint at epoch 40340
# Saved checkpoint at epoch 40360
# Saved checkpoint at epoch 40380
# Saved checkpoint at epoch 40400
# Saved checkpoint at epoch 40420
# Saved checkpoint at epoch 40440
# Saved checkpoint at epoch 40460
# Saved checkpoint at epoch 40480
# Saved checkpoint at epoch 40500
# Saved checkpoint at epoch 40520
# Saved checkpoint at epoch 40540
# Saved checkpoint at epoch 40560
# Saved checkpoint at epoch 40580
# Saved checkpoint at epoch 40600
# Saved checkpoint at epoch 40620
# Saved checkpoint at epoch 40640
# Saved checkpoint at epoch 40660
# Saved checkpoint at epoch 40680
# Saved checkpoint at epoch 40700
# Saved checkpoint at epoch 40720
# Saved checkpoint at epoch 40740
# Saved checkpoint at epoch 40760
# Saved checkpoint at epoch 40780
# Saved checkpoint at epoch 40800
# Saved checkpoint at epoch 40820
# Saved checkpoint at epoch 40840
# Saved checkpoint at epoch 40860
# Saved checkpoint at epoch 40880
# Saved checkpoint at epoch 40900
# Saved checkpoint at epoch 40920
# Saved checkpoint at epoch 40940
# Saved checkpoint at epoch 40960
# Saved checkpoint at epoch 40980
# Saved checkpoint at epoch 41000
# Saved checkpoint at epoch 41020
# Saved checkpoint at epoch 41040
# Saved checkpoint at epoch 41060
# Saved checkpoint at epoch 41080
# Saved checkpoint at epoch 41100
# Saved checkpoint at epoch 41120
# Saved checkpoint at epoch 41140
# Saved checkpoint at epoch 41160
# Saved checkpoint at epoch 41180
# Saved checkpoint at epoch 41200
# Saved checkpoint at epoch 41220
# Saved checkpoint at epoch 41240
# Saved checkpoint at epoch 41260
# Saved checkpoint at epoch 41280
# Saved checkpoint at epoch 41300
# Saved checkpoint at epoch 41320
# Saved checkpoint at epoch 41340
# Saved checkpoint at epoch 41360
# Saved checkpoint at epoch 41380
# Saved checkpoint at epoch 41400
# Saved checkpoint at epoch 41420
# Saved checkpoint at epoch 41440
# Saved checkpoint at epoch 41460
# Saved checkpoint at epoch 41480
# Saved checkpoint at epoch 41500
# Saved checkpoint at epoch 41520
# Saved checkpoint at epoch 41540
# Saved checkpoint at epoch 41560
# Saved checkpoint at epoch 41580
# Saved checkpoint at epoch 41600
# Saved checkpoint at epoch 41620
# Saved checkpoint at epoch 41640
# Saved checkpoint at epoch 41660
# Saved checkpoint at epoch 41680
# Saved checkpoint at epoch 41700
# Saved checkpoint at epoch 41720
# Saved checkpoint at epoch 41740
# Saved checkpoint at epoch 41760
# Saved checkpoint at epoch 41780
# Saved checkpoint at epoch 41800
# Saved checkpoint at epoch 41820
# Saved checkpoint at epoch 41840
# Saved checkpoint at epoch 41860
# Saved checkpoint at epoch 41880
# Saved checkpoint at epoch 41900
# Saved checkpoint at epoch 41920
# Saved checkpoint at epoch 41940
# Saved checkpoint at epoch 41960
# Saved checkpoint at epoch 41980
# Saved checkpoint at epoch 42000
# Saved checkpoint at epoch 42020
# Saved checkpoint at epoch 42040
# Saved checkpoint at epoch 42060
# Saved checkpoint at epoch 42080
# Saved checkpoint at epoch 42100
# Saved checkpoint at epoch 42120
# Saved checkpoint at epoch 42140
# Saved checkpoint at epoch 42160
# Saved checkpoint at epoch 42180
# Saved checkpoint at epoch 42200
# Saved checkpoint at epoch 42220
# Saved checkpoint at epoch 42240
# Saved checkpoint at epoch 42260
# Saved checkpoint at epoch 42280
# Saved checkpoint at epoch 42300
# Saved checkpoint at epoch 42320
# Saved checkpoint at epoch 42340
# Saved checkpoint at epoch 42360
# Saved checkpoint at epoch 42380
# Saved checkpoint at epoch 42400
# Saved checkpoint at epoch 42420
# Saved checkpoint at epoch 42440
# Saved checkpoint at epoch 42460
# Saved checkpoint at epoch 42480
# Saved checkpoint at epoch 42500
# Saved checkpoint at epoch 42520
# Saved checkpoint at epoch 42540
# Saved checkpoint at epoch 42560
# Saved checkpoint at epoch 42580
# Saved checkpoint at epoch 42600
# Saved checkpoint at epoch 42620
# Saved checkpoint at epoch 42640
# Saved checkpoint at epoch 42660
# Saved checkpoint at epoch 42680
# Saved checkpoint at epoch 42700
# Saved checkpoint at epoch 42720
# Saved checkpoint at epoch 42740
# Saved checkpoint at epoch 42760
# Saved checkpoint at epoch 42780
# Saved checkpoint at epoch 42800
# Saved checkpoint at epoch 42820
# Saved checkpoint at epoch 42840
# Saved checkpoint at epoch 42860
# Saved checkpoint at epoch 42880
# Saved checkpoint at epoch 42900
# Saved checkpoint at epoch 42920
# Saved checkpoint at epoch 42940
# Saved checkpoint at epoch 42960
# Saved checkpoint at epoch 42980
# Saved checkpoint at epoch 43000
# Saved checkpoint at epoch 43020
# Saved checkpoint at epoch 43040
# Saved checkpoint at epoch 43060
# Saved checkpoint at epoch 43080
# Saved checkpoint at epoch 43100
# Saved checkpoint at epoch 43120
# Saved checkpoint at epoch 43140
# Saved checkpoint at epoch 43160
# Saved checkpoint at epoch 43180
# Saved checkpoint at epoch 43200
# Saved checkpoint at epoch 43220
# Saved checkpoint at epoch 43240
# Saved checkpoint at epoch 43260
# Saved checkpoint at epoch 43280
# Saved checkpoint at epoch 43300
# Saved checkpoint at epoch 43320
# Saved checkpoint at epoch 43340
# Saved checkpoint at epoch 43360
# Saved checkpoint at epoch 43380
# Saved checkpoint at epoch 43400
# Saved checkpoint at epoch 43420
# Saved checkpoint at epoch 43440
# Saved checkpoint at epoch 43460
# Saved checkpoint at epoch 43480
# Saved checkpoint at epoch 43500
# Saved checkpoint at epoch 43520
# Saved checkpoint at epoch 43540
# Saved checkpoint at epoch 43560
# Saved checkpoint at epoch 43580
# Saved checkpoint at epoch 43600
# Saved checkpoint at epoch 43620
# Saved checkpoint at epoch 43640
# Saved checkpoint at epoch 43660
# Saved checkpoint at epoch 43680
# Saved checkpoint at epoch 43700
# Saved checkpoint at epoch 43720
# Saved checkpoint at epoch 43740
# Saved checkpoint at epoch 43760
# Saved checkpoint at epoch 43780
# Saved checkpoint at epoch 43800
# Saved checkpoint at epoch 43820
# Saved checkpoint at epoch 43840
# Saved checkpoint at epoch 43860
# Saved checkpoint at epoch 43880
# Saved checkpoint at epoch 43900
# Saved checkpoint at epoch 43920
# Saved checkpoint at epoch 43940
# Saved checkpoint at epoch 43960
# Saved checkpoint at epoch 43980
# Saved checkpoint at epoch 44000
# Saved checkpoint at epoch 44020
# Saved checkpoint at epoch 44040
# Saved checkpoint at epoch 44060
# Saved checkpoint at epoch 44080
# Saved checkpoint at epoch 44100
# Saved checkpoint at epoch 44120
# Saved checkpoint at epoch 44140
# Saved checkpoint at epoch 44160
# Saved checkpoint at epoch 44180
# Saved checkpoint at epoch 44200
# Saved checkpoint at epoch 44220
# Saved checkpoint at epoch 44240
# Saved checkpoint at epoch 44260
# Saved checkpoint at epoch 44280
# Saved checkpoint at epoch 44300
# Saved checkpoint at epoch 44320
# Saved checkpoint at epoch 44340
# Saved checkpoint at epoch 44360
# Saved checkpoint at epoch 44380
# Saved checkpoint at epoch 44400
# Saved checkpoint at epoch 44420
# Saved checkpoint at epoch 44440
# Saved checkpoint at epoch 44460
# Saved checkpoint at epoch 44480
# Saved checkpoint at epoch 44500
# Saved checkpoint at epoch 44520
# Saved checkpoint at epoch 44540
# Saved checkpoint at epoch 44560
# Saved checkpoint at epoch 44580
# Saved checkpoint at epoch 44600
# Saved checkpoint at epoch 44620
# Saved checkpoint at epoch 44640
# Saved checkpoint at epoch 44660
# Saved checkpoint at epoch 44680
# Saved checkpoint at epoch 44700
# Saved checkpoint at epoch 44720
# Saved checkpoint at epoch 44740
# Saved checkpoint at epoch 44760
# Saved checkpoint at epoch 44780
# Saved checkpoint at epoch 44800
# Saved checkpoint at epoch 44820
# Saved checkpoint at epoch 44840
# Saved checkpoint at epoch 44860
# Saved checkpoint at epoch 44880
# Saved checkpoint at epoch 44900
# Saved checkpoint at epoch 44920
# Saved checkpoint at epoch 44940
# Saved checkpoint at epoch 44960
# Saved checkpoint at epoch 44980
# Saved checkpoint at epoch 45000
# Saved checkpoint at epoch 45020
# Saved checkpoint at epoch 45040
# Saved checkpoint at epoch 45060
# Saved checkpoint at epoch 45080
# Saved checkpoint at epoch 45100
# Saved checkpoint at epoch 45120
# Saved checkpoint at epoch 45140
# Saved checkpoint at epoch 45160
# Saved checkpoint at epoch 45180
# Saved checkpoint at epoch 45200
# Saved checkpoint at epoch 45220
# Saved checkpoint at epoch 45240
# Saved checkpoint at epoch 45260
# Saved checkpoint at epoch 45280
# Saved checkpoint at epoch 45300
# Saved checkpoint at epoch 45320
# Saved checkpoint at epoch 45340
# Saved checkpoint at epoch 45360
# Saved checkpoint at epoch 45380
# Saved checkpoint at epoch 45400
# Saved checkpoint at epoch 45420
# Saved checkpoint at epoch 45440
# Saved checkpoint at epoch 45460
# Saved checkpoint at epoch 45480
# Saved checkpoint at epoch 45500
# Saved checkpoint at epoch 45520
# Saved checkpoint at epoch 45540
# Saved checkpoint at epoch 45560
# Saved checkpoint at epoch 45580
# Saved checkpoint at epoch 45600
# Saved checkpoint at epoch 45620
# Saved checkpoint at epoch 45640
# Saved checkpoint at epoch 45660
# Saved checkpoint at epoch 45680
# Saved checkpoint at epoch 45700
# Saved checkpoint at epoch 45720
# Saved checkpoint at epoch 45740
# Saved checkpoint at epoch 45760
# Saved checkpoint at epoch 45780
# Saved checkpoint at epoch 45800
# Saved checkpoint at epoch 45820
# Saved checkpoint at epoch 45840
# Saved checkpoint at epoch 45860
# Saved checkpoint at epoch 45880
# Saved checkpoint at epoch 45900
# Saved checkpoint at epoch 45920
# Saved checkpoint at epoch 45940
# Saved checkpoint at epoch 45960
# Saved checkpoint at epoch 45980
# Saved checkpoint at epoch 46000
# Saved checkpoint at epoch 46020
# Saved checkpoint at epoch 46040
# Saved checkpoint at epoch 46060
# Saved checkpoint at epoch 46080
# Saved checkpoint at epoch 46100
# Saved checkpoint at epoch 46120
# Saved checkpoint at epoch 46140
# Saved checkpoint at epoch 46160
# Saved checkpoint at epoch 46180
# Saved checkpoint at epoch 46200
# Saved checkpoint at epoch 46220
# Saved checkpoint at epoch 46240
# Saved checkpoint at epoch 46260
# Saved checkpoint at epoch 46280
# Saved checkpoint at epoch 46300
# Saved checkpoint at epoch 46320
# Saved checkpoint at epoch 46340
# Saved checkpoint at epoch 46360
# Saved checkpoint at epoch 46380
# Saved checkpoint at epoch 46400
# Saved checkpoint at epoch 46420
# Saved checkpoint at epoch 46440
# Saved checkpoint at epoch 46460
# Saved checkpoint at epoch 46480
# Saved checkpoint at epoch 46500
# Saved checkpoint at epoch 46520
# Saved checkpoint at epoch 46540
# Saved checkpoint at epoch 46560
# Saved checkpoint at epoch 46580
# Saved checkpoint at epoch 46600
# Saved checkpoint at epoch 46620
# Saved checkpoint at epoch 46640
# Saved checkpoint at epoch 46660
# Saved checkpoint at epoch 46680
# Saved checkpoint at epoch 46700
# Saved checkpoint at epoch 46720
# Saved checkpoint at epoch 46740
# Saved checkpoint at epoch 46760
# Saved checkpoint at epoch 46780
# Saved checkpoint at epoch 46800
# Saved checkpoint at epoch 46820
# Saved checkpoint at epoch 46840
# Saved checkpoint at epoch 46860
# Saved checkpoint at epoch 46880
# Saved checkpoint at epoch 46900
# Saved checkpoint at epoch 46920
# Saved checkpoint at epoch 46940
# Saved checkpoint at epoch 46960
# Saved checkpoint at epoch 46980
# Saved checkpoint at epoch 47000
# Saved checkpoint at epoch 47020
# Saved checkpoint at epoch 47040
# Saved checkpoint at epoch 47060
# Saved checkpoint at epoch 47080
# Saved checkpoint at epoch 47100
# Saved checkpoint at epoch 47120
# Saved checkpoint at epoch 47140
# Saved checkpoint at epoch 47160
# Saved checkpoint at epoch 47180
# Saved checkpoint at epoch 47200
# Saved checkpoint at epoch 47220
# Saved checkpoint at epoch 47240
# Saved checkpoint at epoch 47260
# Saved checkpoint at epoch 47280
# Saved checkpoint at epoch 47300
# Saved checkpoint at epoch 47320
# Saved checkpoint at epoch 47340
# Saved checkpoint at epoch 47360
# Saved checkpoint at epoch 47380
# Saved checkpoint at epoch 47400
# Saved checkpoint at epoch 47420
# Saved checkpoint at epoch 47440
# Saved checkpoint at epoch 47460
# Saved checkpoint at epoch 47480
# Saved checkpoint at epoch 47500
# Saved checkpoint at epoch 47520
# Saved checkpoint at epoch 47540
# Saved checkpoint at epoch 47560
# Saved checkpoint at epoch 47580
# Saved checkpoint at epoch 47600
# Saved checkpoint at epoch 47620
# Saved checkpoint at epoch 47640
# Saved checkpoint at epoch 47660
# Saved checkpoint at epoch 47680
# Saved checkpoint at epoch 47700
# Saved checkpoint at epoch 47720
# Saved checkpoint at epoch 47740
# Saved checkpoint at epoch 47760
# Saved checkpoint at epoch 47780
# Saved checkpoint at epoch 47800
# Saved checkpoint at epoch 47820
# Saved checkpoint at epoch 47840
# Saved checkpoint at epoch 47860
# Saved checkpoint at epoch 47880
# Saved checkpoint at epoch 47900
# Saved checkpoint at epoch 47920
# Saved checkpoint at epoch 47940
# Saved checkpoint at epoch 47960
# Saved checkpoint at epoch 47980
# Saved checkpoint at epoch 48000
# Saved checkpoint at epoch 48020
# Saved checkpoint at epoch 48040
# Saved checkpoint at epoch 48060
# Saved checkpoint at epoch 48080
# Saved checkpoint at epoch 48100
# Saved checkpoint at epoch 48120
# Saved checkpoint at epoch 48140
# Saved checkpoint at epoch 48160
# Saved checkpoint at epoch 48180
# Saved checkpoint at epoch 48200
# Saved checkpoint at epoch 48220
# Saved checkpoint at epoch 48240
# Saved checkpoint at epoch 48260
# Saved checkpoint at epoch 48280
# Saved checkpoint at epoch 48300
# Saved checkpoint at epoch 48320
# Saved checkpoint at epoch 48340
# Saved checkpoint at epoch 48360
# Saved checkpoint at epoch 48380
# Saved checkpoint at epoch 48400
# Saved checkpoint at epoch 48420
# Saved checkpoint at epoch 48440
# Saved checkpoint at epoch 48460
# Saved checkpoint at epoch 48480
# Saved checkpoint at epoch 48500
# Saved checkpoint at epoch 48520
# Saved checkpoint at epoch 48540
# Saved checkpoint at epoch 48560
# Saved checkpoint at epoch 48580
# Saved checkpoint at epoch 48600
# Saved checkpoint at epoch 48620
# Saved checkpoint at epoch 48640
# Saved checkpoint at epoch 48660
# Saved checkpoint at epoch 48680
# Saved checkpoint at epoch 48700
# Saved checkpoint at epoch 48720
# Saved checkpoint at epoch 48740
# Saved checkpoint at epoch 48760
# Saved checkpoint at epoch 48780
# Saved checkpoint at epoch 48800
# Saved checkpoint at epoch 48820
# Saved checkpoint at epoch 48840
# Saved checkpoint at epoch 48860
# Saved checkpoint at epoch 48880
# Saved checkpoint at epoch 48900
# Saved checkpoint at epoch 48920
# Saved checkpoint at epoch 48940
# Saved checkpoint at epoch 48960
# Saved checkpoint at epoch 48980
# Saved checkpoint at epoch 49000
# Saved checkpoint at epoch 49020
# Saved checkpoint at epoch 49040
# Saved checkpoint at epoch 49060
# Saved checkpoint at epoch 49080
# Saved checkpoint at epoch 49100
# Saved checkpoint at epoch 49120
# Saved checkpoint at epoch 49140
# Saved checkpoint at epoch 49160
# Saved checkpoint at epoch 49180
# Saved checkpoint at epoch 49200
# Saved checkpoint at epoch 49220
# Saved checkpoint at epoch 49240
# Saved checkpoint at epoch 49260
# Saved checkpoint at epoch 49280
# Saved checkpoint at epoch 49300
# Saved checkpoint at epoch 49320
# Saved checkpoint at epoch 49340
# Saved checkpoint at epoch 49360
# Saved checkpoint at epoch 49380
# Saved checkpoint at epoch 49400
# Saved checkpoint at epoch 49420
# Saved checkpoint at epoch 49440
# Saved checkpoint at epoch 49460
# Saved checkpoint at epoch 49480
# Saved checkpoint at epoch 49500
# Saved checkpoint at epoch 49520
# Saved checkpoint at epoch 49540
# Saved checkpoint at epoch 49560
# Saved checkpoint at epoch 49580
# Saved checkpoint at epoch 49600
# Saved checkpoint at epoch 49620
# Saved checkpoint at epoch 49640
# Saved checkpoint at epoch 49660
# Saved checkpoint at epoch 49680
# Saved checkpoint at epoch 49700
# Saved checkpoint at epoch 49720
# Saved checkpoint at epoch 49740
# Saved checkpoint at epoch 49760
# Saved checkpoint at epoch 49780
# Saved checkpoint at epoch 49800
# Saved checkpoint at epoch 49820
# Saved checkpoint at epoch 49840
# Saved checkpoint at epoch 49860
# Saved checkpoint at epoch 49880
# Saved checkpoint at epoch 49900
# Saved checkpoint at epoch 49920
# Saved checkpoint at epoch 49940
# Saved checkpoint at epoch 49960
# Saved checkpoint at epoch 49980
# Saved checkpoint at epoch 50000
#   Final loss: 0.000003
#
# All topology experiments complete!

# %%
# Plot all topologies with fixed layers (1)
plt.figure(figsize=(12, 6))

for n_neurons in neurons_range:
    n_hidden = 1
    loss_hist = topology_results[(n_hidden, n_neurons)]
    plt.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Neurons (1 hidden layer, Seed=0)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %%
import plotly.graph_objects as go

# Create a grid over the input space
grid_size = 50
q1_range = np.linspace(-1, 1, grid_size)
q2_range = np.linspace(-1, 1, grid_size)
Q1_grid, Q2_grid = np.meshgrid(q1_range, q2_range)

# Calculate error at each point
error_grid = np.zeros_like(Q1_grid)

for i in range(grid_size):
    for j in range(grid_size):
        test_input = np.array([Q1_grid[i, j], Q2_grid[i, j]])
        activations, _ = net.forward(test_input)
        predicted = activations[-1]
        expected = np.array(target_function(test_input[0], test_input[1]))
        error = np.sum((predicted - expected)**2)
        error_grid[i, j] = error

# Create interactive 3D plot
fig = go.Figure(data=[go.Surface(
    x=Q1_grid,
    y=Q2_grid,
    z=error_grid,
    colorscale='Viridis',
    colorbar=dict(title='Error')
)])

fig.update_layout(
    title='Network Error Over Input Space',
    scene=dict(
        xaxis_title='q1',
        yaxis_title='q2',
        zaxis_title='Error',
        zaxis=dict(exponentformat='power')
    ),
    width=800,
    height=700
)

fig.show()

print(f"Max error: {np.max(error_grid):.6f}")
print(f"Mean error: {np.mean(error_grid):.6f}")
# Out:
# Max error: 0.000254
# Mean error: 0.000007
