# %% [markdown]
# # Network Comparison Experiments
#
# This notebook compares training results across different seeds and network topologies.
#
# - Seed comparison: Train 5 networks with seeds 0-4
# - Topology comparison: Vary hidden layers (1-7) and neurons (1-8) with seed=0
# - Both experiments share cached checkpoints where topologies and seeds overlap

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt

from lib import (
    Net, NetConfig,
    SymbolicActivation, SymbolicLoss, WeightInit,
    CheckpointConfig, compute_data_hash
)

# %%
# Generate training data
np.random.seed(42)

q1 = np.random.uniform(-1, 1, 1000)
q2 = np.random.uniform(-1, 1, 1000)

def target_function(q1, q2):
    X1 = q1 + (q2**2) - 1
    X2 = q1 - q2 + 1
    return X1, X2

X1, X2 = target_function(q1, q2)

inputs = [[q1[i], q2[i]] for i in range(len(q1))]
targets = [[X1[i], X2[i]] for i in range(len(X1))]

inputs = np.array(inputs)
targets = np.array(targets)

input_list = [inputs[i] for i in range(len(inputs))]
target_list = [targets[i] for i in range(len(targets))]

print(f"Generated {len(inputs)} training samples")
print(f"Input shape: {inputs.shape}")
print(f"Target shape: {targets.shape}")
# Out:
# Generated 1000 training samples
# Input shape: (1000, 2)
# Target shape: (1000, 2)

# %%
# Compute hash for training data (enables checkpoint sharing)
data_hash = compute_data_hash(input_list, target_list)
print(f"Data hash: {data_hash}")

# Configure checkpointing
checkpoint_config = CheckpointConfig(
    enabled=True,
    cache_dir='.net_cache',
    checkpoint_interval=20,
    data_hash=data_hash,
    overwrite=False
)
print("Checkpointing enabled")
# Out:
# Data hash: a1ef014a45550963
# Checkpointing enabled

# %% [markdown]
# ## Seed Comparison
#
# Train 5 networks with seeds 0 to 4 to see effect of random initialization.

# %%
seed_results = {}
seeds = range(5)
epochs = 300
learning_rate = 0.01

for seed in seeds:
    print(f"Training with seed={seed}...")
    
    config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
        n_inputs=2,
        n_outputs=2,
        n_hidden_layers=2,
        n_neurons_per_hidden=4,
        loss_func=SymbolicLoss.mse(),
        weight_init=WeightInit.XAVIER,
        bias_init_std=0.01,
        seed=seed
    )
    
    net = Net.fully_connected(config)
    
    result = net.train(
        inputs=input_list,
        targets=target_list,
        learning_rate=learning_rate,
        epochs=epochs,
        batch_size=32,
        checkpoint_config=checkpoint_config
    )
    
    seed_results[seed] = result['loss_history']
    print(f"  Seed {seed}: final loss = {result['loss_history'][-1]:.6f}")

print("\nAll seed experiments complete!")
# Out:
# Training with seed=0...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Seed 0: final loss = 0.002078
# Training with seed=1...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Seed 1: final loss = 0.001486
# Training with seed=2...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Seed 2: final loss = 0.001266
# Training with seed=3...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Seed 3: final loss = 0.002120
# Training with seed=4...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Seed 4: final loss = 0.001455
#
# All seed experiments complete!

# %% [markdown]
# ### Seed Comparison Plot

# %%
plt.figure(figsize=(12, 6))

for seed, loss_history in seed_results.items():
    plt.plot(loss_history, label=f'Seed {seed}', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss Across Different Seeds')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# Statistics
final_losses = [seed_results[s][-1] for s in seeds]
print(f"Final losses: {[f'{l:.6f}' for l in final_losses]}")
print(f"Mean final loss: {np.mean(final_losses):.6f}")
print(f"Std final loss: {np.std(final_losses):.6f}")
print(f"Min final loss: {np.min(final_losses):.6f} (seed {seeds[np.argmin(final_losses)]})")
print(f"Max final loss: {np.max(final_losses):.6f} (seed {seeds[np.argmax(final_losses)]})")
# Out:
# Final losses: ['0.002078', '0.001486', '0.001266', '0.002120', '0.001455']
# Mean final loss: 0.001681
# Std final loss: 0.000350
# Min final loss: 0.001266 (seed 2)
# Max final loss: 0.002120 (seed 3)

# %% [markdown]
# ## Topology Comparison
#
# Compare training loss for different network topologies with seed=0.
#
# - Hidden layers: 1 to 7
# - Neurons per hidden layer: 1 to 8
#
# **Note:** The topology with 2 hidden layers and 4 neurons per layer will reuse the cached checkpoint from the seed comparison experiment (seed=0).

# %%
topology_results = {}
hidden_layers_range = range(1, 9)
neurons_range = range(1, 9)
epochs = 300
learning_rate = 0.01
seed = 0

for n_hidden in hidden_layers_range:
    for n_neurons in neurons_range:
        print(f"Training: {n_hidden} hidden layers, {n_neurons} neurons each...")
        
        config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
            n_inputs=2,
            n_outputs=2,
            n_hidden_layers=n_hidden,
            n_neurons_per_hidden=n_neurons,
            loss_func=SymbolicLoss.mse(),
            weight_init=WeightInit.XAVIER,
            bias_init_std=0.01,
            seed=seed
        )
        
        net = Net.fully_connected(config)
        
        result = net.train(
            inputs=input_list,
            targets=target_list,
            learning_rate=learning_rate,
            epochs=epochs,
            batch_size=32,
            checkpoint_config=checkpoint_config
        )
        
        topology_results[(n_hidden, n_neurons)] = result['loss_history']
        print(f"  Final loss: {result['loss_history'][-1]:.6f}")

print("\nAll topology experiments complete!")
# Out:
# Training: 1 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.110472
# Training: 1 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.006798
# Training: 1 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.003519
# Training: 1 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.001651
# Training: 1 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.001500
# Training: 1 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.001581
# Training: 1 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.001689
# Training: 1 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 3000, returning first 300 epochs of loss history.
#   Final loss: 0.002065
# Training: 2 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.110813
# Training: 2 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.003591
# Training: 2 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001971
# Training: 2 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.002078
# Training: 2 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001815
# Training: 2 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001216
# Training: 2 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001423
# Training: 2 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001330
# Training: 3 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.111380
# Training: 3 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.005339
# Training: 3 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.002526
# Training: 3 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001281
# Training: 3 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001426
# Training: 3 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001266
# Training: 3 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001285
# Training: 3 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001011
# Training: 4 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.114924
# Training: 4 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.007761
# Training: 4 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.004229
# Training: 4 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001601
# Training: 4 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001555
# Training: 4 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001364
# Training: 4 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001546
# Training: 4 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.000881
# Training: 5 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.117835
# Training: 5 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.010356
# Training: 5 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.002334
# Training: 5 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.003668
# Training: 5 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001666
# Training: 5 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001655
# Training: 5 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001560
# Training: 5 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.000991
# Training: 6 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.120855
# Training: 6 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.043976
# Training: 6 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.005822
# Training: 6 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.004655
# Training: 6 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.002437
# Training: 6 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001971
# Training: 6 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001888
# Training: 6 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.000407
# Training: 7 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.126206
# Training: 7 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.105043
# Training: 7 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.007314
# Training: 7 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.006674
# Training: 7 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.003746
# Training: 7 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001689
# Training: 7 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001069
# Training: 7 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.000774
# Training: 8 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.132694
# Training: 8 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.105658
# Training: 8 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.010532
# Training: 8 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.006957
# Training: 8 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001802
# Training: 8 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001649
# Training: 8 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.002071
# Training: 8 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 300, returning first 300 epochs of loss history.
#   Final loss: 0.001494
#
# All topology experiments complete!

# %% [markdown]
# ### Final Loss Heatmap

# %%
# Create heatmap of final losses
final_loss_grid = np.zeros((len(hidden_layers_range), len(neurons_range)))

for i, n_hidden in enumerate(hidden_layers_range):
    for j, n_neurons in enumerate(neurons_range):
        final_loss_grid[i, j] = topology_results[(n_hidden, n_neurons)][-1]

plt.figure(figsize=(12, 8))
im = plt.imshow(final_loss_grid, cmap='viridis', aspect='auto', origin='lower')

plt.xticks(range(len(neurons_range)), neurons_range)
plt.yticks(range(len(hidden_layers_range)), hidden_layers_range)
plt.xlabel('Neurons per Hidden Layer')
plt.ylabel('Number of Hidden Layers')
plt.title('Final Training Loss by Network Topology (Seed=0)')
plt.colorbar(im, label='Final Loss')
plt.show()

# Find best topology
best_idx = np.unravel_index(np.argmin(final_loss_grid), final_loss_grid.shape)
best_n_hidden = hidden_layers_range[best_idx[0]]
best_n_neurons = neurons_range[best_idx[1]]
best_loss = final_loss_grid[best_idx]

print(f"Best topology: {best_n_hidden} hidden layers, {best_n_neurons} neurons each")
print(f"Best final loss: {best_loss:.6f}")
print(f"Total parameters: {best_n_hidden * best_n_neurons * (2 + best_n_hidden) + 2 * best_n_hidden + 2}")
# Out:
# Best topology: 6 hidden layers, 8 neurons each
# Best final loss: 0.000407
# Total parameters: 398

# %% [markdown]
# ### Training Curves by Topology

# %%
# Plot a few representative topologies
fig, axes = plt.subplots(2, 4, figsize=(16, 8))
fig.suptitle('Training Loss by Topology (Seed=0)', fontsize=14)

for idx, n_hidden in enumerate(hidden_layers_range):
    row = idx // 4
    col = idx % 4
    ax = axes[row, col]
    
    for n_neurons in neurons_range:
        if (n_hidden, n_neurons) in topology_results:
            loss_hist = topology_results[(n_hidden, n_neurons)]
            ax.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)
    
    ax.set_title(f'{n_hidden} Hidden Layer(s)')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Loss')
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)
    ax.set_yscale('log')

plt.tight_layout()
plt.show()

# %%
# Plot all topologies with fixed neurons (4)
plt.figure(figsize=(12, 6))

for n_hidden in hidden_layers_range:
    n_neurons = 4
    loss_hist = topology_results[(n_hidden, n_neurons)]
    plt.plot(loss_hist, label=f'{n_hidden} layer(s)', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Hidden Layers (4 neurons each, Seed=0)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %%
# Plot all topologies with fixed layers (2)
plt.figure(figsize=(12, 6))

for n_neurons in neurons_range:
    n_hidden = 2
    loss_hist = topology_results[(n_hidden, n_neurons)]
    plt.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Neurons (2 hidden layers, Seed=0)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %% [markdown]
# ## Summary
#
# ### Key Findings:

# %%
# Compute summary statistics
print("=" * 60)
print("SEED COMPARISON SUMMARY")
print("=" * 60)
seed_final = [seed_results[s][-1] for s in seeds]
print(f"Seeds tested: {list(seeds)}")
print(f"Final losses: {[f'{l:.6f}' for l in seed_final]}")
print(f"Mean: {np.mean(seed_final):.6f}")
print(f"Std: {np.std(seed_final):.6f}")
print(f"Range: [{np.min(seed_final):.6f}, {np.max(seed_final):.6f}]")

print("\n" + "=" * 60)
print("TOPOLOGY COMPARISON SUMMARY")
print("=" * 60)
print(f"Hidden layers tested: {list(hidden_layers_range)}")
print(f"Neurons tested: {list(neurons_range)}")
print(f"Total configurations: {len(hidden_layers_range) * len(neurons_range)}")

all_final_losses = [topology_results[(h, n)][-1] for h in hidden_layers_range for n in neurons_range]
print(f"\nBest final loss: {np.min(all_final_losses):.6f}")
print(f"Worst final loss: {np.max(all_final_losses):.6f}")
print(f"Mean final loss: {np.mean(all_final_losses):.6f}")
print(f"Median final loss: {np.median(all_final_losses):.6f}")
# Out:
# ============================================================
# SEED COMPARISON SUMMARY
# ============================================================
# Seeds tested: [0, 1, 2, 3, 4]
# Final losses: ['0.002078', '0.001486', '0.001266', '0.002120', '0.001455']
# Mean: 0.001681
# Std: 0.000350
# Range: [0.001266, 0.002120]
#
# ============================================================
# TOPOLOGY COMPARISON SUMMARY
# ============================================================
# Hidden layers tested: [1, 2, 3, 4, 5, 6, 7, 8]
# Neurons tested: [1, 2, 3, 4, 5, 6, 7, 8]
# Total configurations: 64
#
# Best final loss: 0.000407
# Worst final loss: 0.132694
# Mean final loss: 0.021099
# Median final loss: 0.002018

# %%
topology_results = {}
hidden_layers_range = range(1, 2)
neurons_range = range(1, 100)
epochs = 3000
learning_rate = 0.01
seed = 0

for n_hidden in hidden_layers_range:
    for n_neurons in neurons_range:
        print(f"Training: {n_hidden} hidden layers, {n_neurons} neurons each...")
        
        config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
            n_inputs=2,
            n_outputs=2,
            n_hidden_layers=n_hidden,
            n_neurons_per_hidden=n_neurons,
            loss_func=SymbolicLoss.mse(),
            weight_init=WeightInit.XAVIER,
            bias_init_std=0.01,
            seed=seed
        )
        
        net = Net.fully_connected(config)
        
        result = net.train(
            inputs=input_list,
            targets=target_list,
            learning_rate=learning_rate,
            epochs=epochs,
            batch_size=32,
            checkpoint_config=checkpoint_config
        )
        
        topology_results[(n_hidden, n_neurons)] = result['loss_history']
        print(f"  Final loss: {result['loss_history'][-1]:.6f}")

print("\nAll topology experiments complete!")
# Out:
# Training: 1 hidden layers, 1 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.109389
# Training: 1 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.002175
# Training: 1 hidden layers, 3 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000952
# Training: 1 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000334
# Training: 1 hidden layers, 5 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000325
# Training: 1 hidden layers, 6 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000332
# Training: 1 hidden layers, 7 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000344
# Training: 1 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000305
# Training: 1 hidden layers, 9 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000154
# Training: 1 hidden layers, 10 neurons each...
# Loaded checkpoint from epoch 110220, returning first 3000 epochs of loss history.
#   Final loss: 0.000201
# Training: 1 hidden layers, 11 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000095
# Training: 1 hidden layers, 12 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000109
# Training: 1 hidden layers, 13 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000140
# Training: 1 hidden layers, 14 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000362
# Training: 1 hidden layers, 15 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000138
# Training: 1 hidden layers, 16 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000264
# Training: 1 hidden layers, 17 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000152
# Training: 1 hidden layers, 18 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000178
# Training: 1 hidden layers, 19 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000132
# Training: 1 hidden layers, 20 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000183
# Training: 1 hidden layers, 21 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000088
# Training: 1 hidden layers, 22 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000206
# Training: 1 hidden layers, 23 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000206
# Training: 1 hidden layers, 24 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000158
# Training: 1 hidden layers, 25 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000087
# Training: 1 hidden layers, 26 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000074
# Training: 1 hidden layers, 27 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000150
# Training: 1 hidden layers, 28 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000235
# Training: 1 hidden layers, 29 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000269
# Training: 1 hidden layers, 30 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000229
# Training: 1 hidden layers, 31 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000174
# Training: 1 hidden layers, 32 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000303
# Training: 1 hidden layers, 33 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000134
# Training: 1 hidden layers, 34 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000066
# Training: 1 hidden layers, 35 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000208
# Training: 1 hidden layers, 36 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000161
# Training: 1 hidden layers, 37 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000084
# Training: 1 hidden layers, 38 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000221
# Training: 1 hidden layers, 39 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000088
# Training: 1 hidden layers, 40 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000171
# Training: 1 hidden layers, 41 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000129
# Training: 1 hidden layers, 42 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000113
# Training: 1 hidden layers, 43 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000136
# Training: 1 hidden layers, 44 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000179
# Training: 1 hidden layers, 45 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000110
# Training: 1 hidden layers, 46 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000185
# Training: 1 hidden layers, 47 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000130
# Training: 1 hidden layers, 48 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000164
# Training: 1 hidden layers, 49 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000176
# Training: 1 hidden layers, 50 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000077
# Training: 1 hidden layers, 51 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000086
# Training: 1 hidden layers, 52 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000148
# Training: 1 hidden layers, 53 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000297
# Training: 1 hidden layers, 54 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000115
# Training: 1 hidden layers, 55 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000119
# Training: 1 hidden layers, 56 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000111
# Training: 1 hidden layers, 57 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000410
# Training: 1 hidden layers, 58 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000268
# Training: 1 hidden layers, 59 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000237
# Training: 1 hidden layers, 60 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000122
# Training: 1 hidden layers, 61 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000100
# Training: 1 hidden layers, 62 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000186
# Training: 1 hidden layers, 63 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000185
# Training: 1 hidden layers, 64 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000257
# Training: 1 hidden layers, 65 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000240
# Training: 1 hidden layers, 66 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000311
# Training: 1 hidden layers, 67 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000295
# Training: 1 hidden layers, 68 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000170
# Training: 1 hidden layers, 69 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000122
# Training: 1 hidden layers, 70 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000137
# Training: 1 hidden layers, 71 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000168
# Training: 1 hidden layers, 72 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000140
# Training: 1 hidden layers, 73 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000260
# Training: 1 hidden layers, 74 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000207
# Training: 1 hidden layers, 75 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000111
# Training: 1 hidden layers, 76 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000223
# Training: 1 hidden layers, 77 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000251
# Training: 1 hidden layers, 78 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000269
# Training: 1 hidden layers, 79 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000216
# Training: 1 hidden layers, 80 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000239
# Training: 1 hidden layers, 81 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000225
# Training: 1 hidden layers, 82 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000091
# Training: 1 hidden layers, 83 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000138
# Training: 1 hidden layers, 84 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000275
# Training: 1 hidden layers, 85 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000147
# Training: 1 hidden layers, 86 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000070
# Training: 1 hidden layers, 87 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000171
# Training: 1 hidden layers, 88 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000183
# Training: 1 hidden layers, 89 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000131
# Training: 1 hidden layers, 90 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000177
# Training: 1 hidden layers, 91 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000095
# Training: 1 hidden layers, 92 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000264
# Training: 1 hidden layers, 93 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000306
# Training: 1 hidden layers, 94 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000211
# Training: 1 hidden layers, 95 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000209
# Training: 1 hidden layers, 96 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000063
# Training: 1 hidden layers, 97 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000058
# Training: 1 hidden layers, 98 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000227
# Training: 1 hidden layers, 99 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000099
#
# All topology experiments complete!

# %%
# Plot all topologies with fixed layers (1)
plt.figure(figsize=(12, 6))

for n_neurons in neurons_range:
    n_hidden = 1
    loss_hist = topology_results[(n_hidden, n_neurons)]
    plt.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Neurons (1 hidden layer, Seed=0)')
#plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %%
config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
    n_inputs=2,
    n_outputs=2,
    n_hidden_layers=1,
    n_neurons_per_hidden=10,
    loss_func=SymbolicLoss.mse(),
    weight_init=WeightInit.XAVIER,
    bias_init_std=0.01,
    seed=seed
)

net = Net.fully_connected(config)

result = net.train(
    inputs=input_list,
    targets=target_list,
    learning_rate=0.01,
    epochs=100000,
    batch_size=32,
    checkpoint_config=checkpoint_config
)
# Out:
# Loaded checkpoint from epoch 110220, returning first 100000 epochs of loss history.

# %%
# Plot all topologies with fixed layers (2)
plt.figure(figsize=(12, 6))

plt.plot(result['loss_history'], label=f'10 neurons', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Neurons (1 hidden layer, Seed=0)')
#plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()

# %%
topology_results = {}
neurons_range = [2, 4, 8, 16, 32, 64, 100]
epochs = 3000
learning_rate = 0.01
seed = 0

n_hidden = 1
for n_neurons in neurons_range:
    print(f"Training: {n_hidden} hidden layers, {n_neurons} neurons each...")
    
    config = NetConfig(hidden_activation=SymbolicActivation.tanh(), output_activation=SymbolicActivation.linear(), 
        n_inputs=2,
        n_outputs=2,
        n_hidden_layers=n_hidden,
        n_neurons_per_hidden=n_neurons,
        loss_func=SymbolicLoss.mse(),
        weight_init=WeightInit.XAVIER,
        bias_init_std=0.01,
        seed=seed
    )
    
    net = Net.fully_connected(config)
    
    result = net.train(
        inputs=input_list,
        targets=target_list,
        learning_rate=learning_rate,
        epochs=epochs,
        batch_size=32,
        checkpoint_config=checkpoint_config
    )
    
    topology_results[(n_hidden, n_neurons)] = result['loss_history']
    print(f"  Final loss: {result['loss_history'][-1]:.6f}")

print("\nAll topology experiments complete!")
# Out:
# Training: 1 hidden layers, 2 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.002175
# Training: 1 hidden layers, 4 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000334
# Training: 1 hidden layers, 8 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000305
# Training: 1 hidden layers, 16 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000264
# Training: 1 hidden layers, 32 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000303
# Training: 1 hidden layers, 64 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000257
# Training: 1 hidden layers, 100 neurons each...
# Loaded checkpoint from epoch 3000, returning first 3000 epochs of loss history.
#   Final loss: 0.000164
#
# All topology experiments complete!

# %%
# Plot all topologies with fixed layers (1)
plt.figure(figsize=(12, 6))

for n_neurons in neurons_range:
    n_hidden = 1
    loss_hist = topology_results[(n_hidden, n_neurons)]
    plt.plot(loss_hist, label=f'{n_neurons} neurons', alpha=0.8)

plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training Loss: Varying Neurons (1 hidden layer, Seed=0)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.yscale('log')
plt.show()
